# %% [markdown]
# <center><img src="https://raw.githubusercontent.com/mateuszk098/kaggle_notebooks/master/playground_series_s4e03/undraw_Coding_re_iv62.png" width=400px></center>
#
# # <p style="font-family: 'JetBrains Mono'; font-weight: bold; font-size: 125%; color: #4A4B52; text-align: center">Playground Series S4E03 - Steel Plates Faults</p>

# %%
# %load ../utils/config.py
import glob
import logging
import operator
import os
import shutil
import subprocess
import sys
import time
import warnings
from abc import abstractmethod
from array import array
from collections import defaultdict, namedtuple
from copy import copy
from functools import partial, reduce, singledispatch
from itertools import combinations, product
from logging import Logger
from pathlib import Path
from typing import Any, Iterable, Protocol, TypeVar
from urllib.request import urlretrieve

import joblib
import lightgbm as lgb
import matplotlib.pyplot as plt
import numpy as np
import optuna
import pandas as pd
import plotly.express as px
import plotly.figure_factory as ff
import plotly.graph_objects as go
import plotly.io as pio
import scipy.stats as stats
import seaborn as sns
import shap
import xgboost as xgb
import yaml
from colorama import Fore, Style
from IPython.display import HTML, Image, display_html
from matplotlib import lines
from optuna import samplers
from optuna.study import Study, StudyDirection
from optuna.trial import FrozenTrial, Trial
from plotly.subplots import make_subplots
from scipy.cluster.hierarchy import linkage
from scipy.spatial.distance import squareform
from sklearn.compose import make_column_selector, make_column_transformer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve
from sklearn.model_selection import StratifiedKFold, cross_val_predict, train_test_split
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import (
    FunctionTransformer,
    LabelEncoder,
    OneHotEncoder,
    OrdinalEncoder,
    StandardScaler,
)

ON_KAGGLE = os.getenv("KAGGLE_KERNEL_RUN_TYPE") is not None

# Colorama settings.
CLR = (Style.BRIGHT + Fore.BLACK) if ON_KAGGLE else (Style.BRIGHT + Fore.WHITE)
RED = Style.BRIGHT + Fore.RED
BLUE = Style.BRIGHT + Fore.BLUE
CYAN = Style.BRIGHT + Fore.CYAN
MAGENTA = Style.BRIGHT + Fore.MAGENTA
RESET = Style.RESET_ALL

# Ticks size for plotly and matplotlib.
TICKSIZE = 11
# Data Frame and Plotly colors.
FONT_COLOR = "#4A4B52"
GRADIENT_COLOR = "#BAB8B8"
BACKGROUND_COLOR = "#FFFCFA"
COLOR_SCHEME = np.array(("#4A4B52", "#780D0D", "#E8BA91"))

# Set Plotly theme.
pio.templates["minimalist"] = go.layout.Template(
    layout=go.Layout(
        width=820,
        height=520,
        title_font_size=20,
        font_color=FONT_COLOR,
        font_family="Open Sans",
        plot_bgcolor=BACKGROUND_COLOR,
        paper_bgcolor=BACKGROUND_COLOR,
        xaxis=dict(tickfont_size=TICKSIZE, titlefont_size=TICKSIZE, showgrid=False),
        yaxis=dict(tickfont_size=TICKSIZE, titlefont_size=TICKSIZE, showgrid=False),
        legend=dict(x=1, y=1, yanchor="bottom", xanchor="right", orientation="h", title=""),
    ),
    layout_colorway=COLOR_SCHEME,
)
pio.templates.default = "plotly+minimalist"

# Set Matplotlib theme.
MATPLOTLIB_THEME = {
    "axes.labelcolor": FONT_COLOR,
    "axes.labelsize": TICKSIZE,
    "axes.facecolor": BACKGROUND_COLOR,
    "axes.titlesize": 14,
    "axes.grid": False,
    "xtick.labelsize": TICKSIZE,
    "xtick.color": FONT_COLOR,
    "ytick.labelsize": TICKSIZE,
    "ytick.color": FONT_COLOR,
    "figure.facecolor": BACKGROUND_COLOR,
    "figure.edgecolor": BACKGROUND_COLOR,
    "figure.titlesize": 14,
    "figure.dpi": 72,  # Locally Seaborn uses 72, meanwhile Kaggle 96.
    "text.color": FONT_COLOR,
    "font.size": TICKSIZE,
    "font.family": "Serif",
}
sns.set_theme(rc=MATPLOTLIB_THEME)

# Define Data Frame theme.
CELL_HOVER = {  # for row hover use <tr> instead of <td>
    "selector": "td:hover",
    "props": f"background-color: {BACKGROUND_COLOR}",
}
TEXT_HIGHLIGHT = {
    "selector": "td",
    "props": f"color: {FONT_COLOR}; font-weight: bold",
}
INDEX_NAMES = {
    "selector": ".index_name",
    "props": f"font-weight: normal; background-color: {BACKGROUND_COLOR}; color: {FONT_COLOR};",
}
HEADERS = {
    "selector": "th:not(.index_name)",
    "props": f"font-weight: normal; background-color: {BACKGROUND_COLOR}; color: {FONT_COLOR};",
}
DF_STYLE = (INDEX_NAMES, HEADERS, TEXT_HIGHLIGHT)
DF_CMAP = sns.light_palette(GRADIENT_COLOR, as_cmap=True)

# Html style for table of contents, code highlight and url.
HTML_STYLE = """
    <style>
    code {
        background: rgba(42, 53, 125, 0.10) !important;
        border-radius: 4px !important;
    }
    a {
        color: rgba(123, 171, 237, 1.0) !important;
    }
    ol.numbered-list {
        counter-reset: item;
    }
    ol.numbered-list li {
        display: block;
    }
    ol.numbered-list li:before {
        content: counters(item, '.') '. ';
        counter-increment: item;
    }
    </style>
"""


# Utility functions.
def download_from_kaggle(expr, data_dir="data"):
    """Download all files from the Kaggle competition/dataset.

    Args:
        expr: Match expression to be used by kaggle API, e.g.
            "kaggle competitions download -c competition" or
            "kaggle datasets download -d user/dataset".
        data_dir: Optional. Directory path where to save files. Default to `data`,
        which means that files will be downloaded to `data` directory.

    Notes:
        If the associated files already exists, then it does nothing.
    """

    data_dir = Path(data_dir)

    match expr.split():
        case ["kaggle", _, "download", *args] if args:
            data_dir.mkdir(parents=True, exist_ok=True)
            filename = args[-1].split("/")[-1] + ".zip"
            if not (data_dir / filename).is_file():
                subprocess.run(expr)
                shutil.unpack_archive(filename, data_dir)
                shutil.move(filename, data_dir)
        case _:
            raise SyntaxError("expression is not compatible with Kaggle API")


def get_interpolated_colors(color1, color2, /, n_colors=1):
    """Return `n_colors` colors in HEX format, interpolated beetwen `color1` and `color2`.

    Args:
        color1: Initial HEX color to be interpolated from.
        color2: Final HEX color to be interpolated from.
        n_colors: Optional. Number of colors to be interpolated between `color1`
            and `color2`. Default to 1.

    Returns:
        colors: List of colors interpolated between `color1` and `color2`.
    """

    def interpolate(color1, color2, t):
        r1, g1, b1 = int(color1[1:3], 16), int(color1[3:5], 16), int(color1[5:7], 16)
        r2, g2, b2 = int(color2[1:3], 16), int(color2[3:5], 16), int(color2[5:7], 16)
        r = int(r1 + (r2 - r1) * t)
        g = int(g1 + (g2 - g1) * t)
        b = int(b1 + (b2 - b1) * t)
        return f"#{r:02X}{g:02X}{b:02X}"

    return list(interpolate(color1, color2, k / (n_colors + 1)) for k in range(1, n_colors + 1))


def get_pretty_frame(
    frame,
    *,
    gradient=False,
    formatter=None,
    precision=3,
    repr_html=False,
    index_width=None,
    col_width=None,
    col_title_centering=False,
):
    frame = pd.DataFrame(frame)
    style = list(DF_STYLE)
    if index_width is not None:
        index_width_style = {
            "selector": ".index_name",
            "props": f"min-width: {index_width};",
        }
        style.append(index_width_style)
    if col_width is not None:
        col_width_style = {
            "selector": "th",
            "props": f"min-width: {col_width};",
        }
        style.append(col_width_style)
    if col_title_centering:
        col_title_style = {
            "selector": "th.col_heading",
            "props": "text-align: center;",
        }
        style.append(col_title_style)
    stylish_frame = frame.style.set_table_styles(style)  # type: ignore
    stylish_frame = stylish_frame.format(formatter=formatter, precision=precision)
    if gradient:
        stylish_frame = stylish_frame.background_gradient(DF_CMAP)
    if repr_html:
        stylish_frame = stylish_frame.set_table_attributes("style='display:inline'")
        stylish_frame = stylish_frame._repr_html_()  # type: ignore
    return stylish_frame


def numeric_descr(frame, /):
    frame = pd.DataFrame(frame)
    return (
        frame.describe(percentiles=[0.01, 0.05, 0.25, 0.50, 0.75, 0.95, 0.99])
        .T.drop("count", axis=1)
        .rename(columns=str.title)
    )


def frame_summary(frame, /):
    frame = pd.DataFrame(frame)
    n_null = frame.isna().sum()
    n_null_percent = n_null / len(frame) * 100.0
    n_unique = frame.apply(lambda col: len(col.dropna().unique()))
    mode_count = frame.apply(lambda col: col.value_counts().iloc[0])
    mode = frame.mode().iloc[:1].T.squeeze()
    n_unique_percent = n_unique / len(frame) * 100.0
    mode_percent_count = mode_count / len(frame) * 100.0

    return pd.DataFrame(
        {
            "dtype": frame.dtypes,
            "n_null": n_null,
            "n_null_percent": n_null_percent,
            "n_unique": n_unique,
            "n_unique_percent": n_unique_percent,
            "mode": mode,
            "mode_count": mode_count,
            "mode_percent_count": mode_percent_count,
        }
    )


def check_categories_alignment(frame1, frame2, out_color=BLUE):
    frame1 = pd.DataFrame(frame1)
    frame2 = pd.DataFrame(frame2)

    print(CLR + "The same categories in both datasets?\n")
    cat_features = frame2.select_dtypes(include=["object", "category"]).columns.to_list()

    for feature in cat_features:
        frame1_unique = set(frame1[feature].dropna().unique())
        frame2_unique = set(frame2[feature].dropna().unique())
        same = np.all(frame1_unique == frame2_unique)
        print(CLR + f"{feature:25s}", out_color + f"{same}")


def get_lower_triangular_frame(frame, /):
    frame = pd.DataFrame(frame)
    if not frame.shape[0] == frame.shape[1]:
        raise ValueError(f"{type(frame)!r} is not square frame")
    lower_triu = np.triu(np.ones_like(frame, dtype=bool))
    frame = frame.mask(lower_triu)
    return frame.dropna(axis="index", how="all").dropna(axis="columns", how="all")


def save_and_show_fig(fig, filename, img_dir="images", format="png"):
    img_dir = Path(img_dir)
    img_dir.mkdir(parents=True, exist_ok=True)
    fig_path = img_dir / (filename + "." + format)
    fig.write_image(fig_path)
    return Image(fig.to_image(format=format))


def get_n_rows_and_axes(n_features, n_cols, start_at=1):
    n_rows = int(np.ceil(n_features / n_cols))
    current_col = range(start_at, n_cols + start_at)
    current_row = range(start_at, n_rows + start_at)
    return n_rows, tuple(product(current_row, current_col))


def get_kde_estimation(
    series,
    *,
    bw_method=None,
    weights=None,
    percentile_range=(0, 100),
    estimate_points_frac=0.1,
    space_extension_frac=0.01,
    cumulative=False,
):
    """Return pdf dictionary for set of points using gaussian kernel density estimation.

    Args:
        series: The dataset with which `stats.gaussian_kde` is initialized.
        bw_method: Optional. The method used to calculate the estimator bandwidth.
        This can be 'scott', 'silverman', a scalar constant or a callable. If a scalar,
        this will be used directly as `kde.factor`. If a callable, it should take
        a `stats.gaussian_kde` instance as only parameter and return a scalar.
        If `None` (default), 'scott' is used.
        weights: Optional. Weights of datapoints. This must be the same shape as dataset.
        If `None` (default), the samples are assumed to be equally weighted.
        percentile_range: Optional. Percentile range of the `series` to create estimated space.
        By default (0, 100) range is used.
        estimate_points_frac: Optional. Fraction of `series` length to create linspace for
        estimated points.
        space_extension_frac: Optional. Estimation space will be extended by
        `space_extension_frac * len(series)` for both edges.
        cumulative: Optional. Whether to calculate cdf. Default to `False`.

    Returns:
        Dictionary with kde space, values, and cumulative values if `cumulative` is `True`.
    """

    series = pd.Series(series).dropna()
    kde = stats.gaussian_kde(series, bw_method=bw_method, weights=weights)
    start, stop = np.percentile(series, percentile_range)

    n_points = int(estimate_points_frac * len(series))
    n_extend = int(space_extension_frac * len(series))

    if n_extend > 0:
        dx = (stop - start) / (n_points - 1)
        start, stop = start - n_extend * dx, stop + n_extend * dx

    kde_space = np.linspace(start, stop, n_points)
    kde_vals = kde.evaluate(kde_space)
    results = {"space": kde_space, "vals": kde_vals}

    if cumulative:
        kde_vals_cum = np.cumsum(kde_vals)
        return results | {"vals_cumulative": kde_vals_cum / kde_vals_cum.max()}

    return results


# Html highlight. Must be included at the end of all imports!
HTML(HTML_STYLE)
# Out:
#     <style>
#     code {
#         background: rgba(42, 53, 125, 0.10) !important;
#         border-radius: 4px !important;
#     }
#     a {
#         color: rgba(123, 171, 237, 1.0) !important;
#     }
#     ol.numbered-list {
#         counter-reset: item;
#     }
#     ol.numbered-list li {
#         display: block;
#     }
#     ol.numbered-list li:before {
#         content: counters(item, '.') '. ';
#         counter-increment: item;
#     }
#     </style>

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
# ">
#     <b><span style="color: #780D0D;">&#x25FC</span> Competition Description</b>
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
#     text-align: justify;
#     text-justify: inter-word;
# ">
#     The dataset for this competition (both train and test) was generated from a deep learning model trained on the <a href="https://archive.ics.uci.edu/dataset/198/steel+plates+faults"><b>Steel Plates Faults</b></a>. Feature distributions are close to, but not exactly the same, as the original.
# </p>
#
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
# ">
#     <b><span style="color: #780D0D;">&#x25FC</span> Task</b>
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
#     text-align: justify;
#     text-justify: inter-word;
# ">
#     Submissions are evaluated using area under the ROC curve using the predicted probabilities and the ground truth targets. To calculate the final score, AUC is calculated for each of the 7 defect categories and then averaged. In other words, the score is the average of the individual AUC of each predicted column.
# </p>
#
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
# ">
#     <b><span style="color: #780D0D;">&#x25FC</span> Table of Contents</b>
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
#     text-align: justify;
#     text-justify: inter-word;
# ">
#     The table of contents provides pleasurable navigation through the whole notebook. You can easily navigate through sections and return to TOC. If you want quickly find out something about the dataset, just read the first section, i.e. <b>Quick Overview</b>.
# </p>
#
# <blockquote class="anchor" id="top" style="
#     margin-right: auto;
#     margin-left: auto;
#     padding: 10px;
#     background-color: #780D0D;
#     border-radius: 2px;
#     border: 1px solid #780D0D;
# ">
# <ol class="numbered-list" style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
#     color: #F2F2F0;
#     margin-top: 15px;
#     margin-bottom: 15px;
# ">
#     <li><a href="#quick_overview"><span style="color: #F2F2F0">Quick Overview</span></a>
#         <ol class="numbered-list" class="numbered-list" style="
#             font-size: 16px;
#             font-family: 'JetBrains Mono';
#         ">
#             <li><a href="#data_reading_and_problem_definition"><span style="color: #F2F2F0">Data Reading &amp; Problem Definition</span></a></li>
#             <li><a href="#basic_numerical_properties_summaries"><span style="color: #F2F2F0">Basic Numerical Properties &amp; Summaries</span></a></li>
#             <li><a href="#playing_with_categorical_variables"><span style="color: #F2F2F0">Playing with Categorical Variables</span></a></li>
#         </ol>
#     </li>
#     <li><a href="#optuna_tuners"><span style="color: #F2F2F0">Optuna Tuners</span></a>
#         <ol class="numbered-list" class="numbered-list" style="
#             font-size: 16px;
#             font-family: 'JetBrains Mono';
#         ">
#             <li><a href="#simple_preprocessing"><span style="color: #F2F2F0">Simple Preprocessing</span></a></li>
#             <li><a href="#tuner_interface"><span style="color: #F2F2F0">Tuner Interface</span></a></li>
#             <li><a href="#actual_tuner"><span style="color: #F2F2F0">Actual Tuner</span></a></li>
#             <li><a href="#warmup_cross_validation"><span style="color: #F2F2F0">Warmup Cross-Validation</span></a></li>
#             <li><a href="#final_training"><span style="color: #F2F2F0">Final Training</span></a></li>
#         </ol>
#     </li>
#     <li><a href="#summary"><span style="color: #F2F2F0">Summary</span></a></li>
# </ol>
# </blockquote>

# %% [markdown]
# # <b> <span style="font-family: 'JetBrains Mono'; color: #4A4B52">1</span> <span style='color: #780D0D'>|</span> <span style="font-family: 'JetBrains Mono'; color: #4A4B52">Quick Overview</span></b><a class="anchor" id="quick_overview"></a> [↑](#top)

# %% [markdown]
# ## <b> <span style="font-family: 'JetBrains Mono'; color: #4A4B52">1.1</span> <span style='color: #780D0D'>|</span> <span style="font-family: 'JetBrains Mono'; color: #4A4B52">Data Reading &amp; Problem Definition</span></b><a class="anchor" id="data_reading_and_problem_definition"></a> [↑](#top)

# %%
competition = "playground-series-s4e3"
competition_dataset = f"kaggle competitions download -c {competition}"

if not ON_KAGGLE:
    download_from_kaggle(competition_dataset)
    train_path = "data/train.csv"
    test_path = "data/test.csv"
else:
    train_path = f"/kaggle/input/{competition}/train.csv"
    test_path = f"/kaggle/input/{competition}/test.csv"

train = pd.read_csv(train_path, index_col="id", engine="pyarrow")
test = pd.read_csv(test_path, index_col="id", engine="pyarrow")

# %%
# Original dataset is not avaailable on Kaggle so we download it from UCI repository.
orig_url = "https://archive.ics.uci.edu/static/public/198/steel+plates+faults.zip"
orig_path = Path("data/steel_plates_faults.zip")
orig_path.parent.mkdir(parents=True, exist_ok=True)

if not orig_path.is_file():
    urlretrieve(orig_url, orig_path)
    shutil.unpack_archive(orig_path, "data/")

with open("data/Faults27x7_var", "r") as f:
    orig_names = f.read().splitlines()

orig = pd.read_csv("data/Faults.NNA", sep="\t", engine="pyarrow", header=None, names=orig_names)
orig = orig[train.columns]  # Sort columns to match with train dataset - also fast fail.

# %%
# Here I pass comma formatter since there are huge numbers in the dataset.
get_pretty_frame(orig.head(), formatter="{:,.2f}")
# Out:
# <style type="text/css">
# #T_4a40c .index_name {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_4a40c th:not(.index_name) {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_4a40c td {
#   color: #4A4B52;
#   font-weight: bold;
# }
# </style>
# <table id="T_4a40c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a40c_level0_col0" class="col_heading level0 col0" >X_Minimum</th>
#       <th id="T_4a40c_level0_col1" class="col_heading level0 col1" >X_Maximum</th>
#       <th id="T_4a40c_level0_col2" class="col_heading level0 col2" >Y_Minimum</th>
#       <th id="T_4a40c_level0_col3" class="col_heading level0 col3" >Y_Maximum</th>
#       <th id="T_4a40c_level0_col4" class="col_heading level0 col4" >Pixels_Areas</th>
#       <th id="T_4a40c_level0_col5" class="col_heading level0 col5" >X_Perimeter</th>
#       <th id="T_4a40c_level0_col6" class="col_heading level0 col6" >Y_Perimeter</th>
#       <th id="T_4a40c_level0_col7" class="col_heading level0 col7" >Sum_of_Luminosity</th>
#       <th id="T_4a40c_level0_col8" class="col_heading level0 col8" >Minimum_of_Luminosity</th>
#       <th id="T_4a40c_level0_col9" class="col_heading level0 col9" >Maximum_of_Luminosity</th>
#       <th id="T_4a40c_level0_col10" class="col_heading level0 col10" >Length_of_Conveyer</th>
#       <th id="T_4a40c_level0_col11" class="col_heading level0 col11" >TypeOfSteel_A300</th>
#       <th id="T_4a40c_level0_col12" class="col_heading level0 col12" >TypeOfSteel_A400</th>
#       <th id="T_4a40c_level0_col13" class="col_heading level0 col13" >Steel_Plate_Thickness</th>
#       <th id="T_4a40c_level0_col14" class="col_heading level0 col14" >Edges_Index</th>
#       <th id="T_4a40c_level0_col15" class="col_heading level0 col15" >Empty_Index</th>
#       <th id="T_4a40c_level0_col16" class="col_heading level0 col16" >Square_Index</th>
#       <th id="T_4a40c_level0_col17" class="col_heading level0 col17" >Outside_X_Index</th>
#       <th id="T_4a40c_level0_col18" class="col_heading level0 col18" >Edges_X_Index</th>
#       <th id="T_4a40c_level0_col19" class="col_heading level0 col19" >Edges_Y_Index</th>
#       <th id="T_4a40c_level0_col20" class="col_heading level0 col20" >Outside_Global_Index</th>
#       <th id="T_4a40c_level0_col21" class="col_heading level0 col21" >LogOfAreas</th>
#       <th id="T_4a40c_level0_col22" class="col_heading level0 col22" >Log_X_Index</th>
#       <th id="T_4a40c_level0_col23" class="col_heading level0 col23" >Log_Y_Index</th>
#       <th id="T_4a40c_level0_col24" class="col_heading level0 col24" >Orientation_Index</th>
#       <th id="T_4a40c_level0_col25" class="col_heading level0 col25" >Luminosity_Index</th>
#       <th id="T_4a40c_level0_col26" class="col_heading level0 col26" >SigmoidOfAreas</th>
#       <th id="T_4a40c_level0_col27" class="col_heading level0 col27" >Pastry</th>
#       <th id="T_4a40c_level0_col28" class="col_heading level0 col28" >Z_Scratch</th>
#       <th id="T_4a40c_level0_col29" class="col_heading level0 col29" >K_Scatch</th>
#       <th id="T_4a40c_level0_col30" class="col_heading level0 col30" >Stains</th>
#       <th id="T_4a40c_level0_col31" class="col_heading level0 col31" >Dirtiness</th>
#       <th id="T_4a40c_level0_col32" class="col_heading level0 col32" >Bumps</th>
#       <th id="T_4a40c_level0_col33" class="col_heading level0 col33" >Other_Faults</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a40c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4a40c_row0_col0" class="data row0 col0" >42.00</td>
#       <td id="T_4a40c_row0_col1" class="data row0 col1" >50.00</td>
#       <td id="T_4a40c_row0_col2" class="data row0 col2" >270,900.00</td>
#       <td id="T_4a40c_row0_col3" class="data row0 col3" >270,944.00</td>
#       <td id="T_4a40c_row0_col4" class="data row0 col4" >267.00</td>
#       <td id="T_4a40c_row0_col5" class="data row0 col5" >17.00</td>
#       <td id="T_4a40c_row0_col6" class="data row0 col6" >44.00</td>
#       <td id="T_4a40c_row0_col7" class="data row0 col7" >24,220.00</td>
#       <td id="T_4a40c_row0_col8" class="data row0 col8" >76.00</td>
#       <td id="T_4a40c_row0_col9" class="data row0 col9" >108.00</td>
#       <td id="T_4a40c_row0_col10" class="data row0 col10" >1,687.00</td>
#       <td id="T_4a40c_row0_col11" class="data row0 col11" >1.00</td>
#       <td id="T_4a40c_row0_col12" class="data row0 col12" >0.00</td>
#       <td id="T_4a40c_row0_col13" class="data row0 col13" >80.00</td>
#       <td id="T_4a40c_row0_col14" class="data row0 col14" >0.05</td>
#       <td id="T_4a40c_row0_col15" class="data row0 col15" >0.24</td>
#       <td id="T_4a40c_row0_col16" class="data row0 col16" >0.18</td>
#       <td id="T_4a40c_row0_col17" class="data row0 col17" >0.00</td>
#       <td id="T_4a40c_row0_col18" class="data row0 col18" >0.47</td>
#       <td id="T_4a40c_row0_col19" class="data row0 col19" >1.00</td>
#       <td id="T_4a40c_row0_col20" class="data row0 col20" >1.00</td>
#       <td id="T_4a40c_row0_col21" class="data row0 col21" >2.43</td>
#       <td id="T_4a40c_row0_col22" class="data row0 col22" >0.90</td>
#       <td id="T_4a40c_row0_col23" class="data row0 col23" >1.64</td>
#       <td id="T_4a40c_row0_col24" class="data row0 col24" >0.82</td>
#       <td id="T_4a40c_row0_col25" class="data row0 col25" >-0.29</td>
#       <td id="T_4a40c_row0_col26" class="data row0 col26" >0.58</td>
#       <td id="T_4a40c_row0_col27" class="data row0 col27" >1.00</td>
#       <td id="T_4a40c_row0_col28" class="data row0 col28" >0.00</td>
#       <td id="T_4a40c_row0_col29" class="data row0 col29" >0.00</td>
#       <td id="T_4a40c_row0_col30" class="data row0 col30" >0.00</td>
#       <td id="T_4a40c_row0_col31" class="data row0 col31" >0.00</td>
#       <td id="T_4a40c_row0_col32" class="data row0 col32" >0.00</td>
#       <td id="T_4a40c_row0_col33" class="data row0 col33" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_4a40c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4a40c_row1_col0" class="data row1 col0" >645.00</td>
#       <td id="T_4a40c_row1_col1" class="data row1 col1" >651.00</td>
#       <td id="T_4a40c_row1_col2" class="data row1 col2" >2,538,079.00</td>
#       <td id="T_4a40c_row1_col3" class="data row1 col3" >2,538,108.00</td>
#       <td id="T_4a40c_row1_col4" class="data row1 col4" >108.00</td>
#       <td id="T_4a40c_row1_col5" class="data row1 col5" >10.00</td>
#       <td id="T_4a40c_row1_col6" class="data row1 col6" >30.00</td>
#       <td id="T_4a40c_row1_col7" class="data row1 col7" >11,397.00</td>
#       <td id="T_4a40c_row1_col8" class="data row1 col8" >84.00</td>
#       <td id="T_4a40c_row1_col9" class="data row1 col9" >123.00</td>
#       <td id="T_4a40c_row1_col10" class="data row1 col10" >1,687.00</td>
#       <td id="T_4a40c_row1_col11" class="data row1 col11" >1.00</td>
#       <td id="T_4a40c_row1_col12" class="data row1 col12" >0.00</td>
#       <td id="T_4a40c_row1_col13" class="data row1 col13" >80.00</td>
#       <td id="T_4a40c_row1_col14" class="data row1 col14" >0.76</td>
#       <td id="T_4a40c_row1_col15" class="data row1 col15" >0.38</td>
#       <td id="T_4a40c_row1_col16" class="data row1 col16" >0.21</td>
#       <td id="T_4a40c_row1_col17" class="data row1 col17" >0.00</td>
#       <td id="T_4a40c_row1_col18" class="data row1 col18" >0.60</td>
#       <td id="T_4a40c_row1_col19" class="data row1 col19" >0.97</td>
#       <td id="T_4a40c_row1_col20" class="data row1 col20" >1.00</td>
#       <td id="T_4a40c_row1_col21" class="data row1 col21" >2.03</td>
#       <td id="T_4a40c_row1_col22" class="data row1 col22" >0.78</td>
#       <td id="T_4a40c_row1_col23" class="data row1 col23" >1.46</td>
#       <td id="T_4a40c_row1_col24" class="data row1 col24" >0.79</td>
#       <td id="T_4a40c_row1_col25" class="data row1 col25" >-0.18</td>
#       <td id="T_4a40c_row1_col26" class="data row1 col26" >0.30</td>
#       <td id="T_4a40c_row1_col27" class="data row1 col27" >1.00</td>
#       <td id="T_4a40c_row1_col28" class="data row1 col28" >0.00</td>
#       <td id="T_4a40c_row1_col29" class="data row1

# %%
orig.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1941 entries, 0 to 1940
# Columns: 34 entries, X_Minimum to Other_Faults
# dtypes: float64(13), int64(21)
# memory usage: 515.7 KB

# %%
train.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19219 entries, 0 to 19218
# Columns: 34 entries, X_Minimum to Other_Faults
# dtypes: float64(13), int64(21)
# memory usage: 5.1 MB

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
# ">
#     <b><span style="color: #780D0D;">&#x25FC</span> Available Features</b>
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
#     text-align: justify;
#     text-justify: inter-word;
# ">
#     There are 27 available features, whereas all are numerical, so categorical analysis and encoding are probably out unless some integerized variables are categorical indeed. As for the target, we deal with seven binary features. <b>Let's look at whether it's a multi-class or multi-label competition because it's not clear here, I think.</b>
# </p>

# %%
targets = ["Pastry", "Z_Scratch", "K_Scatch", "Stains", "Dirtiness", "Bumps", "Other_Faults"]

orig_met = np.all(orig[targets].sum(axis=1) == 1)
train_met = np.all(train[targets].sum(axis=1) == 1)

print("Original - All Target Categories Independend:", orig_met)
print("Train - All Target Categories Independend:", train_met)
# Out:
# Original - All Target Categories Independend: True
# Train - All Target Categories Independend: False

# %%
train[targets].sum(axis=1).unique()
# Out:
# array([1, 0, 2], dtype=int64)

# %%
train[targets].sum(axis=1).value_counts(normalize=True)
# Out:
# 1    0.956345
# 0    0.042562
# 2    0.001093
# Name: proportion, dtype: float64

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
# ">
#     <b><span style="color: #780D0D;">&#x25FC</span> It's Rather Multiclass</b>
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
#     text-align: justify;
#     text-justify: inter-word;
# ">
#     In the original dataset, all target categories are independent; there is no observation where two or more labels are present. On the other hand, in the training data, this statement is truthful in about 96% of the cases. There is a small amount of samples with two labels at the same time and 4% of samples with no category. <b>We can bring this problem to the multiclass by rejecting these 21 samples with two labels and introducing a new category like</b> <code>No_Fault</code>. In these playground competitions, training and test datasets come almost always from the same distribution, so this assumption should be valid.
# </p>

# %%
# Bring this to the multiclass problem.
train = train[train[targets].sum(axis=1) != 2]

# %%
# Encode 7 + 1 categories as one target.
train_conditions = [
    train.Pastry == 1,
    train.Z_Scratch == 1,
    train.K_Scatch == 1,
    train.Stains == 1,
    train.Dirtiness == 1,
    train.Bumps == 1,
    train.Other_Faults == 1,
]
orig_conditions = [
    orig.Pastry == 1,
    orig.Z_Scratch == 1,
    orig.K_Scatch == 1,
    orig.Stains == 1,
    orig.Dirtiness == 1,
    orig.Bumps == 1,
    orig.Other_Faults == 1,
]

train["Category"] = np.select(train_conditions, targets, default="No_Fault")
orig["Category"] = np.select(orig_conditions, targets, default="No_Fault")

train = train.drop(columns=targets)
orig = orig.drop(columns=targets)

# %% [markdown]
# ## <b> <span style="font-family: 'JetBrains Mono'; color: #4A4B52">1.2</span> <span style='color: #780D0D'>|</span> <span style="font-family: 'JetBrains Mono'; color: #4A4B52">Basic Numerical Properties &amp; Summaries</span></b><a class="anchor" id="basic_numerical_properties_summaries"></a> [↑](#top)

# %% [markdown]
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
#     text-align: justify;
#     text-justify: inter-word;
# ">
#     Now, the problem is a multiclass one. <b>Let's have a look at target distribution.</b>
# </p>

# %%
warnings.filterwarnings("ignore")

train_extended = pd.concat(
    (train.assign(Source="Train"), orig.assign(Source="Original")),
    ignore_index=True,
)
train_extended = train_extended.sample(frac=1.0, random_state=0)

fig = px.histogram(
    train_extended,
    y="Category",
    histnorm="percent",
    color="Source",
    color_discrete_sequence=COLOR_SCHEME,
    width=820,
    height=480,
    barmode="group",
    text_auto="0.2f",  # type: ignore
    orientation="h",
    title="Distribution of Category (Target Variable) in Training & Original Datasets<br>"
    "<span style='font-size: 75%; font-weight: bold;'>"
    "There is imbalance in categories and 'No_Fault' class is not "
    "present in the original dataset</span>",
)
fig.update_yaxes(title="Category", categoryorder="total ascending")
fig.update_xaxes(title="Percent Count", range=(-1, 50))
fig.update_traces(textposition="outside")
fig.update_layout(bargap=0.2, bargroupgap=0.15, legend=dict(y=0.92, x=1.0, title=""))
save_and_show_fig(fig, "status_distribution")

# %%
print(CLR + "Original Dataset - General Summary:")
orig_summary = frame_summary(orig)
get_pretty_frame(orig_summary, gradient=True)
# Out:
# Original Dataset - General Summary:
# <style type="text/css">
# #T_5c148 .index_name {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_5c148 th:not(.index_name) {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_5c148 td {
#   color: #4A4B52;
#   font-weight: bold;
# }
# #T_5c148_row0_col1, #T_5c148_row0_col2, #T_5c148_row1_col1, #T_5c148_row1_col2, #T_5c148_row2_col1, #T_5c148_row2_col2, #T_5c148_row2_col6, #T_5c148_row2_col7, #T_5c148_row3_col1, #T_5c148_row3_col2, #T_5c148_row3_col6, #T_5c148_row3_col7, #T_5c148_row4_col1, #T_5c148_row4_col2, #T_5c148_row5_col1, #T_5c148_row5_col2, #T_5c148_row6_col1, #T_5c148_row6_col2, #T_5c148_row7_col1, #T_5c148_row7_col2, #T_5c148_row7_col6, #T_5c148_row7_col7, #T_5c148_row8_col1, #T_5c148_row8_col2, #T_5c148_row9_col1, #T_5c148_row9_col2, #T_5c148_row10_col1, #T_5c148_row10_col2, #T_5c148_row11_col1, #T_5c148_row11_col2, #T_5c148_row11_col3, #T_5c148_row11_col4, #T_5c148_row12_col1, #T_5c148_row12_col2, #T_5c148_row12_col3, #T_5c148_row12_col4, #T_5c148_row13_col1, #T_5c148_row13_col2, #T_5c148_row14_col1, #T_5c148_row14_col2, #T_5c148_row15_col1, #T_5c148_row15_col2, #T_5c148_row16_col1, #T_5c148_row16_col2, #T_5c148_row17_col1, #T_5c148_row17_col2, #T_5c148_row18_col1, #T_5c148_row18_col2, #T_5c148_row19_col1, #T_5c148_row19_col2, #T_5c148_row20_col1, #T_5c148_row20_col2, #T_5c148_row20_col3, #T_5c148_row20_col4, #T_5c148_row21_col1, #T_5c148_row21_col2, #T_5c148_row22_col1, #T_5c148_row22_col2, #T_5c148_row23_col1, #T_5c148_row23_col2, #T_5c148_row24_col1, #T_5c148_row24_col2, #T_5c148_row25_col1, #T_5c148_row25_col2, #T_5c148_row25_col6, #T_5c148_row25_col7, #T_5c148_row26_col1, #T_5c148_row26_col2, #T_5c148_row27_col1, #T_5c148_row27_col2, #T_5c148_row27_col3, #T_5c148_row27_col4 {
#   background-color: #f1f1f1;
#   color: #000000;
# }
# #T_5c148_row0_col3, #T_5c148_row0_col4 {
#   background-color: #d6d5d5;
#   color: #000000;
# }
# #T_5c148_row0_col6, #T_5c148_row0_col7 {
#   background-color: #ebebeb;
#   color: #000000;
# }
# #T_5c148_row1_col3, #T_5c148_row1_col4 {
#   background-color: #d5d4d3;
#   color: #000000;
# }
# #T_5c148_row1_col6, #T_5c148_row1_col7, #T_5c148_row4_col6, #T_5c148_row4_col7, #T_5c148_row13_col3, #T_5c148_row13_col4, #T_5c148_row21_col6, #T_5c148_row21_col7 {
#   background-color: #f0f0f0;
#   color: #000000;
# }
# #T_5c148_row2_col3, #T_5c148_row2_col4, #T_5c148_row3_col3, #T_5c148_row3_col4, #T_5c148_row11_col6, #T_5c148_row11_col7, #T_5c148_row12_col6, #T_5c148_row12_col7 {
#   background-color: #bab8b8;
#   color: #000000;
# }
# #T_5c148_row4_col3, #T_5c148_row4_col4, #T_5c148_row21_col3, #T_5c148_row21_col4, #T_5c148_row24_col3, #T_5c148_row24_col4 {
#   background-color: #d7d6d6;
#   color: #000000;
# }
# #T_5c148_row5_col3, #T_5c148_row5_col4, #T_5c148_row10_col6, #T_5c148_row10_col7 {
#   background-color: #e5e5e5;
#   color: #000000;
# }
# #T_5c148_row5_col6, #T_5c148_row5_col7, #T_5c148_row6_col6, #T_5c148_row6_col7, #T_5c148_row17_col6, #T_5c148_row17_col7 {
#   background-color: #ededed;
#   color: #000000;
# }
# #T_5c148_row6_col3, #T_5c148_row6_col4, #T_5c148_row9_col6, #T_5c148_row9_col7 {
#   background-color: #e8e7e7;
#   color: #000000;
# }
# #T_5c148_row7_col3, #T_5c148_row7_col4 {
#   background-color: #bbb9b9;
#   color: #000000;
# }
# #T_5c148_row8_col3, #T_5c148_row8_col4 {
#   background-color: #ececec;
#   color: #000000;
# }
# #T_5c148_row8_col6, #T_5c148_row8_col7, #T_5c148_row14_col6, #T_5c148_row14_col7 {
#   background-color: #efefef;
#   color: #000000;
# }
# #T_5c148_row9_col3, #T_5c148_row9_col4, #T_5c148_row10_col3, #T_5c148_row10_col4 {
#   background-color: #eeeeee;
#   color: #000000;
# }
# #T_5c148_row13_col6, #T_5c148_row13_col7 {
#   background-color: #cfcece;
#   color: #000000;
# }
# #T_5c148_row14_col3, #T_5c148_row14_col4 {
#   background-color: #cac8c8;
#   color: #000000;
# }
# #T_5c148_row15_col3, #T_5c148_row15_col4 {
#   background-color: #cbcaca;
#   color: #000000;
# }
# #T_5c148_row15_col6, #T_5c148_row15_col7 {
#   background-color: #f0efef;
#   color: #000000;
# }
# #T_5c148_row16_col3, #T_5c148_row16_col4, #T_5c148_row26_col6, #T_5c148_row26_col7 {
#   background-color: #dbdada;
#   color: #000000;
# }
# #T_5c148_row16_col6, #T_5c148_row16_col7, #T_5c148_row23_col6, #T_5c148_row23_col7, #T_5c148_row24_col6, #T_5c148_row24_col7 {
#   background-color: #edecec;
#   color: #000000;
# }
# #T_5c148_row17_col3, #T_5c148_row17_col4 {
#   background-color: #e4e3e3;
#   color: #000000;
# }
# #T_5c148_row18_col3, #T_5c148_row18_col4 {
#   background-color: #dad9d9;
#   color: #000000;
# }
# #T_5c148_row18_col6, #T_5c148_row18_col7, #T_5c148_row22_col6, #T_5c148_row22_col7 {
#   background-color: #eaeaea;
#   color: #000000;
# }
# #T_5c148_row19_col3, #T_5c148_row19_col4 {
#   background-color: #dedede;
#   color: #000000;
# }
# #T_5c148_row19_col6, #T_5c148_row19_col7 {
#   background-color: #cac9c9;
#   color: #000000;
# }
# #T_5c148_row20_col6, #T_5c148_row20_col7 {
#   background-color: #bebcbc;
#   color: #000000;
# }
# #T_5c148_row22_col3, #T_5c148_row22_col4 {
#   background-color: #ecebeb;
#   color: #000000;
# }
# #T_5c148_row23_col3, #T_5c148_row23_col4 {
#   background-color: #ebeaea;
#   color: #000000;
# }
# #T_5c148_row25_col3, #T_5c148_row25_col4 {
#   background-color: #c6c4c4;
#   color: #000000;
# }
# #T_5c148_row26_col3, #T_5c148_row26_col4 {
#   background-color: #e6e5e5;
#   color: #000000;
# }
# #T_5c148_row27_col6, #T_5c148_row27_col7 {
#   background-color: #d1d0d0;
#   color: #000000;
# }
# </style>
# <table id="T_5c148">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5c148_level0_col0" class="col_heading level0 col0" >dtype</th>
#       <th id="T_5c148_level0_col1" class="col_heading level0 col1" >n_null</th>
#       <th id="T_5c148_level0_col2" class="col_heading level0 col2" >n_null_percent</th>
#       <th id="T_5c148_level0_col3" class="col_heading level0 col3" >n_unique</th>
#       <th id="T_5c148_level0_col4" class="col_heading level0 col4" >n_unique_percent</th>
#       <th id="T_5c148_level0_col5" class="col_heading level0 col5" >mode</th>
#       <th id="T_5c148_level0_col6" class="col_heading level0 col6" >mode_count</th>
#       <th id="T_5c148_level0_col7" class="col_heading level0 col7" >mode_percent_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c148_level0_row0" class="row_heading level0 row0" >X_Minimum</th>
#       <td id="T_5c148_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_5c148_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_5c148_row0_col2" class="data row0 col2" >0.000</td>
#       <td id="T_5c148_row0_col3" class="data row0 col3" >962</td>
#       <td id="T_5c148_row0_col4" class="data row0 col4" >49.562</td>
#       <td id="T_5c148_row0_col5" class="data row0 col5" >41.000</td>
#       <td id="T_5c148_row0_col6" class="data row0 col6" >126</td>
#       <td id="T_5c148_row0_col7" class="data row0 col7" >6.491</td>
#     </tr>
#     <tr>
#       <th id="T_5c148_level0_row1" class="row_heading level0 row1" >X_Maximum</th>
#       <td id="T_5c148_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_5c148_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_5c148_row1_col2" class="data row1 col2" >0.000</td>
#       <td id="T_5c148_row1_col3" class="data row1 col3" >994</td>
#       <td id="T_5c148_row1_col4" class="data row1 col4" >51.211</td>
#       <td id="T_5c148_row1_col5" class="data row1 col5" >212.000</td>
#       <td id="T_5c148_row1_col6" class="data row1 col6" >23</td>
#       <td id="T_5c148_row1_col7" class="data row1 col7" >1.185</td>
#     </tr>
#     <tr>
#       <th id="T_5c148_level0_row2" class="row_heading level0 row2" >Y_Minimum</th>
#       <td id="T_5c148_row2_col0" class="data row2 col0" >int64</td>
#       <td id="T_5c148_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_5c148_row2_col2" class="data row2 col2" >0.000</td>
#       <td id="T_5c148_row2_col3" class="data row2 col3" >1939</td>
#       <td id="T_5c148_row2_col4" class="data row2 col4" >99.897</td>
#       <td id="T_5c148_row2_col5" class="data row2 col5" >28972.000</td>
#       <td id="T_5c148_row2_col6" class="data row2 col6" >2</td>
#       <td id="T_5c148_row2_col7" class="data row2 col7" >0.103</

# %%
print(CLR + "Training Dataset - General Summary:")
train_summary = frame_summary(train)
get_pretty_frame(train_summary, gradient=True)
# Out:
# Training Dataset - General Summary:
# <style type="text/css">
# #T_8a22d .index_name {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_8a22d th:not(.index_name) {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_8a22d td {
#   color: #4A4B52;
#   font-weight: bold;
# }
# #T_8a22d_row0_col1, #T_8a22d_row0_col2, #T_8a22d_row1_col1, #T_8a22d_row1_col2, #T_8a22d_row2_col1, #T_8a22d_row2_col2, #T_8a22d_row2_col6, #T_8a22d_row2_col7, #T_8a22d_row3_col1, #T_8a22d_row3_col2, #T_8a22d_row3_col6, #T_8a22d_row3_col7, #T_8a22d_row4_col1, #T_8a22d_row4_col2, #T_8a22d_row5_col1, #T_8a22d_row5_col2, #T_8a22d_row6_col1, #T_8a22d_row6_col2, #T_8a22d_row7_col1, #T_8a22d_row7_col2, #T_8a22d_row7_col6, #T_8a22d_row7_col7, #T_8a22d_row8_col1, #T_8a22d_row8_col2, #T_8a22d_row9_col1, #T_8a22d_row9_col2, #T_8a22d_row10_col1, #T_8a22d_row10_col2, #T_8a22d_row11_col1, #T_8a22d_row11_col2, #T_8a22d_row11_col3, #T_8a22d_row11_col4, #T_8a22d_row12_col1, #T_8a22d_row12_col2, #T_8a22d_row12_col3, #T_8a22d_row12_col4, #T_8a22d_row13_col1, #T_8a22d_row13_col2, #T_8a22d_row14_col1, #T_8a22d_row14_col2, #T_8a22d_row15_col1, #T_8a22d_row15_col2, #T_8a22d_row16_col1, #T_8a22d_row16_col2, #T_8a22d_row17_col1, #T_8a22d_row17_col2, #T_8a22d_row18_col1, #T_8a22d_row18_col2, #T_8a22d_row19_col1, #T_8a22d_row19_col2, #T_8a22d_row20_col1, #T_8a22d_row20_col2, #T_8a22d_row20_col3, #T_8a22d_row20_col4, #T_8a22d_row21_col1, #T_8a22d_row21_col2, #T_8a22d_row22_col1, #T_8a22d_row22_col2, #T_8a22d_row23_col1, #T_8a22d_row23_col2, #T_8a22d_row24_col1, #T_8a22d_row24_col2, #T_8a22d_row25_col1, #T_8a22d_row25_col2, #T_8a22d_row26_col1, #T_8a22d_row26_col2, #T_8a22d_row27_col1, #T_8a22d_row27_col2, #T_8a22d_row27_col3, #T_8a22d_row27_col4 {
#   background-color: #f1f1f1;
#   color: #000000;
# }
# #T_8a22d_row0_col3, #T_8a22d_row0_col4 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_8a22d_row0_col6, #T_8a22d_row0_col7, #T_8a22d_row5_col3, #T_8a22d_row5_col4, #T_8a22d_row26_col3, #T_8a22d_row26_col4 {
#   background-color: #e9e9e9;
#   color: #000000;
# }
# #T_8a22d_row1_col3, #T_8a22d_row1_col4 {
#   background-color: #dcdbdb;
#   color: #000000;
# }
# #T_8a22d_row1_col6, #T_8a22d_row1_col7, #T_8a22d_row9_col3, #T_8a22d_row9_col4, #T_8a22d_row10_col3, #T_8a22d_row10_col4 {
#   background-color: #efefef;
#   color: #000000;
# }
# #T_8a22d_row2_col3, #T_8a22d_row2_col4, #T_8a22d_row3_col3, #T_8a22d_row3_col4, #T_8a22d_row11_col6, #T_8a22d_row11_col7, #T_8a22d_row12_col6, #T_8a22d_row12_col7 {
#   background-color: #bab8b8;
#   color: #000000;
# }
# #T_8a22d_row4_col3, #T_8a22d_row4_col4, #T_8a22d_row26_col6, #T_8a22d_row26_col7 {
#   background-color: #dedddd;
#   color: #000000;
# }
# #T_8a22d_row4_col6, #T_8a22d_row4_col7, #T_8a22d_row13_col3, #T_8a22d_row13_col4, #T_8a22d_row21_col6, #T_8a22d_row21_col7, #T_8a22d_row25_col6, #T_8a22d_row25_col7 {
#   background-color: #f0f0f0;
#   color: #000000;
# }
# #T_8a22d_row5_col6, #T_8a22d_row5_col7, #T_8a22d_row6_col6, #T_8a22d_row6_col7, #T_8a22d_row14_col6, #T_8a22d_row14_col7, #T_8a22d_row16_col6, #T_8a22d_row16_col7, #T_8a22d_row22_col3, #T_8a22d_row22_col4, #T_8a22d_row23_col3, #T_8a22d_row23_col4, #T_8a22d_row24_col6, #T_8a22d_row24_col7 {
#   background-color: #ededed;
#   color: #000000;
# }
# #T_8a22d_row6_col3, #T_8a22d_row6_col4 {
#   background-color: #ebebeb;
#   color: #000000;
# }
# #T_8a22d_row7_col3, #T_8a22d_row7_col4 {
#   background-color: #c6c5c5;
#   color: #000000;
# }
# #T_8a22d_row8_col3, #T_8a22d_row8_col4, #T_8a22d_row8_col6, #T_8a22d_row8_col7 {
#   background-color: #eeeeee;
#   color: #000000;
# }
# #T_8a22d_row9_col6, #T_8a22d_row9_col7 {
#   background-color: #e5e5e5;
#   color: #000000;
# }
# #T_8a22d_row10_col6, #T_8a22d_row10_col7 {
#   background-color: #e3e3e3;
#   color: #000000;
# }
# #T_8a22d_row13_col6, #T_8a22d_row13_col7 {
#   background-color: #cccbcb;
#   color: #000000;
# }
# #T_8a22d_row14_col3, #T_8a22d_row14_col4 {
#   background-color: #d2d1d1;
#   color: #000000;
# }
# #T_8a22d_row15_col3, #T_8a22d_row15_col4 {
#   background-color: #d4d3d3;
#   color: #000000;
# }
# #T_8a22d_row15_col6, #T_8a22d_row15_col7 {
#   background-color: #f0efef;
#   color: #000000;
# }
# #T_8a22d_row16_col3, #T_8a22d_row16_col4 {
#   background-color: #dedede;
#   color: #000000;
# }
# #T_8a22d_row17_col3, #T_8a22d_row17_col4 {
#   background-color: #e8e8e8;
#   color: #000000;
# }
# #T_8a22d_row17_col6, #T_8a22d_row17_col7 {
#   background-color: #edecec;
#   color: #000000;
# }
# #T_8a22d_row18_col3, #T_8a22d_row18_col4 {
#   background-color: #dfdede;
#   color: #000000;
# }
# #T_8a22d_row18_col6, #T_8a22d_row18_col7, #T_8a22d_row23_col6, #T_8a22d_row23_col7 {
#   background-color: #ececec;
#   color: #000000;
# }
# #T_8a22d_row19_col3, #T_8a22d_row19_col4 {
#   background-color: #e2e1e1;
#   color: #000000;
# }
# #T_8a22d_row19_col6, #T_8a22d_row19_col7 {
#   background-color: #c7c6c6;
#   color: #000000;
# }
# #T_8a22d_row20_col6, #T_8a22d_row20_col7 {
#   background-color: #bcbaba;
#   color: #000000;
# }
# #T_8a22d_row21_col3, #T_8a22d_row21_col4 {
#   background-color: #dfdfdf;
#   color: #000000;
# }
# #T_8a22d_row22_col6, #T_8a22d_row22_col7 {
#   background-color: #eae9e9;
#   color: #000000;
# }
# #T_8a22d_row24_col3, #T_8a22d_row24_col4 {
#   background-color: #d6d6d5;
#   color: #000000;
# }
# #T_8a22d_row25_col3, #T_8a22d_row25_col4 {
#   background-color: #cfcece;
#   color: #000000;
# }
# #T_8a22d_row27_col6, #T_8a22d_row27_col7 {
#   background-color: #d2d0d0;
#   color: #000000;
# }
# </style>
# <table id="T_8a22d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a22d_level0_col0" class="col_heading level0 col0" >dtype</th>
#       <th id="T_8a22d_level0_col1" class="col_heading level0 col1" >n_null</th>
#       <th id="T_8a22d_level0_col2" class="col_heading level0 col2" >n_null_percent</th>
#       <th id="T_8a22d_level0_col3" class="col_heading level0 col3" >n_unique</th>
#       <th id="T_8a22d_level0_col4" class="col_heading level0 col4" >n_unique_percent</th>
#       <th id="T_8a22d_level0_col5" class="col_heading level0 col5" >mode</th>
#       <th id="T_8a22d_level0_col6" class="col_heading level0 col6" >mode_count</th>
#       <th id="T_8a22d_level0_col7" class="col_heading level0 col7" >mode_percent_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a22d_level0_row0" class="row_heading level0 row0" >X_Minimum</th>
#       <td id="T_8a22d_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_8a22d_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_8a22d_row0_col2" class="data row0 col2" >0.000</td>
#       <td id="T_8a22d_row0_col3" class="data row0 col3" >1190</td>
#       <td id="T_8a22d_row0_col4" class="data row0 col4" >6.199</td>
#       <td id="T_8a22d_row0_col5" class="data row0 col5" >39</td>
#       <td id="T_8a22d_row0_col6" class="data row0 col6" >1593</td>
#       <td id="T_8a22d_row0_col7" class="data row0 col7" >8.298</td>
#     </tr>
#     <tr>
#       <th id="T_8a22d_level0_row1" class="row_heading level0 row1" >X_Maximum</th>
#       <td id="T_8a22d_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_8a22d_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_8a22d_row1_col2" class="data row1 col2" >0.000</td>
#       <td id="T_8a22d_row1_col3" class="data row1 col3" >1259</td>
#       <td id="T_8a22d_row1_col4" class="data row1 col4" >6.558</td>
#       <td id="T_8a22d_row1_col5" class="data row1 col5" >214</td>
#       <td id="T_8a22d_row1_col6" class="data row1 col6" >376</td>
#       <td id="T_8a22d_row1_col7" class="data row1 col7" >1.959</td>
#     </tr>
#     <tr>
#       <th id="T_8a22d_level0_row2" class="row_heading level0 row2" >Y_Minimum</th>
#       <td id="T_8a22d_row2_col0" class="data row2 col0" >int64</td>
#       <td id="T_8a22d_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_8a22d_row2_col2" class="data row2 col2" >0.000</td>
#       <td id="T_8a22d_row2_col3" class="data row2 col3" >3340</td>
#       <td id="T_8a22d_row2_col4" class="data row2 col4" >17.398</td>
#       <td id="T_8a22d_row2_col5" class="data row2 col5" >1740121</td>
#       <td id="T_8a22d_row2_col6" class="data row2 col6" >53</td>
#       <td id="T_8a22d_row2_col7" class="data row2 col7" >0.276</td>

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
# ">
#     <b><span style="color: #780D0D;">&#x25FC</span> Missing &amp; Unique &amp; Most Frequent Values</b>
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
#     text-align: justify;
#     text-justify: inter-word;
# ">
#     <b>There is no missing values, so we don't need to bother about imputation and this makes the task a more pleasant.</b> There is a low diversity of values in train & test (as usual when datasets are generated artificially) and these datasets almost overlap (so I show only the training dataset). Here we also see there are 3 features that are categorical. These are: <code>TypeOfSteel_A300</code>, <code>TypeOfSteel_A400</code>, and <code>Outside_Global_Index</code>. <b>The original dataset is much more diverse.</b> See that values of <code>Y_Minimum</code>, <code>Y_Maximum</code>, and <code>Sum_of_Luminosity</code> are almost always unique for each sample, which is completely disrupted in train & test.
# </p>

# %%
cat_features = ["TypeOfSteel_A300", "TypeOfSteel_A400", "Outside_Global_Index"]

orig[cat_features] = orig[cat_features].astype("category")
train[cat_features] = train[cat_features].astype("category")
test[cat_features] = test[cat_features].astype("category")
train_extended[cat_features] = train_extended[cat_features].astype("category")

num_features = test.select_dtypes(include="number").columns.to_list()

# %%
print(CLR + "Original Dataset - Numerical Summary:")
orig_num_descr = numeric_descr(orig)
get_pretty_frame(orig_num_descr, gradient=True, formatter="{:,.2f}")
# Out:
# Original Dataset - Numerical Summary:
# <style type="text/css">
# #T_6cb36 .index_name {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_6cb36 th:not(.index_name) {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_6cb36 td {
#   color: #4A4B52;
#   font-weight: bold;
# }
# #T_6cb36_row0_col0, #T_6cb36_row0_col1, #T_6cb36_row0_col2, #T_6cb36_row0_col3, #T_6cb36_row0_col4, #T_6cb36_row0_col5, #T_6cb36_row0_col6, #T_6cb36_row0_col7, #T_6cb36_row0_col8, #T_6cb36_row0_col9, #T_6cb36_row0_col10, #T_6cb36_row1_col0, #T_6cb36_row1_col1, #T_6cb36_row1_col2, #T_6cb36_row1_col3, #T_6cb36_row1_col4, #T_6cb36_row1_col5, #T_6cb36_row1_col6, #T_6cb36_row1_col7, #T_6cb36_row1_col8, #T_6cb36_row1_col9, #T_6cb36_row1_col10, #T_6cb36_row4_col0, #T_6cb36_row4_col1, #T_6cb36_row4_col2, #T_6cb36_row4_col3, #T_6cb36_row4_col4, #T_6cb36_row4_col5, #T_6cb36_row4_col6, #T_6cb36_row4_col7, #T_6cb36_row4_col8, #T_6cb36_row4_col9, #T_6cb36_row5_col0, #T_6cb36_row5_col1, #T_6cb36_row5_col2, #T_6cb36_row5_col3, #T_6cb36_row5_col4, #T_6cb36_row5_col5, #T_6cb36_row5_col6, #T_6cb36_row5_col7, #T_6cb36_row5_col8, #T_6cb36_row5_col9, #T_6cb36_row5_col10, #T_6cb36_row6_col0, #T_6cb36_row6_col1, #T_6cb36_row6_col2, #T_6cb36_row6_col3, #T_6cb36_row6_col4, #T_6cb36_row6_col5, #T_6cb36_row6_col6, #T_6cb36_row6_col7, #T_6cb36_row6_col8, #T_6cb36_row6_col9, #T_6cb36_row6_col10, #T_6cb36_row8_col0, #T_6cb36_row8_col1, #T_6cb36_row8_col2, #T_6cb36_row8_col3, #T_6cb36_row8_col4, #T_6cb36_row8_col5, #T_6cb36_row8_col6, #T_6cb36_row8_col7, #T_6cb36_row8_col8, #T_6cb36_row8_col9, #T_6cb36_row8_col10, #T_6cb36_row9_col0, #T_6cb36_row9_col1, #T_6cb36_row9_col3, #T_6cb36_row9_col4, #T_6cb36_row9_col5, #T_6cb36_row9_col6, #T_6cb36_row9_col7, #T_6cb36_row9_col8, #T_6cb36_row9_col9, #T_6cb36_row9_col10, #T_6cb36_row10_col0, #T_6cb36_row10_col1, #T_6cb36_row10_col5, #T_6cb36_row10_col6, #T_6cb36_row10_col7, #T_6cb36_row10_col8, #T_6cb36_row10_col9, #T_6cb36_row10_col10, #T_6cb36_row11_col0, #T_6cb36_row11_col1, #T_6cb36_row11_col3, #T_6cb36_row11_col4, #T_6cb36_row11_col5, #T_6cb36_row11_col6, #T_6cb36_row11_col7, #T_6cb36_row11_col8, #T_6cb36_row11_col9, #T_6cb36_row11_col10, #T_6cb36_row12_col0, #T_6cb36_row12_col1, #T_6cb36_row12_col2, #T_6cb36_row12_col3, #T_6cb36_row12_col4, #T_6cb36_row12_col5, #T_6cb36_row12_col6, #T_6cb36_row12_col7, #T_6cb36_row12_col8, #T_6cb36_row12_col9, #T_6cb36_row12_col10, #T_6cb36_row13_col0, #T_6cb36_row13_col1, #T_6cb36_row13_col2, #T_6cb36_row13_col3, #T_6cb36_row13_col4, #T_6cb36_row13_col5, #T_6cb36_row13_col6, #T_6cb36_row13_col7, #T_6cb36_row13_col8, #T_6cb36_row13_col9, #T_6cb36_row13_col10, #T_6cb36_row14_col0, #T_6cb36_row14_col1, #T_6cb36_row14_col2, #T_6cb36_row14_col3, #T_6cb36_row14_col4, #T_6cb36_row14_col5, #T_6cb36_row14_col6, #T_6cb36_row14_col7, #T_6cb36_row14_col8, #T_6cb36_row14_col9, #T_6cb36_row14_col10, #T_6cb36_row15_col0, #T_6cb36_row15_col1, #T_6cb36_row15_col2, #T_6cb36_row15_col3, #T_6cb36_row15_col4, #T_6cb36_row15_col5, #T_6cb36_row15_col6, #T_6cb36_row15_col7, #T_6cb36_row15_col8, #T_6cb36_row15_col9, #T_6cb36_row15_col10, #T_6cb36_row16_col0, #T_6cb36_row16_col1, #T_6cb36_row16_col2, #T_6cb36_row16_col3, #T_6cb36_row16_col4, #T_6cb36_row16_col5, #T_6cb36_row16_col6, #T_6cb36_row16_col7, #T_6cb36_row16_col8, #T_6cb36_row16_col9, #T_6cb36_row16_col10, #T_6cb36_row17_col0, #T_6cb36_row17_col1, #T_6cb36_row17_col2, #T_6cb36_row17_col3, #T_6cb36_row17_col4, #T_6cb36_row17_col5, #T_6cb36_row17_col6, #T_6cb36_row17_col7, #T_6cb36_row17_col8, #T_6cb36_row17_col9, #T_6cb36_row17_col10, #T_6cb36_row18_col0, #T_6cb36_row18_col1, #T_6cb36_row18_col2, #T_6cb36_row18_col3, #T_6cb36_row18_col4, #T_6cb36_row18_col5, #T_6cb36_row18_col6, #T_6cb36_row18_col7, #T_6cb36_row18_col8, #T_6cb36_row18_col9, #T_6cb36_row18_col10, #T_6cb36_row19_col0, #T_6cb36_row19_col1, #T_6cb36_row19_col2, #T_6cb36_row19_col3, #T_6cb36_row19_col4, #T_6cb36_row19_col5, #T_6cb36_row19_col6, #T_6cb36_row19_col7, #T_6cb36_row19_col8, #T_6cb36_row19_col9, #T_6cb36_row19_col10, #T_6cb36_row20_col0, #T_6cb36_row20_col1, #T_6cb36_row20_col2, #T_6cb36_row20_col3, #T_6cb36_row20_col4, #T_6cb36_row20_col5, #T_6cb36_row20_col6, #T_6cb36_row20_col7, #T_6cb36_row20_col8, #T_6cb36_row20_col9, #T_6cb36_row20_col10, #T_6cb36_row21_col0, #T_6c ...
#   background-color: #f1f1f1;
#   color: #000000;
# }
# #T_6cb36_row2_col0, #T_6cb36_row2_col1, #T_6cb36_row2_col2, #T_6cb36_row2_col3, #T_6cb36_row2_col4, #T_6cb36_row2_col5, #T_6cb36_row2_col6, #T_6cb36_row2_col7, #T_6cb36_row2_col8, #T_6cb36_row2_col9, #T_6cb36_row2_col10, #T_6cb36_row3_col0, #T_6cb36_row3_col1, #T_6cb36_row3_col2, #T_6cb36_row3_col3, #T_6cb36_row3_col4, #T_6cb36_row3_col5, #T_6cb36_row3_col6, #T_6cb36_row3_col7, #T_6cb36_row3_col8, #T_6cb36_row3_col9, #T_6cb36_row3_col10 {
#   background-color: #bab8b8;
#   color: #000000;
# }
# #T_6cb36_row4_col10, #T_6cb36_row7_col6, #T_6cb36_row9_col2, #T_6cb36_row10_col4, #T_6cb36_row11_col2 {
#   background-color: #f0f0f0;
#   color: #000000;
# }
# #T_6cb36_row7_col0 {
#   background-color: #eaeaea;
#   color: #000000;
# }
# #T_6cb36_row7_col1, #T_6cb36_row7_col8 {
#   background-color: #e1e0e0;
#   color: #000000;
# }
# #T_6cb36_row7_col2, #T_6cb36_row7_col7 {
#   background-color: #efefef;
#   color: #000000;
# }
# #T_6cb36_row7_col3, #T_6cb36_row7_col4, #T_6cb36_row10_col3 {
#   background-color: #eeeeee;
#   color: #000000;
# }
# #T_6cb36_row7_col5 {
#   background-color: #f0efef;
#   color: #000000;
# }
# #T_6cb36_row7_col9 {
#   background-color: #e5e5e5;
#   color: #000000;
# }
# #T_6cb36_row7_col10 {
#   background-color: #c0bebe;
#   color: #000000;
# }
# #T_6cb36_row10_col2 {
#   background-color: #e7e6e6;
#   color: #000000;
# }
# </style>
# <table id="T_6cb36">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6cb36_level0_col0" class="col_heading level0 col0" >Mean</th>
#       <th id="T_6cb36_level0_col1" class="col_heading level0 col1" >Std</th>
#       <th id="T_6cb36_level0_col2" class="col_heading level0 col2" >Min</th>
#       <th id="T_6cb36_level0_col3" class="col_heading level0 col3" >1%</th>
#       <th id="T_6cb36_level0_col4" class="col_heading level0 col4" >5%</th>
#       <th id="T_6cb36_level0_col5" class="col_heading level0 col5" >25%</th>
#       <th id="T_6cb36_level0_col6" class="col_heading level0 col6" >50%</th>
#       <th id="T_6cb36_level0_col7" class="col_heading level0 col7" >75%</th>
#       <th id="T_6cb36_level0_col8" class="col_heading level0 col8" >95%</th>
#       <th id="T_6cb36_level0_col9" class="col_heading level0 col9" >99%</th>
#       <th id="T_6cb36_level0_col10" class="col_heading level0 col10" >Max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6cb36_level0_row0" class="row_heading level0 row0" >X_Minimum</th>
#       <td id="T_6cb36_row0_col0" class="data row0 col0" >571.14</td>
#       <td id="T_6cb36_row0_col1" class="data row0 col1" >520.69</td>
#       <td id="T_6cb36_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_6cb36_row0_col3" class="data row0 col3" >0.00</td>
#       <td id="T_6cb36_row0_col4" class="data row0 col4" >14.00</td>
#       <td id="T_6cb36_row0_col5" class="data row0 col5" >51.00</td>
#       <td id="T_6cb36_row0_col6" class="data row0 col6" >435.00</td>
#       <td id="T_6cb36_row0_col7" class="data row0 col7" >1,053.00</td>
#       <td id="T_6cb36_row0_col8" class="data row0 col8" >1,538.00</td>
#       <td id="T_6cb36_row0_col9"

# %%
print(CLR + "Training Dataset - Numerical Summary:")
train_num_descr = numeric_descr(train)
get_pretty_frame(train_num_descr, gradient=True, formatter="{:,.2f}")
# Out:
# Training Dataset - Numerical Summary:
# <style type="text/css">
# #T_9b950 .index_name {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_9b950 th:not(.index_name) {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_9b950 td {
#   color: #4A4B52;
#   font-weight: bold;
# }
# #T_9b950_row0_col0, #T_9b950_row0_col1, #T_9b950_row0_col2, #T_9b950_row0_col3, #T_9b950_row0_col4, #T_9b950_row0_col5, #T_9b950_row0_col6, #T_9b950_row0_col7, #T_9b950_row0_col8, #T_9b950_row0_col9, #T_9b950_row0_col10, #T_9b950_row1_col0, #T_9b950_row1_col1, #T_9b950_row1_col2, #T_9b950_row1_col3, #T_9b950_row1_col4, #T_9b950_row1_col5, #T_9b950_row1_col6, #T_9b950_row1_col7, #T_9b950_row1_col8, #T_9b950_row1_col9, #T_9b950_row1_col10, #T_9b950_row4_col0, #T_9b950_row4_col1, #T_9b950_row4_col2, #T_9b950_row4_col3, #T_9b950_row4_col4, #T_9b950_row4_col5, #T_9b950_row4_col6, #T_9b950_row4_col7, #T_9b950_row4_col8, #T_9b950_row4_col9, #T_9b950_row5_col0, #T_9b950_row5_col1, #T_9b950_row5_col2, #T_9b950_row5_col3, #T_9b950_row5_col4, #T_9b950_row5_col5, #T_9b950_row5_col6, #T_9b950_row5_col7, #T_9b950_row5_col8, #T_9b950_row5_col9, #T_9b950_row5_col10, #T_9b950_row6_col0, #T_9b950_row6_col1, #T_9b950_row6_col2, #T_9b950_row6_col3, #T_9b950_row6_col4, #T_9b950_row6_col5, #T_9b950_row6_col6, #T_9b950_row6_col7, #T_9b950_row6_col8, #T_9b950_row6_col9, #T_9b950_row6_col10, #T_9b950_row8_col0, #T_9b950_row8_col1, #T_9b950_row8_col2, #T_9b950_row8_col3, #T_9b950_row8_col4, #T_9b950_row8_col5, #T_9b950_row8_col6, #T_9b950_row8_col7, #T_9b950_row8_col8, #T_9b950_row8_col9, #T_9b950_row8_col10, #T_9b950_row9_col0, #T_9b950_row9_col1, #T_9b950_row9_col3, #T_9b950_row9_col4, #T_9b950_row9_col5, #T_9b950_row9_col6, #T_9b950_row9_col7, #T_9b950_row9_col8, #T_9b950_row9_col9, #T_9b950_row9_col10, #T_9b950_row10_col0, #T_9b950_row10_col1, #T_9b950_row10_col5, #T_9b950_row10_col6, #T_9b950_row10_col7, #T_9b950_row10_col8, #T_9b950_row10_col9, #T_9b950_row10_col10, #T_9b950_row11_col0, #T_9b950_row11_col1, #T_9b950_row11_col3, #T_9b950_row11_col4, #T_9b950_row11_col5, #T_9b950_row11_col6, #T_9b950_row11_col7, #T_9b950_row11_col8, #T_9b950_row11_col9, #T_9b950_row11_col10, #T_9b950_row12_col0, #T_9b950_row12_col1, #T_9b950_row12_col2, #T_9b950_row12_col3, #T_9b950_row12_col4, #T_9b950_row12_col5, #T_9b950_row12_col6, #T_9b950_row12_col7, #T_9b950_row12_col8, #T_9b950_row12_col9, #T_9b950_row12_col10, #T_9b950_row13_col0, #T_9b950_row13_col1, #T_9b950_row13_col2, #T_9b950_row13_col3, #T_9b950_row13_col4, #T_9b950_row13_col5, #T_9b950_row13_col6, #T_9b950_row13_col7, #T_9b950_row13_col8, #T_9b950_row13_col9, #T_9b950_row13_col10, #T_9b950_row14_col0, #T_9b950_row14_col1, #T_9b950_row14_col2, #T_9b950_row14_col3, #T_9b950_row14_col4, #T_9b950_row14_col5, #T_9b950_row14_col6, #T_9b950_row14_col7, #T_9b950_row14_col8, #T_9b950_row14_col9, #T_9b950_row14_col10, #T_9b950_row15_col0, #T_9b950_row15_col1, #T_9b950_row15_col2, #T_9b950_row15_col3, #T_9b950_row15_col4, #T_9b950_row15_col5, #T_9b950_row15_col6, #T_9b950_row15_col7, #T_9b950_row15_col8, #T_9b950_row15_col9, #T_9b950_row15_col10, #T_9b950_row16_col0, #T_9b950_row16_col1, #T_9b950_row16_col2, #T_9b950_row16_col3, #T_9b950_row16_col4, #T_9b950_row16_col5, #T_9b950_row16_col6, #T_9b950_row16_col7, #T_9b950_row16_col8, #T_9b950_row16_col9, #T_9b950_row16_col10, #T_9b950_row17_col0, #T_9b950_row17_col1, #T_9b950_row17_col2, #T_9b950_row17_col3, #T_9b950_row17_col4, #T_9b950_row17_col5, #T_9b950_row17_col6, #T_9b950_row17_col7, #T_9b950_row17_col8, #T_9b950_row17_col9, #T_9b950_row17_col10, #T_9b950_row18_col0, #T_9b950_row18_col1, #T_9b950_row18_col2, #T_9b950_row18_col3, #T_9b950_row18_col4, #T_9b950_row18_col5, #T_9b950_row18_col6, #T_9b950_row18_col7, #T_9b950_row18_col8, #T_9b950_row18_col9, #T_9b950_row18_col10, #T_9b950_row19_col0, #T_9b950_row19_col1, #T_9b950_row19_col2, #T_9b950_row19_col3, #T_9b950_row19_col4, #T_9b950_row19_col5, #T_9b950_row19_col6, #T_9b950_row19_col7, #T_9b950_row19_col8, #T_9b950_row19_col9, #T_9b950_row19_col10, #T_9b950_row20_col0, #T_9b950_row20_col1, #T_9b950_row20_col2, #T_9b950_row20_col3, #T_9b950_row20_col4, #T_9b950_row20_col5, #T_9b950_row20_col6, #T_9b950_row20_col7, #T_9b950_row20_col8, #T_9b950_row20_col9, #T_9b950_row20_col10, #T_9b950_row21_col0, #T_9b ...
#   background-color: #f1f1f1;
#   color: #000000;
# }
# #T_9b950_row2_col0, #T_9b950_row2_col1, #T_9b950_row2_col2, #T_9b950_row2_col4, #T_9b950_row2_col5, #T_9b950_row2_col6, #T_9b950_row2_col7, #T_9b950_row2_col8, #T_9b950_row2_col9, #T_9b950_row2_col10, #T_9b950_row3_col0, #T_9b950_row3_col1, #T_9b950_row3_col2, #T_9b950_row3_col3, #T_9b950_row3_col4, #T_9b950_row3_col5, #T_9b950_row3_col6, #T_9b950_row3_col7, #T_9b950_row3_col8, #T_9b950_row3_col9, #T_9b950_row3_col10 {
#   background-color: #bab8b8;
#   color: #000000;
# }
# #T_9b950_row2_col3 {
#   background-color: #bbb9b9;
#   color: #000000;
# }
# #T_9b950_row4_col10, #T_9b950_row7_col5, #T_9b950_row7_col6, #T_9b950_row9_col2, #T_9b950_row10_col4, #T_9b950_row11_col2 {
#   background-color: #f0f0f0;
#   color: #000000;
# }
# #T_9b950_row7_col0 {
#   background-color: #ebebeb;
#   color: #000000;
# }
# #T_9b950_row7_col1 {
#   background-color: #e4e3e3;
#   color: #000000;
# }
# #T_9b950_row7_col2, #T_9b950_row7_col7 {
#   background-color: #efefef;
#   color: #000000;
# }
# #T_9b950_row7_col3 {
#   background-color: #ededed;
#   color: #000000;
# }
# #T_9b950_row7_col4, #T_9b950_row10_col3 {
#   background-color: #eeeeee;
#   color: #000000;
# }
# #T_9b950_row7_col8 {
#   background-color: #e5e4e4;
#   color: #000000;
# }
# #T_9b950_row7_col9, #T_9b950_row10_col2 {
#   background-color: #e7e6e6;
#   color: #000000;
# }
# #T_9b950_row7_col10 {
#   background-color: #c0bebe;
#   color: #000000;
# }
# </style>
# <table id="T_9b950">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9b950_level0_col0" class="col_heading level0 col0" >Mean</th>
#       <th id="T_9b950_level0_col1" class="col_heading level0 col1" >Std</th>
#       <th id="T_9b950_level0_col2" class="col_heading level0 col2" >Min</th>
#       <th id="T_9b950_level0_col3" class="col_heading level0 col3" >1%</th>
#       <th id="T_9b950_level0_col4" class="col_heading level0 col4" >5%</th>
#       <th id="T_9b950_level0_col5" class="col_heading level0 col5" >25%</th>
#       <th id="T_9b950_level0_col6" class="col_heading level0 col6" >50%</th>
#       <th id="T_9b950_level0_col7" class="col_heading level0 col7" >75%</th>
#       <th id="T_9b950_level0_col8" class="col_heading level0 col8" >95%</th>
#       <th id="T_9b950_level0_col9" class="col_heading level0 col9" >99%</th>
#       <th id="T_9b950_level0_col10" class="col_heading level0 col10" >Max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9b950_level0_row0" class="row_heading level0 row0" >X_Minimum</th>
#       <td id="T_9b950_row0_col0" class="data row0 col0" >710.50</td>
#       <td id="T_9b950_row0_col1" class="data row0 col1" >531.42</td>
#       <td id="T_9b950_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_9b950_row0_col3" class="data row0 col3" >0.00</td>
#       <td id="T_9b950_row0_col4" class="data row0 col4" >14.00</td>
#       <td id="T_9b950_row0_col5" class="data row0 col5" >50.00</td>
#       <td id="T_9b950_row0_col6" class="data row0 col6" >778.00</td>
#       <td id="T_9b950_row0_col7" class="data row0 col7" >1,152.00</td>
#       <td id="T_9b950_row0_col8" class="data row0 col

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
# ">
#     <b><span style="color: #780D0D;">&#x25FC</span> Numerical Summary</b>
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
#     text-align: justify;
#     text-justify: inter-word;
# ">
#     So, as we can see, the original dataset is slightly different when you ask for distributions, but the train and test subsets almost perfectly overlap (respective percentiles in both cases match) for all attributes. It is most probable that they come from the same distribution. Besides, some features contain outliers, but we will leave this problem for now. Further, I will show you how to check whether these can be removed using cross-validation.<br><br>
#     Now, let's test whether we can include original data into training using an <b>adversarial validation</b>. What is the adversarial validation? <b>Well, it's a very straightforward way to check whether our subsets are similar (sampled from the same or very similar distributions).</b> We label training and original datasets with, for example, $0$ and $1$. Then, we combine them into one dataset and shuffle them. Subsequently, we can perform binary classification and assess if we're able to identify which observation is from which dataset. When we get a ROC-AUC value of around $0.5$ (random guessing), they are indistinguishable, and this case is desired. On the other hand, when ROC-AUC $>0.5$, it probably means that training and test subsets are from different distributions.
# </p>

# %%
train_av = train.drop(columns="Category").assign(AV=0)
orig_av = orig.drop(columns="Category").assign(AV=1)

data_av = pd.concat((train_av, orig_av), ignore_index=True)
data_av = data_av.sample(frac=1.0, random_state=42)

X = data_av.drop("AV", axis=1)
y = data_av.AV

y_proba = cross_val_predict(
    estimator=make_pipeline(
        make_column_transformer(
            (
                StandardScaler(),
                make_column_selector(dtype_include="number"),  # type: ignore
            ),
        ),
        LogisticRegression(random_state=42, penalty="l2", solver="liblinear"),
    ),
    X=X,
    y=y,
    cv=StratifiedKFold(n_splits=5, shuffle=True, random_state=42),
    method="predict_proba",
)

av_scores = {
    "ConfusionMatrix": confusion_matrix(y, y_proba.argmax(axis=1)),
    "FPR-TPR-Threshold": roc_curve(y, y_proba[:, 1]),
    "ROC-AUC": roc_auc_score(y, y_proba[:, 1]),
}

# %%
fig = go.Figure()
fig.add_scatter(
    x=av_scores["FPR-TPR-Threshold"][0],
    y=av_scores["FPR-TPR-Threshold"][1],
    name="AV Result",
    mode="lines",
    line_color=COLOR_SCHEME[1],
)
fig.add_scatter(
    x=[0, 1],
    y=[0, 1],
    name="Random Guess",
    mode="lines",
    line=dict(dash="longdash", color=COLOR_SCHEME[0]),
)
fig.add_annotation(
    x=0.05,
    y=0.85,
    align="left",
    xanchor="left",
    text=f"<b>AV ROC-AUC: {av_scores['ROC-AUC']:.5f}<br>" "Conclusion? Well, let's conclude...",
    showarrow=False,
    font_size=14,
)
fig.update_yaxes(
    scaleanchor="x",
    scaleratio=1,
    range=(-0.01, 1.01),
    title="True Positive Rate (Recall)",
)
fig.update_xaxes(
    scaleanchor="y",
    scaleratio=1,
    range=(-0.01, 1.01),
    title="False Positive Rate (Fall-Out)",
)
fig.update_layout(
    title="Adversarial Validation Results<br>"
    "<span style='font-size: 75%; font-weight: bold;'>"
    "There is a slight ability to distinguish between training and original datasets</span>",
    width=540,
    legend=dict(y=0.1, x=1.0),
)
save_and_show_fig(fig, "adversarial_validation")

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
# ">
#     <b><span style="color: #780D0D;">&#x25FC</span> Adversarial Validation Results</b>
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
#     text-align: justify;
#     text-justify: inter-word;
# ">
#     The ROC-AUC score of $0.5$ typically indicates that the classifier cannot distinguish between the two distributions and suggests that the datasets come from the same distribution. <b>With a ROC-AUC score of $0.61$, it indicates a slight ability to distinguish between the training and original datasets, but the discrimination is not strong.</b> The score is higher than the baseline of $0.5$, suggesting some difference between the distributions, but it's not a strong signal.<b> On the other hand, the result should be as it is, as we read from competition description.</b> We're likely to include original samples in training, it usually helps in the playground. If you're asking for training and test datasets, the result is $0.5$.
# </p>

# %%
n_cols = 4
n_rows, axes = get_n_rows_and_axes(len(num_features), n_cols)

fig = make_subplots(
    rows=n_rows,
    cols=n_cols,
    y_title="Density",
).update_annotations(font_size=14)

for frame, color, group in zip((train, orig, test), COLOR_SCHEME, ("Train", "Original", "Test")):
    for k, (var, (row, col)) in enumerate(zip(num_features, axes), start=1):
        kde = get_kde_estimation(frame[var], percentile_range=(1, 99), space_extension_frac=0.03)
        fig.add_scatter(
            x=kde["space"],
            y=kde["vals"],
            line=dict(dash="solid", color=color, width=1.5),
            name=group,
            legendgroup=group,
            showlegend=k == 1,
            row=row,
            col=col,
        )
        fig.update_xaxes(title_text=f"<b>{var}</b>", row=row, col=col)

fig.update_layout(
    width=820,
    height=1140,
    title="Original & Training & Test Feature KDEs<br>"
    "<span style='font-size: 75%; font-weight: bold;'>"
    "Restricted to (1, 99) percentile range to avoid showing extreme outliers</span>",
)
save_and_show_fig(fig, "kdes")

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
# ">
#     <b><span style="color: #780D0D;">&#x25FC</span> Continuous Feature Distributions</b>
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
#     text-align: justify;
#     text-justify: inter-word;
# ">
#     Feature distributions show why Logistic Regression was able to slightly distinguish between training and original data. As we can see, these distributions are indeed, slightly different, but in the end, it shouldn't be a problem. Alternatively we may cross-validate that. Let's continue analysis with cross tables concerning training dataset.
# </p>

# %%
k_scatch_more_interesing_feats = [
    "Log_X_Index",
    "LogOfAreas",
    "X_Perimeter",
    "Pixels_Areas",
]

for feature in k_scatch_more_interesing_feats:
    cross = pd.crosstab(
        index=[pd.qcut(train[feature], q=5, duplicates="drop", precision=3)],
        columns=train.Category,
        normalize="index",
    )
    stylish_frame = get_pretty_frame(
        cross,
        gradient=True,
        formatter="{:.1%}",
        repr_html=True,
        index_width="170px",
        col_width="60px",
    )
    display_html(stylish_frame, raw=True)
# Out:
# <style type="text/css">
# #T_62729 .index_name {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_62729 th:not(.index_name) {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_62729 td {
#   color: #4A4B52;
#   font-weight: bold;
# }
# #T_62729 .index_name {
#   min-width: 170px;
# }
# #T_62729 th {
#   min-width: 60px;
# }
# #T_62729_row0_col0 {
#   background-color: #cccbcb;
#   color: #000000;
# }
# #T_62729_row0_col1, #T_62729_row0_col5, #T_62729_row0_col6, #T_62729_row1_col0, #T_62729_row3_col3, #T_62729_row3_col4, #T_62729_row3_col7, #T_62729_row4_col2 {
#   background-color: #bab8b8;
#   color: #000000;
# }
# #T_62729_row0_col2, #T_62729_row1_col2, #T_62729_row2_col2, #T_62729_row4_col0, #T_62729_row4_col1, #T_62729_row4_col3, #T_62729_row4_col4, #T_62729_row4_col5, #T_62729_row4_col6, #T_62729_row4_col7 {
#   background-color: #f1f1f1;
#   color: #000000;
# }
# #T_62729_row0_col3, #T_62729_row1_col3 {
#   background-color: #dedddd;
#   color: #000000;
# }
# #T_62729_row0_col4 {
#   background-color: #c3c1c1;
#   color: #000000;
# }
# #T_62729_row0_col7 {
#   background-color: #e2e2e2;
#   color: #000000;
# }
# #T_62729_row1_col1 {
#   background-color: #c6c5c5;
#   color: #000000;
# }
# #T_62729_row1_col4 {
#   background-color: #c1c0c0;
#   color: #000000;
# }
# #T_62729_row1_col5 {
#   background-color: #c7c5c5;
#   color: #000000;
# }
# #T_62729_row1_col6 {
#   background-color: #ececec;
#   color: #000000;
# }
# #T_62729_row1_col7 {
#   background-color: #cfcece;
#   color: #000000;
# }
# #T_62729_row2_col0 {
#   background-color: #c0bebe;
#   color: #000000;
# }
# #T_62729_row2_col1 {
#   background-color: #cbcaca;
#   color: #000000;
# }
# #T_62729_row2_col3 {
#   background-color: #cdcccc;
#   color: #000000;
# }
# #T_62729_row2_col4, #T_62729_row2_col7 {
#   background-color: #bcbaba;
#   color: #000000;
# }
# #T_62729_row2_col5 {
#   background-color: #d2d1d1;
#   color: #000000;
# }
# #T_62729_row2_col6 {
#   background-color: #eeeeee;
#   color: #000000;
# }
# #T_62729_row3_col0 {
#   background-color: #bfbdbd;
#   color: #000000;
# }
# #T_62729_row3_col1 {
#   background-color: #d6d5d5;
#   color: #000000;
# }
# #T_62729_row3_col2 {
#   background-color: #efefef;
#   color: #000000;
# }
# #T_62729_row3_col5 {
#   background-color: #e8e7e7;
#   color: #000000;
# }
# #T_62729_row3_col6 {
#   background-color: #ebebeb;
#   color: #000000;
# }
# </style>
# <table id="T_62729" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Category</th>
#       <th id="T_62729_level0_col0" class="col_heading level0 col0" >Bumps</th>
#       <th id="T_62729_level0_col1" class="col_heading level0 col1" >Dirtiness</th>
#       <th id="T_62729_level0_col2" class="col_heading level0 col2" >K_Scatch</th>
#       <th id="T_62729_level0_col3" class="col_heading level0 col3" >No_Fault</th>
#       <th id="T_62729_level0_col4" class="col_heading level0 col4" >Other_Faults</th>
#       <th id="T_62729_level0_col5" class="col_heading level0 col5" >Pastry</th>
#       <th id="T_62729_level0_col6" class="col_heading level0 col6" >Stains</th>
#       <th id="T_62729_level0_col7" class="col_heading level0 col7" >Z_Scratch</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Log_X_Index</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_62729_level0_row0" class="row_heading level0 row0" >(0.3, 0.954]</th>
#       <td id="T_62729_row0_col0" class="data row0 col0" >24.3%</td>
#       <td id="T_62729_row0_col1" class="data row0 col1" >4.0%</td>
#       <td id="T_62729_row0_col2" class="data row0 col2" >1.8%</td>
#       <td id="T_62729_row0_col3" class="data row0 col3" >3.8%</td>
#       <td id="T_62729_row0_col4" class="data row0 col4" >37.2%</td>
#       <td id="T_62729_row0_col5" class="data row0 col5" >14.5%</td>
#       <td id="T_62729_row0_col6" class="data row0 col6" >10.6%</td>
#       <td id="T_62729_row0_col7" class="data row0 col7" >3.8%</td>
#     </tr>
#     <tr>
#       <th id="T_62729_level0_row1" class="row_heading level0 row1" >(0.954, 1.079]</th>
#       <td id="T_62729_row1_col0" class="data row1 col0" >34.4%</td>
#       <td id="T_62729_row1_col1" class="data row1 col1" >3.2%</td>
#       <td id="T_62729_row1_col2" class="data row1 col2" >1.9%</td>
#       <td id="T_62729_row1_col3" class="data row1 col3" >3.8%</td>
#       <td id="T_62729_row1_col4" class="data row1 col4" >38.1%</td>
#       <td id="T_62729_row1_col5" class="data row1 col5" >11.1%</td>
#       <td id="T_62729_row1_col6" class="data row1 col6" >1.0%</td>
#       <td id="T_62729_row1_col7" class="data row1 col7" >6.6%</td>
#     </tr>
#     <tr>
#       <th id="T_62729_level0_row2" class="row_heading level0 row2" >(1.079, 1.23]</th>
#       <td id="T_62729_row2_col0" class="data row2 col0" >31.1%</td>
#       <td id="T_62729_row2_col1" class="data row2 col1" >2.8%</td>
#       <td id="T_62729_row2_col2" class="data row2 col2" >1.9%</td>
#       <td id="T_62729_row2_col3" class="data row2 col3" >5.2%</td>
#       <td id="T_62729_row2_col4" class="data row2 col4" >41.1%</td>
#       <td id="T_62729_row2_col5" class="data row2 col5" >8.1%</td>
#       <td id="T_62729_row2_col6" class="data row2 col6" >0.5%</td>
#       <td id="T_62729_row2_col7" class="data row2 col7" >9.2%</td>
#     </tr>
#     <tr>
#       <th id="T_62729_level0_row3" class="row_heading level0 row3" >(1.23, 1.602]</th>
#       <td id="T_62729_row3_col0" class="data row3 col0" >31.6%</td>
#       <td id="T_62729_row3_col1" class="data row3 col1" >2.1%</td>
#       <td id="T_62729_row3_col2" class="data row3 col2" >4.4%</td>
#       <td id="T_62729_row3_col3" class="data row3 col3" >6.7%</td>
#       <td id="T_62729_row3_col4" class="data row3 col4" >42.1%</td>
#       <td id="T_62729_row3_col5" class="data row3 col5" >2.5%</td>
#       <td id="T_62729_row3_col6" class="data row3 col6" >1.1%</td>
#       <td id="T_62729_row3_col7" class="data row3 col7" >9.5%</td>
#     </tr>
#     <tr>
#       <th id="T_62729_level0_row4" class="row_heading level0 row4" >(1.602, 2.997]</th>
#       <td id="T_62729_row4_col0" class="data row4 col0" >3.6%</td>
#       <td id="T_62729_row4_col1" class="data row4 col1" >0.3%</td>
#       <td id="T_62729_row4_col2" class="data row4 col2" >79.1%</td>
#       <td id="T_62729_row4_col3" class="data row4 col3" >2.3%</td>
#       <td id="T_62729_row4_col4" class="data row4 col4" >12.7%</td>
#       <td id="T_62729_row4_col5" class="data row4 col5" >0.2%</td>
#       <td id="T_62729_row4_col6" class="data row4 col6" >0.0%</td>
#       <td id="T_62729_row4_col7" class="data row4 col7" >1.8%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_000aa .index_name {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_000aa th:not(.index_name) {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_000aa td {
#   color: #4A4B52;
#   font-weight: bold;
# }
# #T_000aa .index_name {
#   min-width: 170px;
# }
# #T_000aa th {
#   min-width: 60px;
# }
# #T_000aa_row0_col0 {
#   background-color: #c1bfbf;
#   color: #000000;
# }
# #T_000aa_row0_col1 {
#   background-color: #e3e2e2;
#   color: #000000;
# }
# #T_000aa_row0_col2, #T_000aa_row1_col2, #T_000aa_row2_col2, #T_000aa_row3_col6, #T_000aa_row4_col0, #T_000aa_row4_col1, #T_000aa_row4_col3, #T_000aa_row4_col4, #T_000aa_row4_col5, #T_000aa_row4_col6, #T_000aa_row4_col7 {
#   background-color: #f1f1f1;
#   color: #000000;
# }
# #T_000aa_row0_col3 {
#   background-color: #cbcaca;
#   color: #000000;
# }
# #T_000aa_row0_col4 {
#   background-color: #c5c4c4;
#   color: #000000;
# }
# #T_000aa_row0_col5 {
#   background-color: #d7d6d6;
#   color: #000000;
# }
# #T_000aa_row0_col6, #T_000aa_row1_col0, #T_000aa_row1_col4, #T_000aa_row3_col1, #T_000aa_row3_col3, #T_000aa_row3_col5, #T_000aa_row3_col7, #T_000aa_row4_col2 {
#   background-color: #bab8b8;
#   color: #000000;
# }
# #T_000aa_row0_col7 {
#   background-color: #dfdfdf;
#   color: #000000;
# }
# #T_000aa_row1_col1 {
#   background-color: #dedddd;
#   color: #000000;
# }
# #T_000aa_row1_col3 {
#   background-color: #d1d0d0;
#   color: #000000;
# }
# #T_000aa_row1_col5 {
#   background-color: #d5d4d3;
#   color: #000000;
# }
# #T_000aa_row1_col6 {
#   background-color: #efefef;
#   color: #000000;
# }
# #T_000aa_row1_col7 {
#   background-color: #cccbcb;
#   color: #000000;
# }
# #T_000aa_row2_col0 {
#   background-color: #c2c1c1;
#   color: #000000;
# }
# #T_000aa_row2_col1 {
#   background-color: #d4d3d3;
#   color: #000000;
# }
# #T_000aa_row2_col3 {
#   background-color: #d0cfcf;
#   color: #000000;
# }
# #T_000aa_row2_col4 {
#   background-color: #bbbaba;
#   color: #000000;
# }
# #T_000aa_row2_col5 {
#   background-color: #bbb9b9;
#   color: #000000;
# }
# #T_000aa_row2_col6, #T_000aa_row3_col2 {
#   background-color: #f0f0f0;
#   color: #000000;
# }
# #T_000aa_row2_col7 {
#   background-color: #c7c5c5;
#   color: #000000;
# }
# #T_000aa_row3_col0 {
#   background-color: #cccaca;
#   color: #000000;
# }
# #T_000aa_row3_col4 {
#   background-color: #bdbbbb;
#   color: #000000;
# }
# </style>
# <table id="T_000aa" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Category</th>
#       <th id="T_000aa_level0_col0" class="col_heading level0 col0" >Bumps</th>
#       <th id="T_000aa_level0_col1" class="col_heading level0 col1" >Dirtiness</th>
#       <th id="T_000aa_level0_col2" class="col_heading level0 col2" >K_Scatch</th>
#       <th id="T_000aa_level0_col3" class="col_heading level0 col3" >No_Fault</th>
#       <th id="T_000aa_level0_col4" class="col_heading level0 col4" >Other_Faults</th>
#       <th id="T_000aa_level0_col5" class="col_heading level0 col5" >Pastry</th>
#       <th id="T_000aa_level0_col6" class="col_heading level0 col6" >Stains</th>
#       <th id="T_000aa_level0_col7" class="col_heading level0 col7" >Z_Scratch</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >LogOfAreas</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_000aa_level0_row0" class="row_heading level0 row0" >(0.777, 1.881]</th>
#       <td id="T_000aa_row0_col0" class="data row0 col0" >31.2%</td>
#       <td id="T_000aa_row0_col1" class="data row0 col1" >1.8%</td>
#       <td id="T_000aa_row0_col2" class="data row0 col2" >2.2%</td>
#       <td id="T_000aa_row0_col3" class="data row0 col3" >4.6%</td>
#       <td id="T_000aa_row0_col4" class="data row0 col4" >35.6%</td>
#       <td id="T_000aa_row0_col5" class="data row0 col5" >6.3%</td>
#       <td id="T_000aa_row0_col6" class="data row0 col6" >13.9%</td>
#       <td id="T_000aa_row0_col7" class="data row0 col7" >4.4%</td>
#     </tr>
#     <tr>
#       <th id="T_000aa_level0_row1" class="row_heading level0 row1" >(1.881, 2.111]</th>
#       <td id="T_000aa_row1_col0" class="data row1 col0" >35.5%</td>
#       <td id="T_000aa_row1_col1" class="data row1 col1" >2.2%</td>
#       <td id="T_000aa_row1_col2" class="data row1 col2" >2.0%</td>
#       <td id="T_000aa_row1_col3" class="data row1 col3" >4.3%</td>
#       <td id="T_000aa_row1_col4" class="data row1 col4" >41.9%</td>
#       <td id="T_000aa_row1_col5" class="data row1 col5" >6.8%</td>
#       <td id="T_000aa_row1_col6" class="data row1 col6" >0.5%</td>
#       <td id="T_000aa_row1_col7" class="data row1 col7" >6.8%</td>
#     </tr>
#     <tr>
#       <th id="T_000aa_level0_row2" class="row_heading level0 row2" >(2.111, 2.354]</th>
#       <td id="T_000aa_row2_col0" class="data row2 col0" >30.4%</td>
#       <td id="T_000aa_row2_col1" class="data row2 col1" >3.0%</td>
#       <td id="T_000aa_row2_col2" class="data row2 col2" >2.1%</td>
#       <td id="T_000aa_row2_col3" class="data row2 col3" >4.4%</td>
#       <td id="T_000aa_row2_col4" class="data row2 col4" >40.9%</td>
#       <td id="T_000aa_row2_col5" class="data row2 col5" >11.6%</td>
#       <td id="T_000aa_row2_col6" class="data row2 col6" >0.2%</td>
#       <td id="T_000aa_row2_col7" class="data row2 col7" >7.5%</td>
#     </tr>
#     <tr>
#       <th id="T_000aa_level0_row3" class="row_heading level0 row3" >(2.354, 3.051]</th>
#       <td id="T_000aa_row3_col0" class="data row3 col0" >24.8%</td>
#       <td id="T_000aa_row3_col1" class="data row3 col1" >5.1%</td>
#       <td id="T_000aa_row3_col2" class="data row3 col2" >3.3%</td>
#       <td id="T_000aa_row3_col3" class="data row3 col3" >5.8%</td>
#       <td id="T_000aa_row3_col4" class="data row3 col4" >40.2%</td>
#       <td id="T_000aa_row3_col5" class="data row3 col5" >11.7%</td>
#       <td id="T_000aa_row3_col6" class="data row3 col6" >0.0%</td>
#       <td id="T_000aa_row3_col7" class="data row3 col7" >9.1%</td>
#     </tr>
#     <tr>
#       <th id="T_000aa_level0_row4" class="row_heading level0 row4" >(3.051, 4.554]</th>
#       <td id="T_000aa_row4_col0" class="data row4 col0" >2.1%</td>
#       <td id="T_000aa_row4_col1" class="data row4 col1" >0.7%</td>
#       <td id="T_000aa_row4_col2" class="data row4 col2" >79.4%</td>
#       <td id="T_000aa_row4_col3" class="data row4 col3" >2.2%</td>
#       <td id="T_000aa_row4_col4" class="data row4 col4" >11.7%</td>
#       <td id="T_000aa_row4_col5" class="data row4 col5" >1.7%</td>
#       <td id="T_000aa_row4_col6" class="data row4 col6" >0.0%</td>
#       <td id="T_000aa_row4_col7" class="data row4 col7" >2.1%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d04e3 .index_name {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_d04e3 th:not(.index_name) {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_d04e3 td {
#   color: #4A4B52;
#   font-weight: bold;
# }
# #T_d04e3 .index_name {
#   min-width: 170px;
# }
# #T_d04e3 th {
#   min-width: 60px;
# }
# #T_d04e3_row0_col0 {
#   background-color: #c0bebe;
#   color: #000000;
# }
# #T_d04e3_row0_col1 {
#   background-color: #dbdada;
#   color: #000000;
# }
# #T_d04e3_row0_col2, #T_d04e3_row3_col6 {
#   background-color: #f0f0f0;
#   color: #000000;
# }
# #T_d04e3_row0_col3 {
#   background-color: #dddddd;
#   color: #000000;
# }
# #T_d04e3_row0_col4 {
#   background-color: #c7c6c6;
#   color: #000000;
# }
# #T_d04e3_row0_col5, #T_d04e3_row0_col6, #T_d04e3_row1_col0, #T_d04e3_row1_col5, #T_d04e3_row2_col4, #T_d04e3_row3_col1, #T_d04e3_row3_col3, #T_d04e3_row3_col7, #T_d04e3_row4_col2 {
#   background-color: #bab8b8;
#   color: #000000;
# }
# #T_d04e3_row0_col7 {
#   background-color: #e9e9e9;
#   color: #000000;
# }
# #T_d04e3_row1_col1 {
#   background-color: #d1d0d0;
#   color: #000000;
# }
# #T_d04e3_row1_col2, #T_d04e3_row2_col2, #T_d04e3_row4_col0, #T_d04e3_row4_col1, #T_d04e3_row4_col3, #T_d04e3_row4_col4, #T_d04e3_row4_col5, #T_d04e3_row4_col6, #T_d04e3_row4_col7 {
#   background-color: #f1f1f1;
#   color: #000000;
# }
# #T_d04e3_row1_col3 {
#   background-color: #e1e1e1;
#   color: #000000;
# }
# #T_d04e3_row1_col4 {
#   background-color: #bfbdbd;
#   color: #000000;
# }
# #T_d04e3_row1_col6, #T_d04e3_row2_col6 {
#   background-color: #ededed;
#   color: #000000;
# }
# #T_d04e3_row1_col7 {
#   background-color: #cdcccc;
#   color: #000000;
# }
# #T_d04e3_row2_col0, #T_d04e3_row2_col5 {
#   background-color: #c1c0c0;
#   color: #000000;
# }
# #T_d04e3_row2_col1 {
#   background-color: #d2d1d1;
#   color: #000000;
# }
# #T_d04e3_row2_col3 {
#   background-color: #cccbcb;
#   color: #000000;
# }
# #T_d04e3_row2_col7, #T_d04e3_row3_col5 {
#   background-color: #c3c2c2;
#   color: #000000;
# }
# #T_d04e3_row3_col0 {
#   background-color: #c9c8c8;
#   color: #000000;
# }
# #T_d04e3_row3_col2 {
#   background-color: #efefef;
#   color: #000000;
# }
# #T_d04e3_row3_col4 {
#   background-color: #bcbaba;
#   color: #000000;
# }
# </style>
# <table id="T_d04e3" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Category</th>
#       <th id="T_d04e3_level0_col0" class="col_heading level0 col0" >Bumps</th>
#       <th id="T_d04e3_level0_col1" class="col_heading level0 col1" >Dirtiness</th>
#       <th id="T_d04e3_level0_col2" class="col_heading level0 col2" >K_Scatch</th>
#       <th id="T_d04e3_level0_col3" class="col_heading level0 col3" >No_Fault</th>
#       <th id="T_d04e3_level0_col4" class="col_heading level0 col4" >Other_Faults</th>
#       <th id="T_d04e3_level0_col5" class="col_heading level0 col5" >Pastry</th>
#       <th id="T_d04e3_level0_col6" class="col_heading level0 col6" >Stains</th>
#       <th id="T_d04e3_level0_col7" class="col_heading level0 col7" >Z_Scratch</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >X_Perimeter</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d04e3_level0_row0" class="row_heading level0 row0" >(1.999, 13.0]</th>
#       <td id="T_d04e3_row0_col0" class="data row0 col0" >31.0%</td>
#       <td id="T_d04e3_row0_col1" class="data row0 col1" >2.1%</td>
#       <td id="T_d04e3_row0_col2" class="data row0 col2" >2.5%</td>
#       <td id="T_d04e3_row0_col3" class="data row0 col3" >3.9%</td>
#       <td id="T_d04e3_row0_col4" class="data row0 col4" >35.0%</td>
#       <td id="T_d04e3_row0_col5" class="data row0 col5" >9.9%</td>
#       <td id="T_d04e3_row0_col6" class="data row0 col6" >12.6%</td>
#       <td id="T_d04e3_row0_col7" class="data row0 col7" >3.1%</td>
#     </tr>
#     <tr>
#       <th id="T_d04e3_level0_row1" class="row_heading level0 row1" >(13.0, 20.0]</th>
#       <td id="T_d04e3_row1_col0" class="data row1 col0" >34.6%</td>
#       <td id="T_d04e3_row1_col1" class="data row1 col1" >2.8%</td>
#       <td id="T_d04e3_row1_col2" class="data row1 col2" >1.5%</td>
#       <td id="T_d04e3_row1_col3" class="data row1 col3" >3.6%</td>
#       <td id="T_d04e3_row1_col4" class="data row1 col4" >39.8%</td>
#       <td id="T_d04e3_row1_col5" class="data row1 col5" >9.8%</td>
#       <td id="T_d04e3_row1_col6" class="data row1 col6" >0.9%</td>
#       <td id="T_d04e3_row1_col7" class="data row1 col7" >7.0%</td>
#     </tr>
#     <tr>
#       <th id="T_d04e3_level0_row2" class="row_heading level0 row2" >(20.0, 32.0]</th>
#       <td id="T_d04e3_row2_col0" class="data row2 col0" >30.1%</td>
#       <td id="T_d04e3_row2_col1" class="data row2 col1" >2.7%</td>
#       <td id="T_d04e3_row2_col2" class="data row2 col2" >1.5%</td>
#       <td id="T_d04e3_row2_col3" class="data row2 col3" >5.1%</td>
#       <td id="T_d04e3_row2_col4" class="data row2 col4" >42.6%</td>
#       <td id="T_d04e3_row2_col5" class="data row2 col5" >8.7%</td>
#       <td id="T_d04e3_row2_col6" class="data row2 col6" >0.8%</td>
#       <td id="T_d04e3_row2_col7" class="data row2 col7" >8.4%</td>
#     </tr>
#     <tr>
#       <th id="T_d04e3_level0_row3" class="row_heading level0 row3" >(32.0, 109.0]</th>
#       <td id="T_d04e3_row3_col0" class="data row3 col0" >25.4%</td>
#       <td id="T_d04e3_row3_col1" class="data row3 col1" >4.6%</td>
#       <td id="T_d04e3_row3_col2" class="data row3 col2" >3.8%</td>
#       <td id="T_d04e3_row3_col3" class="data row3 col3" >6.4%</td>
#       <td id="T_d04e3_row3_col4" class="data row3 col4" >41.4%</td>
#       <td id="T_d04e3_row3_col5" class="data row3 col5" >8.4%</td>
#       <td id="T_d04e3_row3_col6" class="data row3 col6" >0.2%</td>
#       <td id="T_d04e3_row3_col7" class="data row3 col7" >9.7%</td>
#     </tr>
#     <tr>
#       <th id="T_d04e3_level0_row4" class="row_heading level0 row4" >(109.0, 7553.0]</th>
#       <td id="T_d04e3_row4_col0" class="data row4 col0" >2.1%</td>
#       <td id="T_d04e3_row4_col1" class="data row4 col1" >0.4%</td>
#       <td id="T_d04e3_row4_col2" class="data row4 col2" >80.4%</td>
#       <td id="T_d04e3_row4_col3" class="data row4 col3" >2.5%</td>
#       <td id="T_d04e3_row4_col4" class="data row4 col4" >11.6%</td>
#       <td id="T_d04e3_row4_col5" class="data row4 col5" >1.2%</td>
#       <td id="T_d04e3_row4_col6" class="data row4 col6" >0.0%</td>
#       <td id="T_d04e3_row4_col7" class="data row4 col7" >1.9%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_69a2f .index_name {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_69a2f th:not(.index_name) {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_69a2f td {
#   color: #4A4B52;
#   font-weight: bold;
# }
# #T_69a2f .index_name {
#   min-width: 170px;
# }
# #T_69a2f th {
#   min-width: 60px;
# }
# #T_69a2f_row0_col0 {
#   background-color: #c1bfbf;
#   color: #000000;
# }
# #T_69a2f_row0_col1 {
#   background-color: #e3e3e3;
#   color: #000000;
# }
# #T_69a2f_row0_col2, #T_69a2f_row1_col2, #T_69a2f_row2_col2, #T_69a2f_row3_col6, #T_69a2f_row4_col0, #T_69a2f_row4_col1, #T_69a2f_row4_col3, #T_69a2f_row4_col4, #T_69a2f_row4_col5, #T_69a2f_row4_col6, #T_69a2f_row4_col7 {
#   background-color: #f1f1f1;
#   color: #000000;
# }
# #T_69a2f_row0_col3, #T_69a2f_row3_col0 {
#   background-color: #cccaca;
#   color: #000000;
# }
# #T_69a2f_row0_col4 {
#   background-color: #c5c4c4;
#   color: #000000;
# }
# #T_69a2f_row0_col5 {
#   background-color: #d8d7d7;
#   color: #000000;
# }
# #T_69a2f_row0_col6, #T_69a2f_row1_col0, #T_69a2f_row1_col4, #T_69a2f_row3_col1, #T_69a2f_row3_col3, #T_69a2f_row3_col5, #T_69a2f_row3_col7, #T_69a2f_row4_col2 {
#   background-color: #bab8b8;
#   color: #000000;
# }
# #T_69a2f_row0_col7 {
#   background-color: #dfdfdf;
#   color: #000000;
# }
# #T_69a2f_row1_col1 {
#   background-color: #dedddd;
#   color: #000000;
# }
# #T_69a2f_row1_col3 {
#   background-color: #d1d0d0;
#   color: #000000;
# }
# #T_69a2f_row1_col5 {
#   background-color: #d5d4d4;
#   color: #000000;
# }
# #T_69a2f_row1_col6 {
#   background-color: #efefef;
#   color: #000000;
# }
# #T_69a2f_row1_col7 {
#   background-color: #cccbcb;
#   color: #000000;
# }
# #T_69a2f_row2_col0 {
#   background-color: #c2c0c0;
#   color: #000000;
# }
# #T_69a2f_row2_col1 {
#   background-color: #d4d3d3;
#   color: #000000;
# }
# #T_69a2f_row2_col3 {
#   background-color: #d0cfcf;
#   color: #000000;
# }
# #T_69a2f_row2_col4 {
#   background-color: #bcbaba;
#   color: #000000;
# }
# #T_69a2f_row2_col5 {
#   background-color: #bbb9b9;
#   color: #000000;
# }
# #T_69a2f_row2_col6, #T_69a2f_row3_col2 {
#   background-color: #f0f0f0;
#   color: #000000;
# }
# #T_69a2f_row2_col7 {
#   background-color: #c6c4c4;
#   color: #000000;
# }
# #T_69a2f_row3_col4 {
#   background-color: #bdbbbb;
#   color: #000000;
# }
# </style>
# <table id="T_69a2f" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Category</th>
#       <th id="T_69a2f_level0_col0" class="col_heading level0 col0" >Bumps</th>
#       <th id="T_69a2f_level0_col1" class="col_heading level0 col1" >Dirtiness</th>
#       <th id="T_69a2f_level0_col2" class="col_heading level0 col2" >K_Scatch</th>
#       <th id="T_69a2f_level0_col3" class="col_heading level0 col3" >No_Fault</th>
#       <th id="T_69a2f_level0_col4" class="col_heading level0 col4" >Other_Faults</th>
#       <th id="T_69a2f_level0_col5" class="col_heading level0 col5" >Pastry</th>
#       <th id="T_69a2f_level0_col6" class="col_heading level0 col6" >Stains</th>
#       <th id="T_69a2f_level0_col7" class="col_heading level0 col7" >Z_Scratch</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pixels_Areas</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69a2f_level0_row0" class="row_heading level0 row0" >(5.999, 76.0]</th>
#       <td id="T_69a2f_row0_col0" class="data row0 col0" >31.2%</td>
#       <td id="T_69a2f_row0_col1" class="data row0 col1" >1.8%</td>
#       <td id="T_69a2f_row0_col2" class="data row0 col2" >2.2%</td>
#       <td id="T_69a2f_row0_col3" class="data row0 col3" >4.6%</td>
#       <td id="T_69a2f_row0_col4" class="data row0 col4" >35.6%</td>
#       <td id="T_69a2f_row0_col5" class="data row0 col5" >6.3%</td>
#       <td id="T_69a2f_row0_col6" class="data row0 col6" >13.9%</td>
#       <td id="T_69a2f_row0_col7" class="data row0 col7" >4.4%</td>
#     </tr>
#     <tr>
#       <th id="T_69a2f_level0_row1" class="row_heading level0 row1" >(76.0, 129.0]</th>
#       <td id="T_69a2f_row1_col0" class="data row1 col0" >35.5%</td>
#       <td id="T_69a2f_row1_col1" class="data row1 col1" >2.2%</td>
#       <td id="T_69a2f_row1_col2" class="data row1 col2" >2.0%</td>
#       <td id="T_69a2f_row1_col3" class="data row1 col3" >4.3%</td>
#       <td id="T_69a2f_row1_col4" class="data row1 col4" >41.9%</td>
#       <td id="T_69a2f_row1_col5" class="data row1 col5" >6.8%</td>
#       <td id="T_69a2f_row1_col6" class="data row1 col6" >0.5%</td>
#       <td id="T_69a2f_row1_col7" class="data row1 col7" >6.8%</td>
#     </tr>
#     <tr>
#       <th id="T_69a2f_level0_row2" class="row_heading level0 row2" >(129.0, 226.0]</th>
#       <td id="T_69a2f_row2_col0" class="data row2 col0" >30.4%</td>
#       <td id="T_69a2f_row2_col1" class="data row2 col1" >3.0%</td>
#       <td id="T_69a2f_row2_col2" class="data row2 col2" >2.1%</td>
#       <td id="T_69a2f_row2_col3" class="data row2 col3" >4.3%</td>
#       <td id="T_69a2f_row2_col4" class="data row2 col4" >40.9%</td>
#       <td id="T_69a2f_row2_col5" class="data row2 col5" >11.5%</td>
#       <td id="T_69a2f_row2_col6" class="data row2 col6" >0.2%</td>
#       <td id="T_69a2f_row2_col7" class="data row2 col7" >7.6%</td>
#     </tr>
#     <tr>
#       <th id="T_69a2f_level0_row3" class="row_heading level0 row3" >(226.0, 1119.4]</th>
#       <td id="T_69a2f_row3_col0" class="data row3 col0" >24.8%</td>
#       <td id="T_69a2f_row3_col1" class="data row3 col1" >5.1%</td>
#       <td id="T_69a2f_row3_col2" class="data row3 col2" >3.4%</td>
#       <td id="T_69a2f_row3_col3" class="data row3 col3" >5.8%</td>
#       <td id="T_69a2f_row3_col4" class="data row3 col4" >40.2%</td>
#       <td id="T_69a2f_row3_col5" class="data row3 col5" >11.7%</td>
#       <td id="T_69a2f_row3_col6" class="data row3 col6" >0.0%</td>
#       <td id="T_69a2f_row3_col7" class="data row3 col7" >9.1%</td>
#     </tr>
#     <tr>
#       <th id="T_69a2f_level0_row4" class="row_heading level0 row4" >(1119.4, 152655.0]</th>
#       <td id="T_69a2f_row4_col0" class="data row4 col0" >2.1%</td>
#       <td id="T_69a2f_row4_col1" class="data row4 col1" >0.7%</td>
#       <td id="T_69a2f_row4_col2" class="data row4 col2" >79.2%</td>
#       <td id="T_69a2f_row4_col3" class="data row4 col3" >2.3%</td>
#       <td id="T_69a2f_row4_col4" class="data row4 col4" >11.8%</td>
#       <td id="T_69a2f_row4_col5" class="data row4 col5" >1.8%</td>
#       <td id="T_69a2f_row4_col6" class="data row4 col6" >0.0%</td>
#       <td id="T_69a2f_row4_col7" class="data row4 col7" >2.2%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
# ">
#     <b><span style="color: #780D0D;">&#x25FC</span> Continuous Feature Cross Tables</b>
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
#     text-align: justify;
#     text-justify: inter-word;
# ">
#     Here we create cross tables for some features versus the target variable. This gives us a handy univariate analysis of cut-off levels in particular variables and how target categories characterize this level. Each level is row-wise normalized, so for example, the $(1.602, 2.997]$ cut-off level in the <code>Log_X_Index</code> feature is characterized by 79% observations with <code>K_Scatch</code> target value. <b>I intentionally chose these features because of the</b> <code>K_Scatch</code> <b>pattern, i.e. see how much this category prevails in some cut-offs (there is more such features but no need to show these all). There is no such pattern for any features in the remaining categories, which makes</b> <code>K_Scatch</code> <b>somehow special.</b> Let's see correlations now!
# </p>

# %%
spearman_corr = orig.corr(method="spearman", numeric_only=True)
lower_triu_corr = get_lower_triangular_frame(spearman_corr)
dissimilarity = 1 - np.abs(spearman_corr)

fig = ff.create_dendrogram(
    dissimilarity,
    labels=spearman_corr.columns,
    orientation="left",
    colorscale=px.colors.sequential.Greys[1:],
    # squareform() returns lower triangular in compressed form - as 1D array.
    linkagefun=lambda x: linkage(squareform(dissimilarity), method="complete"),
)
fig.update_xaxes(showline=False, title="Distance", ticks="", range=[-0.03, 1.05])
fig.update_yaxes(showline=False, ticks="")
fig.update_layout(
    title="Training Dataset - Hierarchical Clustering using Correlation Matrix (Spearman)<br>"
    "<span style='font-size: 75%; font-weight: bold;'>"
    "Small distances give hope for some feature clusters and dimensionality reduction</span>",
    height=720,
    width=820,
)
fig.update_traces(line_width=1.5, opacity=1)
save_and_show_fig(fig, "hierarchical_clustering")

# %%
abs_corr = (
    lower_triu_corr.abs()
    .unstack()
    .sort_values(ascending=False)  # type: ignore
    .rename("ABS Spearman Correlation")
    .to_frame()
    .reset_index(names=["Feature 1", "Feature 2"])
    .dropna()
    .round(5)
)

with pd.option_context("display.max_rows", 10):
    print(abs_corr)
# Out:
#                  Feature 1          Feature 2  ABS Spearman Correlation
# 0             Pixels_Areas         LogOfAreas                   1.00000
# 1                Y_Minimum          Y_Maximum                   1.00000
# 2          Outside_X_Index        Log_X_Index                   0.98866
# 3             Pixels_Areas  Sum_of_Luminosity                   0.98509
# 4        Sum_of_Luminosity         LogOfAreas                   0.98509
# ..                     ...                ...                       ...
# 271              X_Minimum          Y_Maximum                   0.00355
# 272              X_Minimum          Y_Minimum                   0.00353
# 273  Maximum_of_Luminosity     SigmoidOfAreas                   0.00272
# 274              Y_Maximum        Log_Y_Index                   0.00064
# 275              Y_Minimum        Log_Y_Index                   0.00058
#
# [276 rows x 3 columns]

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
# ">
#     <b><span style="color: #780D0D;">&#x25FC</span> Correlations &amp; Hierarchical Clustering</b>
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
#     text-align: justify;
#     text-justify: inter-word;
# ">
#     There we have Spearman correlation visual analysis. I intentionally use Spearman because, for this dataset, this type of correlation gives more higher results, so we perhaps deal with non-linear dependencies. As you notice, there are clear non-linear correlations, <b>but the question is are these pairs indeed correlated, or is it an impact of some outliers?</b> We will check this later on scatter-pair plots. As for hierarchical clustering, we just use to assess whether there are feature clusters. In this specific example, I've used <code>complete</code> method in <code>linkage</code> function, and if you use a different method, you may get different results.<br><br>
#     <b>Let's have a look at highly correlated pairs on scatter-pair plots.</b>
# </p>

# %%
n_cols, n_pairs = 4, 16
n_rows, axes = get_n_rows_and_axes(n_pairs, n_cols)

fig = make_subplots(
    rows=n_rows,
    cols=n_cols,
    horizontal_spacing=0.1,
)

for (row, col), (feature1, feature2, corr) in zip(axes, abs_corr[:n_pairs].to_numpy()):
    fig.add_scatter(
        x=train.iloc[:2000][feature1],
        y=train.iloc[:2000][feature2],
        mode="markers",
        name="",
        row=row,
        col=col,
    )
    fig.update_xaxes(title_text=feature1, row=row, col=col)
    fig.update_yaxes(title_text=feature2, row=row, col=col)

fig.update_layout(
    title="Training Dataset - Highly Non-Linear Correlated Pairs<br>"
    "<span style='font-size: 75%; font-weight: bold;'>"
    "Training data include many artifacts that does not occur in the original dataset</span>",
    width=820,
    height=820,
    showlegend=False,
)
fig.update_traces(marker=dict(size=1, symbol="x-thin", line=dict(width=1)))
save_and_show_fig(fig, "train_highly_correlated_scatter_plots")

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
# ">
#     <b><span style="color: #780D0D;">&#x25FC</span> Training Scatter-Pair Plots</b>
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
#     text-align: justify;
#     text-justify: inter-word;
# ">
#     Obiously in the playground series, training data includes some weird synthetic observations (see first row and second column or first row and fourth column). There are no such patterns in the original data (there are only main diagonals without samples distributed strictly horizontally and vertically).
# </p>

# %% [markdown]
# ## <b> <span style="font-family: 'JetBrains Mono'; color: #4A4B52">1.3</span> <span style='color: #780D0D'>|</span> <span style="font-family: 'JetBrains Mono'; color: #4A4B52">Playing with Categorical Variables</span></b><a class="anchor" id="playing_with_categorical_variables"></a> [↑](#top)

# %% [markdown]
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
#     text-align: justify;
#     text-justify: inter-word;
# ">
#     <b>Some features are categorical. Let's visualize their dependencies with some useful stacked-bar plots.</b>
# </p>

# %%
n_cols = 3
n_rows, axes = get_n_rows_and_axes(len(cat_features), n_cols)
fig = make_subplots(
    rows=n_rows,
    cols=n_cols,
    y_title="Sum of Count (Normalized as Percent)",
)
fig.update_annotations(font_size=14)

for k, (var, (row, col)) in enumerate(zip(cat_features, axes), start=1):
    for cat, color in zip(targets, px.colors.diverging.oxy):
        fig.add_histogram(
            x=train.query(f"Category == '{cat}'")[var].astype(str),
            marker_color=color,
            name=cat,
            legendgroup=cat,
            showlegend=k == 1,
            row=row,
            col=col,
        )
        fig.update_xaxes(title_text=f"<b>{var}</b>", row=row, col=col)

fig.update_layout(
    title="Training Dataset - Categorical Features vs Target Classes<br>"
    "<span style='font-size: 75%; font-weight: bold;'>"
    "There is only one sample with 'Outside_Global_Index' = 0.7, "
    "so visualization is confusing</span>",
    width=820,
    height=440,
    barnorm="percent",
    barmode="relative",
    bargap=0.3,
    legend=dict(
        orientation="v",
        xanchor="left",
        yanchor="top",
        traceorder="reversed",
        y=0.98,
    ),
)
save_and_show_fig(fig, "categorical_bars")

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
# ">
#     <b><span style="color: #780D0D;">&#x25FC</span> Categorical Feature Distributions</b>
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
#     text-align: justify;
#     text-justify: inter-word;
# ">
#     Bar plots above are normalized as percent count so they can be easily compared across specific categories in the target variable. Let's see:
# </p>
#
# <ul style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
#     text-align: justify;
#     text-justify: inter-word;
# ">
#     <li>For <code>TypeOfSteel_A300</code> and <code>TypeOfSteel_400</code> the situation is reversed in the case of <code>Bumps</code> and <code>K_Scatch</code>.</li>
#     <li>For <code>Outside_Global_Index</code> feature, values of '0.7' category are dominated by 'Other_Faults' target class, but it's misleading since there is only one such observation. See below.</li>
# </ul>

# %%
get_pretty_frame(
    pd.DataFrame(
        {
            "Train": train.Outside_Global_Index.value_counts(),
            "Test": test.Outside_Global_Index.value_counts(),
            "Original": orig.Outside_Global_Index.value_counts(),
        }
    )
)
# Out:
# <style type="text/css">
# #T_9d0dd .index_name {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_9d0dd th:not(.index_name) {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_9d0dd td {
#   color: #4A4B52;
#   font-weight: bold;
# }
# </style>
# <table id="T_9d0dd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9d0dd_level0_col0" class="col_heading level0 col0" >Train</th>
#       <th id="T_9d0dd_level0_col1" class="col_heading level0 col1" >Test</th>
#       <th id="T_9d0dd_level0_col2" class="col_heading level0 col2" >Original</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Outside_Global_Index</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d0dd_level0_row0" class="row_heading level0 row0" >0.000000</th>
#       <td id="T_9d0dd_row0_col0" class="data row0 col0" >7486</td>
#       <td id="T_9d0dd_row0_col1" class="data row0 col1" >5082.000</td>
#       <td id="T_9d0dd_row0_col2" class="data row0 col2" >778.000</td>
#     </tr>
#     <tr>
#       <th id="T_9d0dd_level0_row1" class="row_heading level0 row1" >0.500000</th>
#       <td id="T_9d0dd_row1_col0" class="data row1 col0" >705</td>
#       <td id="T_9d0dd_row1_col1" class="data row1 col1" >472.000</td>
#       <td id="T_9d0dd_row1_col2" class="data row1 col2" >91.000</td>
#     </tr>
#     <tr>
#       <th id="T_9d0dd_level0_row2" class="row_heading level0 row2" >0.700000</th>
#       <td id="T_9d0dd_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_9d0dd_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_9d0dd_row2_col2" class="data row2 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9d0dd_level0_row3" class="row_heading level0 row3" >1.000000</th>
#       <td id="T_9d0dd_row3_col0" class="data row3 col0" >11006</td>
#       <td id="T_9d0dd_row3_col1" class="data row3 col1" >7260.000</td>
#       <td id="T_9d0dd_row3_col2" class="data row3 col2" >1072.000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Let's map this.
train.Outside_Global_Index = train.Outside_Global_Index.replace({0.7: 1.0})
train_extended.Outside_Global_Index = train_extended.Outside_Global_Index.replace({0.7: 1.0})

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
# ">
#     <b><span style="color: #780D0D;">&#x25FC</span> Category Mismatch</b>
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
# ">
#     There is no '0.7' category in test and original datasets in <code>Outside_Global_Index</code> feature. As we can see there is only one such observation in train subset in total. We can reject this category and map it to something more frequent, like '1.0'.
# </p>

# %% [markdown]
# # <b> <span style="font-family: 'JetBrains Mono'; color: #4A4B52">2</span> <span style='color: #780D0D'>|</span> <span style="font-family: 'JetBrains Mono'; color: #4A4B52">Optuna Tuners</span></b><a class="anchor" id="optuna_tuners"></a> [↑](#top)

# %% [markdown]
# ## <b> <span style="font-family: 'JetBrains Mono'; color: #4A4B52">2.1</span> <span style='color: #780D0D'>|</span> <span style="font-family: 'JetBrains Mono'; color: #4A4B52">Simple Preprocessing</span></b><a class="anchor" id="simple_preprocessing"></a> [↑](#top)

# %%
def clip_features(X, percentiles):
    X = np.asarray(X)
    lower_limit, upper_limit = np.percentile(X, percentiles, axis=0)
    return np.clip(X, lower_limit, upper_limit)


preprocess = make_column_transformer(
    (
        OneHotEncoder(drop="if_binary", sparse_output=False, handle_unknown="ignore"),
        ["TypeOfSteel_A300", "TypeOfSteel_A400", "Outside_Global_Index"],
    ),
    (
        make_pipeline(
            FunctionTransformer(
                clip_features,
                feature_names_out="one-to-one",
                kw_args=dict(percentiles=(0, 99)),
            ),
            StandardScaler(),
        ),
        ["Pixels_Areas", "X_Perimeter", "Sum_of_Luminosity"],
    ),
    (
        StandardScaler(),
        [
            "X_Minimum",
            "X_Maximum",
            "Y_Minimum",
            "Y_Maximum",
            "Y_Perimeter",
            "Minimum_of_Luminosity",
            "Maximum_of_Luminosity",
            "Length_of_Conveyer",
            "Steel_Plate_Thickness",
            "Edges_Index",
            "Empty_Index",
            "Square_Index",
            "Outside_X_Index",
            "Edges_X_Index",
            "Edges_Y_Index",
            "LogOfAreas",
            "Log_X_Index",
            "Log_Y_Index",
            "Orientation_Index",
            "Luminosity_Index",
            "SigmoidOfAreas",
        ],
    ),
    remainder="drop",
)

preprocess.set_output(transform="pandas")
# Out:
# ColumnTransformer(transformers=[('onehotencoder',
#                                  OneHotEncoder(drop='if_binary',
#                                                handle_unknown='ignore',
#                                                sparse_output=False),
#                                  ['TypeOfSteel_A300', 'TypeOfSteel_A400',
#                                   'Outside_Global_Index']),
#                                 ('pipeline',
#                                  Pipeline(steps=[('functiontransformer',
#                                                   FunctionTransformer(feature_names_out='one-to-one',
#                                                                       func=<function clip_features at 0x00000180623C3A60>,
#                                                                       kw_args={'...
#                                 ('standardscaler', StandardScaler(),
#                                  ['X_Minimum', 'X_Maximum', 'Y_Minimum',
#                                   'Y_Maximum', 'Y_Perimeter',
#                                   'Minimum_of_Luminosity',
#                                   'Maximum_of_Luminosity', 'Length_of_Conveyer',
#                                   'Steel_Plate_Thickness', 'Edges_Index',
#                                   'Empty_Index', 'Square_Index',
#                                   'Outside_X_Index', 'Edges_X_Index',
#                                   'Edges_Y_Index', 'LogOfAreas', 'Log_X_Index',
#                                   'Log_Y_Index', 'Orientation_Index',
#                                   'Luminosity_Index', 'SigmoidOfAreas'])])

# %%
tmp = preprocess.fit_transform(train_extended.drop(columns="Category"))
get_pretty_frame(tmp.head())  # type: ignore
# Out:
# <style type="text/css">
# #T_12c50 .index_name {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_12c50 th:not(.index_name) {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_12c50 td {
#   color: #4A4B52;
#   font-weight: bold;
# }
# </style>
# <table id="T_12c50">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12c50_level0_col0" class="col_heading level0 col0" >onehotencoder__TypeOfSteel_A300_1</th>
#       <th id="T_12c50_level0_col1" class="col_heading level0 col1" >onehotencoder__TypeOfSteel_A400_1</th>
#       <th id="T_12c50_level0_col2" class="col_heading level0 col2" >onehotencoder__Outside_Global_Index_0.0</th>
#       <th id="T_12c50_level0_col3" class="col_heading level0 col3" >onehotencoder__Outside_Global_Index_0.5</th>
#       <th id="T_12c50_level0_col4" class="col_heading level0 col4" >onehotencoder__Outside_Global_Index_1.0</th>
#       <th id="T_12c50_level0_col5" class="col_heading level0 col5" >pipeline__Pixels_Areas</th>
#       <th id="T_12c50_level0_col6" class="col_heading level0 col6" >pipeline__X_Perimeter</th>
#       <th id="T_12c50_level0_col7" class="col_heading level0 col7" >pipeline__Sum_of_Luminosity</th>
#       <th id="T_12c50_level0_col8" class="col_heading level0 col8" >standardscaler__X_Minimum</th>
#       <th id="T_12c50_level0_col9" class="col_heading level0 col9" >standardscaler__X_Maximum</th>
#       <th id="T_12c50_level0_col10" class="col_heading level0 col10" >standardscaler__Y_Minimum</th>
#       <th id="T_12c50_level0_col11" class="col_heading level0 col11" >standardscaler__Y_Maximum</th>
#       <th id="T_12c50_level0_col12" class="col_heading level0 col12" >standardscaler__Y_Perimeter</th>
#       <th id="T_12c50_level0_col13" class="col_heading level0 col13" >standardscaler__Minimum_of_Luminosity</th>
#       <th id="T_12c50_level0_col14" class="col_heading level0 col14" >standardscaler__Maximum_of_Luminosity</th>
#       <th id="T_12c50_level0_col15" class="col_heading level0 col15" >standardscaler__Length_of_Conveyer</th>
#       <th id="T_12c50_level0_col16" class="col_heading level0 col16" >standardscaler__Steel_Plate_Thickness</th>
#       <th id="T_12c50_level0_col17" class="col_heading level0 col17" >standardscaler__Edges_Index</th>
#       <th id="T_12c50_level0_col18" class="col_heading level0 col18" >standardscaler__Empty_Index</th>
#       <th id="T_12c50_level0_col19" class="col_heading level0 col19" >standardscaler__Square_Index</th>
#       <th id="T_12c50_level0_col20" class="col_heading level0 col20" >standardscaler__Outside_X_Index</th>
#       <th id="T_12c50_level0_col21" class="col_heading level0 col21" >standardscaler__Edges_X_Index</th>
#       <th id="T_12c50_level0_col22" class="col_heading level0 col22" >standardscaler__Edges_Y_Index</th>
#       <th id="T_12c50_level0_col23" class="col_heading level0 col23" >standardscaler__LogOfAreas</th>
#       <th id="T_12c50_level0_col24" class="col_heading level0 col24" >standardscaler__Log_X_Index</th>
#       <th id="T_12c50_level0_col25" class="col_heading level0 col25" >standardscaler__Log_Y_Index</th>
#       <th id="T_12c50_level0_col26" class="col_heading level0 col26" >standardscaler__Orientation_Index</th>
#       <th id="T_12c50_level0_col27" class="col_heading level0 col27" >standardscaler__Luminosity_Index</th>
#       <th id="T_12c50_level0_col28" class="col_heading level0 col28" >standardscaler__SigmoidOfAreas</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12c50_level0_row0" class="row_heading level0 row0" >17174</th>
#       <td id="T_12c50_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_12c50_row0_col1" class="data row0 col1" >0.000</td>
#       <td id="T_12c50_row0_col2" class="data row0 col2" >0.000</td>
#       <td id="T_12c50_row0_col3" class="data row0 col3" >0.000</td>
#       <td id="T_12c50_row0_col4" class="data row0 col4" >1.000</td>
#       <td id="T_12c50_row0_col5" class="data row0 col5" >-0.454</td>
#       <td id="T_12c50_row0_col6" class="data row0 col6" >-0.457</td>
#       <td id="T_12c50_row0_col7" class="data row0 col7" >-0.450</td>
#       <td id="T_12c50_row0_col8" class="data row0 col8" >-1.257</td>
#       <td id="T_12c50_row0_col9" class="data row0 col9" >-1.402</td>
#       <td id="T_12c50_row0_col10" class="data row0 col10" >-0.209</td>
#       <td id="T_12c50_row0_col11" class="data row0 col11" >-0.208</td>
#       <td id="T_12c50_row0_col12" class="data row0 col12" >-0.320</td>
#       <td id="T_12c50_row0_col13" class="data row0 col13" >0.040</td>
#       <td id="T_12c50_row0_col14" class="data row0 col14" >-0.326</td>
#       <td id="T_12c50_row0_col15" class="data row0 col15" >-0.710</td>
#       <td id="T_12c50_row0_col16" class="data row0 col16" >-0.120</td>
#       <td id="T_12c50_row0_col17" class="data row0 col17" >-0.995</td>
#       <td id="T_12c50_row0_col18" class="data row0 col18" >-0.972</td>
#       <td id="T_12c50_row0_col19" class="data row0 col19" >1.087</td>
#       <td id="T_12c50_row0_col20" class="data row0 col20" >-0.489</td>
#       <td id="T_12c50_row0_col21" class="data row0 col21" >0.075</td>
#       <td id="T_12c50_row0_col22" class="data row0 col22" >0.764</td>
#       <td id="T_12c50_row0_col23" class="data row0 col23" >-0.495</td>
#       <td id="T_12c50_row0_col24" class="data row0 col24" >-0.501</td>
#       <td id="T_12c50_row0_col25" class="data row0 col25" >-0.596</td>
#       <td id="T_12c50_row0_col26" class="data row0 col26" >0.086</td>
#       <td id="T_12c50_row0_col27" class="data row0 col27" >-0.659</td>
#       <td id="T_12c50_row0_col28" class="data row0 col28" >-0.849</td>
#     </tr>
#     <tr>
#       <th id="T_12c50_level0_row1" class="row_heading level0 row1" >8711</th>
#       <td id="T_12c50_row1_col0" class="data row1 col0" >1.000</td>
#       <td id="T_12c50_row1_col1" class="data row1 col1" >0.000</td>
#       <td id="T_12c50_row1_col2" class="data row1 col2" >1.000</td>
#       <td id="T_12c50_row1_col3" class="data row1 col3" >0.000</td>
#       <td id="T_12c50_row1_col4" class="data row1 col4" >0.000</td>
#       <td id="T_12c50_row1_col5" class="data row1 col5" >-0.455</td>
#       <td id="T_12c50_row1_col6" class="data row1 col6" >-0.367</td>
#       <td id="T_12c50_row1_col7" class="data row1 col7" >-0.445</td>
#       <td id="T_12c50_row1_col8" class="data row1 col8" >0.675</td>
#       <td id="T_12c50_row1_col9" class="data row1 col9" >0.683</td>
#       <td id="T_12c50_row1_col10" class="data row1 col10" >-0.795</td>
#       <td id="T_12c50_row1_col11" class="data row1 col11" >-0.797</td>
#       <td id="T_12c50_row1_col12" class="data row1 col12" >-0.264</td>
#       <td id="T_12c50_row1_col13" class="data row1 col13" >0.006</td>
#       <td id="T_12c50_row1_col14" class="data row1 col14" >2.537</td>
#       <td id="T_12c50_row1_col15" class="data row1 col15" >1.612</td>
#       <td id="T_12c50_row1_col16" class="data row1 col16" >0.065</td>
#       <td id="T_12c50_row1_col17" class="data row1 col17" >0.168</td>
#       <td id="T_12c50_row1_col18" class="data row1 col18" >-0.200</td>
#       <td id="T_12c50_row1_col19" class="data row1 col19" >1.410</td>
#       <td id="T_12c50_row1_col20" class="data row1 col20" >-0.425</td>
#       <td id="T_12c50_row1_col21" class="data row1 col21" >-0.444</td>
#       <td id="T_12c50_row1_col22" class="data row1 col22" >-1.194</td>
#       <td id="T_12c50_row1_col23" class="data row1 col23" >-0.523</td>
#       <td id="T_12c50_row1_col24" class="data row1 col24" >-0.178</td>
#       <td id="T_12c50_row1_col25" class="data row1 col25" >-0.674</td>
#       <td id="T_12c50_row1_col26" class="data row1 col26" >-0.327</td>
#       <td id="T_12c50_row1_col27" class="data row1 col27" >2.938</td>
#       <td id="T_12c50_row1_col28" class="data row1 col28" >-0.370</td>
#     </tr>
#     <tr>
#       <th id="T_12c50_level0_row2" class="row_heading level0 row2" >12477</th>
#       <td id="T_12c50_row2_col0" class="data row2 col0" >0.000</td>
#       <td id="T_12c50_row2_col1" class="data row2 col1" >1.000</td>
#       <td id="T_12c50_row2_col2" class="data row2 col2" >0.000</td>

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
# ">
#     <b><span style="color: #780D0D;">&#x25FC</span> Dataset Ready</b>
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
# ">
#     So, we brought the problem to the multiclass and checked there were no missing values and duplicated samples. Furthermore, we found out that some features are, in fact, categorical, and both training and test datasets follow the same distribution and include outliers in several features. Therefore, we write a simple preprocessing stage to rescale data, encode it, and eliminate extreme outliers by percentile clipping from one side. We also have some clusters here, but let's leave this for now. <b>Now, let's write Optua tuner and see what we can achieve with a casual approach like the one described.</b>
# </p>

# %% [markdown]
# ## <b> <span style="font-family: 'JetBrains Mono'; color: #4A4B52">2.2</span> <span style='color: #780D0D'>|</span> <span style="font-family: 'JetBrains Mono'; color: #4A4B52">Tuner Interface</span></b><a class="anchor" id="tuner_interface"></a> [↑](#top)

# %% [markdown]
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
# ">
#     <b>Below, I define the tuner interface and LightGBM tuner based on Optuna. You can skip these subsections.</b>
# </p>

# %%
LOG_FMT = "%(asctime)s - %(name)s - %(levelname)s - %(message)s"
DATE_FMT = "%Y-%m-%d %H:%M:%S"
logging.basicConfig(level=logging.INFO, format=LOG_FMT, datefmt=DATE_FMT, stream=sys.stdout)

Model = TypeVar("Model")
ModelStudy = namedtuple("ModelStudy", ["hps", "study"])

# %%
class Tuner(Protocol):
    logger: Logger
    show_frozen: bool

    @abstractmethod
    def objective(self, trial: Trial, seed: int = 42) -> Any:
        """The `objective()` to be optimized by Optuna."""

    @abstractmethod
    def define_hps(self, trial: Trial, seed: int = 42) -> dict[str, Any]:
        """Defines hyperparameters for the model."""

    def run_study(
        self,
        *,
        direction: str | StudyDirection,
        n_trials: int | None = None,
        timeout: float | None = None,
        seed: int = 42,
    ) -> tuple[dict[str, Any], Study]:
        sampler = samplers.TPESampler(seed=seed)
        study = optuna.create_study(direction=direction, sampler=sampler)
        study.optimize(
            func=partial(self.objective, seed=seed),
            n_trials=n_trials,
            timeout=timeout,
            callbacks=[self._logging_callback],
            n_jobs=-1,
            gc_after_trial=True,
        )
        hps = study.best_trial.user_attrs | study.best_params
        return hps, study

    def tune(
        self,
        *,
        model_name: str,
        seeds: Iterable[int],
        direction: str | StudyDirection,
        n_trials: int | None = None,
        timeout: float | None = None,
    ) -> dict[int, ModelStudy]:
        models = dict()
        models_path = Path("models/")
        models_path.mkdir(parents=True, exist_ok=True)

        for seed in seeds:
            self.logger.info(f"Fine Tuning with Seed: {seed!r}")
            best_hps, study = self.run_study(
                direction=direction, n_trials=n_trials, timeout=timeout, seed=seed
            )
            models[seed] = ModelStudy(best_hps, study)
            model_id = f"{model_name}_{seed}_{time.strftime('run_%Y_%m_%d_%H_%M_%S')}.yaml"
            with open(models_path / model_id, "w") as f:
                yaml.dump(best_hps, f)
            self.logger.info(f"Saving: {model_id!r}\n")

        return models

    def __call__(
        self,
        *,
        model_name: str,
        seeds: Iterable[int],
        direction: str | StudyDirection,
        n_trials: int | None = None,
        timeout: float | None = None,
    ) -> dict[int, ModelStudy]:
        return self.tune(
            model_name=model_name,
            seeds=seeds,
            direction=direction,
            n_trials=n_trials,
            timeout=timeout,
        )

    def _logging_callback(self, study: Study, frozen_trial: FrozenTrial) -> None:
        previous_best_value = study.user_attrs.get("previous_best_value", None)
        headline = f"Trial: {frozen_trial.number:03} - Best Value: {frozen_trial.value:.5f}"
        hps = frozen_trial.params
        if self.show_frozen:
            hps = frozen_trial.user_attrs | hps
        hps_pattern = "\n".join(f"{' ':>5}{k!r}: {v!r}," for k, v in hps.items())
        if not previous_best_value == study.best_value:
            study.set_user_attr("previous_best_value", study.best_value)
            self.logger.info(headline + "\n{\n" + hps_pattern + "\n}")

# %% [markdown]
# ## <b> <span style="font-family: 'JetBrains Mono'; color: #4A4B52">2.3</span> <span style='color: #780D0D'>|</span> <span style="font-family: 'JetBrains Mono'; color: #4A4B52">Actual Tuner</span></b><a class="anchor" id="actual_tuner"></a> [↑](#top)

# %%
def lgb_roc_auc_ovr(preds, dataset):
    ground_truth = dataset.get_label()
    roc_auc = roc_auc_score(ground_truth, preds, average="macro", multi_class="ovr")
    return "roc_auc_ovr", roc_auc, True  # Higher is better - True.


def xgb_roc_auc_ovr(preds, dataset):
    ground_truth = dataset.get_label()
    roc_auc = roc_auc_score(ground_truth, preds, average="macro", multi_class="ovr")
    return "roc_auc_ovr", roc_auc

# %%
NUM_ITERATIONS = 1000
EARLY_STOPPING_ROUNDS = 20
MIN_DELTA = 1e-4


class LGBMTuner(Tuner):
    def __init__(
        self,
        X: pd.DataFrame,
        y: np.ndarray,
        preprocess: Pipeline | None = None,
        show_frozen: bool = False,
    ) -> None:
        self.X = X
        self.y = y
        self.preprocess = preprocess
        self.show_frozen = show_frozen
        self.logger = logging.getLogger(self.__class__.__name__)

    def objective(self, trial: Trial, seed: int = 42) -> Any:
        X, y = self.X, self.y
        hps = self.define_hps(trial, seed)
        y_proba = np.zeros((len(y), len(np.unique(y))), dtype=np.float32)
        skfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)

        for train_ids, test_ids in skfold.split(X, y):
            X_train, y_train = X.iloc[train_ids], y[train_ids]
            X_test, y_test = X.iloc[test_ids], y[test_ids]
            X_train, X_valid, y_train, y_valid = train_test_split(
                X_train, y_train, test_size=0.15, stratify=y_train, random_state=seed
            )

            if self.preprocess is not None:
                X_train = self.preprocess.fit_transform(X_train)
                X_valid = self.preprocess.transform(X_valid)
                X_test = self.preprocess.transform(X_test)

            train_set = lgb.Dataset(X_train, label=y_train)
            valid_set = lgb.Dataset(X_valid, label=y_valid, reference=train_set)

            model = lgb.train(
                params=hps,
                train_set=train_set,
                valid_sets=[train_set, valid_set],
                valid_names=["train", "valid"],
                num_boost_round=NUM_ITERATIONS,
                feval=lgb_roc_auc_ovr,  # type: ignore
                callbacks=[
                    lgb.early_stopping(
                        stopping_rounds=EARLY_STOPPING_ROUNDS,
                        min_delta=MIN_DELTA,
                        verbose=False,
                        first_metric_only=True,  # No matter since we have only one metric.
                    ),
                ],
            )
            y_proba[test_ids] = model.predict(X_test)

        return roc_auc_score(y, y_proba, average="macro", multi_class="ovr")

    def define_hps(self, trial: Trial, seed: int = 42) -> dict[str, Any]:
        frozen_hps = {
            "objective": "multiclass",
            "importance_type": "gain",  # The total gain across all splits the feature is used in.
            "metric": "None",  # We will use custom metric for early stopping.
            "bagging_freq": 1,
            "num_class": 8,
            "verbose": -1,
            "seed": seed,
        }
        for k, v in frozen_hps.items():
            trial.set_user_attr(k, v)
        hps = {
            "max_depth": trial.suggest_int("max_depth", 2, 6),
            "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 32, 512, step=32),
            "learning_rate": trial.suggest_float("learning_rate", 0.05, 0.5),
            "lambda_l1": trial.suggest_float("lambda_l1", 0.05, 20, log=True),
            "lambda_l2": trial.suggest_float("lambda_l2", 0.05, 20, log=True),
            "bagging_fraction": trial.suggest_float("bagging_fraction", 0.1, 0.8, step=0.1),
            "feature_fraction": trial.suggest_float("feature_fraction", 0.1, 0.8, step=0.1),
        }
        return frozen_hps | hps

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
# ">
#     <b><span style="color: #780D0D;">&#x25FC</span> Tuner's Objective</b>
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
# ">
#     Here, I define the <code>objective()</code> method using ordinary 5-fold stratified cross-validation. Furthermore, I should include original data only in the training process but not in the validation and test subsets. <b>The purpose of it is to see how the model trained on both datasets handles evaluation on a test subset which does not contain original samples (this situation corresponds to the leaderboard's assessement). Nevertheless, I don't fancy it any more, maybe later.</b>
# </p>

# %%
optuna.logging.set_verbosity(optuna.logging.ERROR)

encoder = LabelEncoder()
X = train_extended.drop(columns=["Category", "Source"])
y = encoder.fit_transform(train_extended.Category)

seeds = (0,)
timeout = 60 * 60 * 2  # 2 hours
n_trials = 10

lgbm_tuner = LGBMTuner(X, y, preprocess=preprocess, show_frozen=False)  # type: ignore
models = lgbm_tuner.tune(
    model_name="xgb",
    seeds=seeds,
    direction="maximize",
    n_trials=n_trials,
    timeout=timeout,
)

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
# ">
#     <b><span style="color: #780D0D;">&#x25FC</span> Warmup Hyperparameters</b>
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
# ">
#     On Kaggle, I run the tuner just ten times only to show you how it works. However, I set 2-hour timeout for local tuning in the case of <code>LightGBM</code> and <code>XGBoost</code>. Here are found hyperparameters:</b>
# </p>

# %%
# with open("models/lgbm_0_run_2024_03_15_11_21_42.yaml", "r") as f:
#     lgb_warmup_hps = yaml.safe_load(f)

# with open("models/xgb_0_run_2024_03_15_14_14_16.yaml", "r") as f:
#     xgb_warmup_hps = yaml.safe_load(f)

lgb_warmup_hps = {
    "bagging_fraction": 0.8,
    "bagging_freq": 1,
    "feature_fraction": 0.4,
    "importance_type": "gain",
    "lambda_l1": 3.614072222511715,
    "lambda_l2": 0.9192133346716994,
    "learning_rate": 0.06554069674764376,
    "max_depth": 3,
    "metric": "None",
    "min_data_in_leaf": 192,
    "num_class": 8,
    "objective": "multiclass",
    "seed": 0,
    "verbose": -1,
}

xgb_warmup_hps = {
    "colsample_bylevel": 0.8,
    "colsample_bytree": 0.30000000000000004,
    "disable_default_eval_metric": True,
    "importance_type": "gain",
    "learning_rate": 0.11826206587043206,
    "max_depth": 4,
    "min_child_weight": 8.668923783377751,
    "num_class": 8,
    "objective": "multi:softprob",
    "random_state": 0,
    "reg_alpha": 1.3901913096753962,
    "reg_lambda": 8.621688949357258,
    "subsample": 0.8,
    "verbosity": 0,
}

# %% [markdown]
# ## <b> <span style="font-family: 'JetBrains Mono'; color: #4A4B52">2.4</span> <span style='color: #780D0D'>|</span> <span style="font-family: 'JetBrains Mono'; color: #4A4B52">Warmup Cross-Validation</span></b><a class="anchor" id="warmup_cross_validation"></a> [↑](#top)

# %% [markdown]
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
# ">
#     <b>Let's write some simple functions for history plotting and training.</b>
# </p>

# %%
def draw_valid_curves(
    history, *, ax, title, xlabel, ylabel, show_legend=True, legend_loc="upper left"
):
    linestyles = iter(tuple(lines.lineStyles))
    colors = iter(COLOR_SCHEME)
    for eval_set, metrics in history.items():
        for metric, values in metrics.items():
            ax.plot(
                values,
                label=eval_set.title(),
                color=next(colors),
                linestyle=next(linestyles),
            )

    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.spines["bottom"].set_visible(False)
    ax.spines["left"].set_visible(False)
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)

    if show_legend:
        ax.legend(loc=legend_loc)

    return ax

# %%
def train_lgb_xgb(
    *,
    X_train,
    y_train,
    X_valid,
    y_valid,
    lgb_params,
    xgb_params,
    lgb_feval,
    xgb_feval,
    num_iterations,
    early_stopping_rounds,
    min_delta,
):
    lgb_history = dict()
    lgb_train_set = lgb.Dataset(X_train, label=y_train)
    lgb_valid_set = lgb.Dataset(X_valid, label=y_valid, reference=lgb_train_set)
    lgb_model = lgb.train(
        params=lgb_params,
        train_set=lgb_train_set,
        num_boost_round=num_iterations,
        valid_sets=[lgb_train_set, lgb_valid_set],
        valid_names=["train", "valid"],
        feval=lgb_feval,  # type: ignore
        callbacks=[
            lgb.record_evaluation(lgb_history),
            lgb.early_stopping(
                stopping_rounds=early_stopping_rounds,
                min_delta=min_delta,
                first_metric_only=True,  # No matter since we have only one metric.
                verbose=False,
            ),
        ],
    )

    xgb_history = dict()
    xgb_train_set = xgb.DMatrix(X_train, label=y_train)
    xgb_valid_set = xgb.DMatrix(X_valid, label=y_valid)
    xgb_model = xgb.train(
        params=xgb_params,
        dtrain=xgb_train_set,
        num_boost_round=num_iterations,
        evals=[(xgb_train_set, "train"), (xgb_valid_set, "valid")],
        evals_result=xgb_history,
        custom_metric=xgb_feval,
        verbose_eval=False,
        callbacks=[
            xgb.callback.EarlyStopping(  # type: ignore
                rounds=early_stopping_rounds,
                min_delta=min_delta,
                data_name="valid",
                maximize=True,
            )
        ],
    )

    return lgb_model, lgb_history, xgb_model, xgb_history

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
# ">
#     <b><span style="color: #780D0D;">&#x25FC</span> Cross-Validation Scheme</b>
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
# ">
#     CV scheme is the same as for the tuner (must be), but remember that the label encoder encodes classes not exactly in the same order as in the competition LB. This is not the problem for the training and inference. Nevertheless, we need to remember to submit the correct order in submission, which you will see later.
# </p>

# %%
encoder = LabelEncoder()
X = train_extended.drop(columns=["Category", "Source"])
y = np.asarray(encoder.fit_transform(train_extended.Category))

seed = 0
logger = logging.getLogger("CV")
y_proba = np.zeros((len(y), len(np.unique(y))), dtype=np.float32)
skfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)

for train_ids, test_ids in skfold.split(X, y):
    X_train, y_train = X.iloc[train_ids], y[train_ids]
    X_test, y_test = X.iloc[test_ids], y[test_ids]
    X_train, X_valid, y_train, y_valid = train_test_split(
        X_train, y_train, test_size=0.15, stratify=y_train, random_state=seed
    )

    X_train = preprocess.fit_transform(X_train)
    X_valid = preprocess.transform(X_valid)
    X_test = preprocess.transform(X_test)

    lgb_model, lgb_history, xgb_model, xgb_history = train_lgb_xgb(
        X_train=X_train,
        y_train=y_train,
        X_valid=X_valid,
        y_valid=y_valid,
        lgb_params=lgb_warmup_hps,
        xgb_params=xgb_warmup_hps,
        lgb_feval=lgb_roc_auc_ovr,
        xgb_feval=xgb_roc_auc_ovr,
        num_iterations=NUM_ITERATIONS,
        early_stopping_rounds=EARLY_STOPPING_ROUNDS,
        min_delta=MIN_DELTA,
    )

    lgb_val_auc = lgb_model.best_score["valid"]["roc_auc_ovr"]
    xgb_val_auc = xgb_model.best_score
    logger.info(
        f"Results\n"
        f"Train Shape: {X_train.shape} - Val Shape: {X_valid.shape} - Test Shape: {X_test.shape}\n"
        f"LightGBM - Best Iter: {lgb_model.best_iteration:3} - Val ROC-AUC: {lgb_val_auc:.5f}\n"
        f"XGBoost  - Best Iter: {xgb_model.best_iteration:3} - Val ROC-AUC: {xgb_val_auc:.5f}"
    )

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11.5, 5.5), tight_layout=True, sharey=True)
    draw_valid_curves(
        lgb_history, ax=ax1, title="LightGBM", xlabel="Iteration", ylabel="ROC-AUC-OVR"
    )
    draw_valid_curves(
        xgb_history, ax=ax2, title="XGBoost", xlabel="Iteration", ylabel="", show_legend=False
    )
    plt.show()

    y_lgb = lgb_model.predict(X_test, num_iteration=lgb_model.best_iteration)
    y_xgb = xgb_model.predict(xgb.DMatrix(X_test), iteration_range=(0, xgb_model.best_iteration))
    y_proba[test_ids] = (y_lgb + y_xgb) / 2

oof_roc_auc = roc_auc_score(y, y_proba, average="macro", multi_class="ovr")
logger.info(f"Final Out-of-Fold ROC-AUC: {oof_roc_auc:.5f}")
# Out:
# 2024-03-15 17:17:37 - CV - INFO - Results
# Train Shape: (14374, 29) - Valid Shape: (2537, 29) - Test Shape: (4228, 29)
# LightGBM - Best Iter: 148 - Valid ROC-AUC: 0.86685
# XGBoost  - Best Iter: 142 - Valid ROC-AUC: 0.86880
# 2024-03-15 17:18:09 - CV - INFO - Results
# Train Shape: (14374, 29) - Valid Shape: (2537, 29) - Test Shape: (4228, 29)
# LightGBM - Best Iter: 136 - Valid ROC-AUC: 0.86811
# XGBoost  - Best Iter: 134 - Valid ROC-AUC: 0.86575
# 2024-03-15 17:18:38 - CV - INFO - Results
# Train Shape: (14374, 29) - Valid Shape: (2537, 29) - Test Shape: (4228, 29)
# LightGBM - Best Iter: 116 - Valid ROC-AUC: 0.86814
# XGBoost  - Best Iter: 120 - Valid ROC-AUC: 0.86988
# 2024-03-15 17:19:07 - CV - INFO - Results
# Train Shape: (14374, 29) - Valid Shape: (2537, 29) - Test Shape: (4228, 29)
# LightGBM - Best Iter: 105 - Valid ROC-AUC: 0.86709
# XGBoost  - Best Iter: 123 - Valid ROC-AUC: 0.86931
# 2024-03-15 17:19:41 - CV - INFO - Results
# Train Shape: (14375, 29) - Valid Shape: (2537, 29) - Test Shape: (4227, 29)
# LightGBM - Best Iter: 132 - Valid ROC-AUC: 0.86865
# XGBoost  - Best Iter: 163 - Valid ROC-AUC: 0.86783
# 2024-03-15 17:19:41 - CV - INFO - Final Out-of-Fold ROC-AUC: 0.86783

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
# ">
#     <b><span style="color: #780D0D;">&#x25FC</span> Cross-Validation Results</b>
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
# ">
#     <b>I will step into the future and tell you that out-of-fold and CV folds results don't match the public LB result, so something stinks here.</b> But what? Perhaps the situation in the public LB is more straightforward than in our folds, or maybe it's the result of including the original dataset in training and validation on partially that data. <b>Nevermind, let's have a look at confusion matrix.</b>
# </p>

# %%
conf_matrix = confusion_matrix(y, y_proba.argmax(axis=1))
classes = encoder.classes_

fig = go.Figure()
fig.add_heatmap(
    z=conf_matrix,
    x=classes,
    y=classes,
    name="ConfusionMatrix",
    text=conf_matrix,
    texttemplate="%{text}",
    xgap=5,
    ygap=5,
    showscale=True,
    colorbar_len=1.03,
    colorscale=COLOR_SCHEME[[0, 2, 1]],
)
fig.update_yaxes(title="True Label", autorange="reversed", tickangle=-90)
fig.update_xaxes(title="Predicted Label")
fig.update_layout(
    font_color=FONT_COLOR,
    title="LightGBM & XGBoost Ensemble - Confusion Matrix<br>"
    "<span style='font-size: 75%; font-weight: bold;'>"
    "'Bumps' and 'Other_Faults' are mismatched in both ways. "
    "Maybe separate classifier only for these classes?</span>",
    title_font_size=18,
    plot_bgcolor=BACKGROUND_COLOR,
    paper_bgcolor=BACKGROUND_COLOR,
    height=720,
    width=720,
)
save_and_show_fig(fig, "ensemble_confusion_matrix")

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
# ">
#     <b><span style="color: #780D0D;">&#x25FC</span> Confusion Matrix</b>
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
# ">
#     The model completely fails to cope with the 'Bumps' and 'Other_Faults' classes. These are mismatched in both ways. So, this is interesting somehow. Perhaps we should focus on samples with these two classes only and find out what's going on there. <b>Maybe a separate classifier trained only on these classes should be considered?</b><br><br>Bear it for a moment, and let's submit predictions for the test dataset.
# </p>

# %% [markdown]
# ## <b> <span style="font-family: 'JetBrains Mono'; color: #4A4B52">2.5</span> <span style='color: #780D0D'>|</span> <span style="font-family: 'JetBrains Mono'; color: #4A4B52">Final Training</span></b><a class="anchor" id="final_training"></a> [↑](#top)

# %%
seed = 0
encoder = LabelEncoder()
X = train_extended.drop(columns=["Category", "Source"])
y = np.asarray(encoder.fit_transform(train_extended.Category))

X_train, X_valid, y_train, y_valid = train_test_split(
    X, y, test_size=0.15, stratify=y, random_state=seed
)

X_train = preprocess.fit_transform(X_train)
X_valid = preprocess.transform(X_valid)

lgb_model, lgb_history, xgb_model, xgb_history = train_lgb_xgb(
    X_train=X_train,
    y_train=y_train,
    X_valid=X_valid,
    y_valid=y_valid,
    lgb_params=lgb_warmup_hps,
    xgb_params=xgb_warmup_hps,
    lgb_feval=lgb_roc_auc_ovr,
    xgb_feval=xgb_roc_auc_ovr,
    num_iterations=NUM_ITERATIONS,
    early_stopping_rounds=EARLY_STOPPING_ROUNDS,
    min_delta=MIN_DELTA,
)

lgb_val_auc = lgb_model.best_score["valid"]["roc_auc_ovr"]
xgb_val_auc = xgb_model.best_score
logger = logging.getLogger("Final Training")
logger.info(
    f"Results\n"
    f"Train Shape: {X_train.shape} - Valid Shape: {X_valid.shape}\n"
    f"LightGBM - Best Iter: {lgb_model.best_iteration:3} - Val ROC-AUC: {lgb_val_auc:.5f}\n"
    f"XGBoost  - Best Iter: {xgb_model.best_iteration:3} - Val ROC-AUC: {xgb_val_auc:.5f}"
)
# Out:
# 2024-03-15 21:26:08 - Final Training - INFO - Results
# Train Shape: (17968, 29) - Valid Shape: (3171, 29)
# LightGBM - Best Iter: 197 - Val ROC-AUC: 0.86209
# XGBoost  - Best Iter:  98 - Val ROC-AUC: 0.86228

# %%
X_test = preprocess.transform(test)

y_lgb = lgb_model.predict(X_test, num_iteration=lgb_model.best_iteration)
y_xgb = xgb_model.predict(xgb.DMatrix(X_test), iteration_range=(0, xgb_model.best_iteration))

y_test = (y_lgb + y_xgb) / 2

# %%
# Order for classes from Label Encoder and LB are different.
lb_order = ["Pastry", "Z_Scratch", "K_Scatch", "Stains", "Dirtiness", "Bumps", "Other_Faults"]
submission = pd.DataFrame(y_test, columns=encoder.classes_, index=test.index)
submission = submission[lb_order]
submission.to_csv("submission.csv")
get_pretty_frame(submission.head())
# Out:
# <style type="text/css">
# #T_d85e4 .index_name {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_d85e4 th:not(.index_name) {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_d85e4 td {
#   color: #4A4B52;
#   font-weight: bold;
# }
# </style>
# <table id="T_d85e4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d85e4_level0_col0" class="col_heading level0 col0" >Pastry</th>
#       <th id="T_d85e4_level0_col1" class="col_heading level0 col1" >Z_Scratch</th>
#       <th id="T_d85e4_level0_col2" class="col_heading level0 col2" >K_Scatch</th>
#       <th id="T_d85e4_level0_col3" class="col_heading level0 col3" >Stains</th>
#       <th id="T_d85e4_level0_col4" class="col_heading level0 col4" >Dirtiness</th>
#       <th id="T_d85e4_level0_col5" class="col_heading level0 col5" >Bumps</th>
#       <th id="T_d85e4_level0_col6" class="col_heading level0 col6" >Other_Faults</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d85e4_level0_row0" class="row_heading level0 row0" >19219</th>
#       <td id="T_d85e4_row0_col0" class="data row0 col0" >0.530</td>
#       <td id="T_d85e4_row0_col1" class="data row0 col1" >0.002</td>
#       <td id="T_d85e4_row0_col2" class="data row0 col2" >0.003</td>
#       <td id="T_d85e4_row0_col3" class="data row0 col3" >0.000</td>
#       <td id="T_d85e4_row0_col4" class="data row0 col4" >0.013</td>
#       <td id="T_d85e4_row0_col5" class="data row0 col5" >0.138</td>
#       <td id="T_d85e4_row0_col6" class="data row0 col6" >0.281</td>
#     </tr>
#     <tr>
#       <th id="T_d85e4_level0_row1" class="row_heading level0 row1" >19220</th>
#       <td id="T_d85e4_row1_col0" class="data row1 col0" >0.229</td>
#       <td id="T_d85e4_row1_col1" class="data row1 col1" >0.034</td>
#       <td id="T_d85e4_row1_col2" class="data row1 col2" >0.009</td>
#       <td id="T_d85e4_row1_col3" class="data row1 col3" >0.001</td>
#       <td id="T_d85e4_row1_col4" class="data row1 col4" >0.204</td>
#       <td id="T_d85e4_row1_col5" class="data row1 col5" >0.144</td>
#       <td id="T_d85e4_row1_col6" class="data row1 col6" >0.343</td>
#     </tr>
#     <tr>
#       <th id="T_d85e4_level0_row2" class="row_heading level0 row2" >19221</th>
#       <td id="T_d85e4_row2_col0" class="data row2 col0" >0.003</td>
#       <td id="T_d85e4_row2_col1" class="data row2 col1" >0.038</td>
#       <td id="T_d85e4_row2_col2" class="data row2 col2" >0.035</td>
#       <td id="T_d85e4_row2_col3" class="data row2 col3" >0.001</td>
#       <td id="T_d85e4_row2_col4" class="data row2 col4" >0.011</td>
#       <td id="T_d85e4_row2_col5" class="data row2 col5" >0.303</td>
#       <td id="T_d85e4_row2_col6" class="data row2 col6" >0.525</td>
#     </tr>
#     <tr>
#       <th id="T_d85e4_level0_row3" class="row_heading level0 row3" >19222</th>
#       <td id="T_d85e4_row3_col0" class="data row3 col0" >0.148</td>
#       <td id="T_d85e4_row3_col1" class="data row3 col1" >0.007</td>
#       <td id="T_d85e4_row3_col2" class="data row3 col2" >0.002</td>
#       <td id="T_d85e4_row3_col3" class="data row3 col3" >0.003</td>
#       <td id="T_d85e4_row3_col4" class="data row3 col4" >0.013</td>
#       <td id="T_d85e4_row3_col5" class="data row3 col5" >0.361</td>
#       <td id="T_d85e4_row3_col6" class="data row3 col6" >0.433</td>
#     </tr>
#     <tr>
#       <th id="T_d85e4_level0_row4" class="row_heading level0 row4" >19223</th>
#       <td id="T_d85e4_row4_col0" class="data row4 col0" >0.003</td>
#       <td id="T_d85e4_row4_col1" class="data row4 col1" >0.006</td>
#       <td id="T_d85e4_row4_col2" class="data row4 col2" >0.002</td>
#       <td id="T_d85e4_row4_col3" class="data row4 col3" >0.005</td>
#       <td id="T_d85e4_row4_col4" class="data row4 col4" >0.006</td>
#       <td id="T_d85e4_row4_col5" class="data row4 col5" >0.605</td>
#       <td id="T_d85e4_row4_col6" class="data row4 col6" >0.332</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # <b> <span style="font-family: 'JetBrains Mono'; color: #4A4B52">3</span> <span style='color: #780D0D'>|</span> <span style="font-family: 'JetBrains Mono'; color: #4A4B52">Summary</span></b><a class="anchor" id="summary"></a> [↑](#top)

# %% [markdown]
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
# ">
#     <b>That's all for now; I hope you like it. If you have any questions, let me know in the comments section.</b>
# </p>

# %%
            # xgb_train_set = xgb.DMatrix(X_train, label=y_train)
            # xgb_valid_set = xgb.DMatrix(X_valid, label=y_valid)
            
            # model = xgb.train(
            #     params=hps,
            #     dtrain=xgb_train_set,
            #     num_boost_round=NUM_ITERATIONS,
            #     evals=[(xgb_train_set, "train"), (xgb_valid_set, "valid")],
            #     custom_metric=xgb_roc_auc_ovr,
            #     verbose_eval=False,
            #     callbacks=[
            #         xgb.callback.EarlyStopping(  # type: ignore
            #             rounds=EARLY_STOPPING_ROUNDS,
            #             min_delta=MIN_DELTA,
            #             data_name="valid",
            #             maximize=True,
            #         )
            #     ],
            # )
            
            # frozen_hps = {
            #     "objective": "multi:softprob",
            #     "importance_type": "gain",  # The total gain across all splits the feature is used in.
            #     "disable_default_eval_metric": True,  # We will use custom metric for early stopping.
            #     "num_class": 8,
            #     "verbosity": 0,
            #     "random_state": seed,
            # }
            # for k, v in frozen_hps.items():
            #     trial.set_user_attr(k, v)
            # hps = {
            #     "max_depth": trial.suggest_int("max_depth", 2, 6),
            #     "min_child_weight": trial.suggest_float("min_child_weight", 0.1, 10),
            #     "learning_rate": trial.suggest_float("learning_rate", 0.05, 0.5),
            #     "reg_alpha": trial.suggest_float("reg_alpha", 0.05, 20, log=True),
            #     "reg_lambda": trial.suggest_float("reg_lambda", 0.05, 20, log=True),
            #     "subsample": trial.suggest_float("subsample", 0.1, 0.8, step=0.1),
            #     "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.1, 0.8, step=0.1),
            #     "colsample_bytree": trial.suggest_float("colsample_bytree", 0.1, 0.8, step=0.1),
            # }
