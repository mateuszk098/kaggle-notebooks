# %% [markdown]
# <center><img src="https://raw.githubusercontent.com/mateuszk098/kaggle_notebooks/master/playground_series_s3e22/undraw_Working_late_re_0c3y.png" width=400px></center>
#
# # <p style="font-family: 'JetBrains Mono'; font-weight: bold; font-size: 125%; color: #4A4B52; text-align: center">Playground Series S3E22 - Horse Survival Classification</p>

# %%
# %load ../general_settings.py
import glob
import os
import shutil
import subprocess
import sys
import warnings
from array import array
from collections import defaultdict, namedtuple
from copy import copy
from functools import partial, singledispatch
from itertools import chain, combinations, product
from pathlib import Path
from time import strftime

import joblib
import matplotlib.pyplot as plt
import numpy as np
import optuna
import pandas as pd
import plotly.express as px
import plotly.figure_factory as ff
import plotly.graph_objects as go
import scipy.stats as stats
import seaborn as sns
import shap
from colorama import Fore, Style
from IPython.core.display import HTML, display_html
from plotly.subplots import make_subplots
from scipy.cluster.hierarchy import linkage
from scipy.spatial.distance import squareform

ON_KAGGLE = os.getenv("KAGGLE_KERNEL_RUN_TYPE") is not None

# Colorama settings.
CLR = (Style.BRIGHT + Fore.BLACK) if ON_KAGGLE else (Style.BRIGHT + Fore.WHITE)
RED = Style.BRIGHT + Fore.RED
BLUE = Style.BRIGHT + Fore.BLUE
CYAN = Style.BRIGHT + Fore.CYAN
RESET = Style.RESET_ALL

# Data Frame color theme.
FONT_COLOR = "#4A4B52"
BACKGROUND_COLOR = "#FFFCFA"

CELL_HOVER = {  # for row hover use <tr> instead of <td>
    "selector": "td:hover",
    "props": "background-color: #FFFCFA",
}
TEXT_HIGHLIGHT = {
    "selector": "td",
    "props": "color: #4A4B52; font-weight: bold",
}
INDEX_NAMES = {
    "selector": ".index_name",
    "props": "font-weight: normal; background-color: #FFFCFA; color: #4A4B52;",
}
HEADERS = {
    "selector": "th:not(.index_name)",
    "props": "font-weight: normal; background-color: #FFFCFA; color: #4A4B52;",
}
DF_STYLE = (INDEX_NAMES, HEADERS, TEXT_HIGHLIGHT)
DF_CMAP = sns.light_palette("#BAB8B8", as_cmap=True)

# Utility functions.
def download_from_kaggle(expr: list[str], directory: Path | None = None, /) -> None:
    if directory is None:
        directory = Path("data")
    if not isinstance(directory, Path):
        raise TypeError("The `directory` argument must be `Path` instance!")
    match expr:
        case ["kaggle", _, "download", *args] if args:
            directory.parent.mkdir(parents=True, exist_ok=True)
            filename = args[-1].split("/")[-1] + ".zip"
            if not (directory / filename).is_file():
                subprocess.run(expr)
                shutil.unpack_archive(filename, directory)
                shutil.move(filename, directory)
        case _:
            raise SyntaxError("Invalid expression!")


def get_interpolated_colors(color1: str, color2: str, /, num_colors: int = 2) -> list[str]:
    """Return `num_colors` interpolated beetwen `color1` and `color2`.
    Arguments need to be HEX."""

    def interpolate_color(color1, color2, t) -> str:
        r1, g1, b1 = int(color1[1:3], 16), int(color1[3:5], 16), int(color1[5:7], 16)
        r2, g2, b2 = int(color2[1:3], 16), int(color2[3:5], 16), int(color2[5:7], 16)
        r = int(r1 + (r2 - r1) * t)
        g = int(g1 + (g2 - g1) * t)
        b = int(b1 + (b2 - b1) * t)
        return f"#{r:02X}{g:02X}{b:02X}"

    num_colors = num_colors + 2
    return [interpolate_color(color1, color2, i / (num_colors - 1)) for i in range(num_colors)]


# Html highlight. Must be included at the end of all imports!
HTML(
    """
<style>
code {
    background: rgba(42, 53, 125, 0.10) !important;
    border-radius: 4px !important;
}
a {
    color: rgba(123, 171, 237, 1.0) !important;
}
ol.numbered-list {
  counter-reset: item;
}
ol.numbered-list li {
  display: block;
}
ol.numbered-list li:before {
  content: counters(item, '.') '. ';
  counter-increment: item;
}
</style>
"""
)
# Out:
# <style>
# code {
#     background: rgba(42, 53, 125, 0.10) !important;
#     border-radius: 4px !important;
# }
# a {
#     color: rgba(123, 171, 237, 1.0) !important;
# }
# ol.numbered-list {
#   counter-reset: item;
# }
# ol.numbered-list li {
#   display: block;
# }
# ol.numbered-list li:before {
#   content: counters(item, '.') '. ';
#   counter-increment: item;
# }
# </style>

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
# ">
#     <b>Competition Description</b> 📜
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
# ">
#     The dataset for this competition is a synthetic dataset based off of the <a href="https://www.kaggle.com/datasets/yasserh/horse-survival-dataset"><b>Horse Survival Dataset</b></a>. As we can read in the original dataset description, the main task of the dataset is to understand the data and assess whether a horse can survive or not based on medical conditions. The original dataset is rich in missing values and according to the author, this issue is a real problem there. Moreover, all indicators were converted into words to understand what they represent easily.
# </p>
#
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
# ">
#     <b>Task</b> 💡
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
# ">
#     This is a multiclass classification problem, where the main task is to predict the <code>Outcome</code> feature ($3$ classes) about horse health status. The competition evaluation metric is <a href="https://en.wikipedia.org/wiki/F-score"><b>Micro-Averaged F1-Score</b></a> (a harmonic mean of precision and recall):
#     \[F_1 =\frac{2}{\textrm{Precision}^{-1} + \textrm{Recall}^{-1}},\]
#     where <i>Micro-Averaged</i> means calculate metrics globally by counting the total true positives, false negatives and false positives.
# </p>
#
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
# ">
#     <b>Table of Contents</b> 📔
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
# ">
#     The table of contents provides pleasurable navigation through the whole notebook. You can easily navigate through sections and return to TOC. If you want quickly find out something about the dataset, just read the first section, i.e. <b>Quick Overview</b>.
# </p>
#
# <blockquote class="anchor" id="top" style="
#     margin-right: auto;
#     margin-left: auto;
#     padding: 10px;
#     background-color: #3A5A81;
#     border-radius: 2px;
#     border: 1px solid #3A5A81;
# ">
# <ol class="numbered-list" style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
#     color: #F2F2F0;
#     margin-top: 15px;
#     margin-bottom: 15px;
# ">
#     <li><a href="#quick_overview"><span style="color: #F2F2F0">Quick Overview</span></a>
#     <ol class="numbered-list" class="numbered-list" style="
#         font-size: 16px;
#         font-family: 'JetBrains Mono';
#         color: #F2F2F0;
#     ">
#         <li><a href="#data_reading_and_features_description"><span style="color: #F2F2F0">Data Reading &amp; Features Description</span></a></li>
#         <li><a href="#basic_numerical_properties_summaries"><span style="color: #F2F2F0">Basic Numerical Properties &amp; Summaries</span></a></li>
#     </ol>
#     </li>
# </ol>
# </blockquote>

# %% [markdown]
# # <b> <span style="font-family: 'JetBrains Mono'; color: #4A4B52">1</span> <span style='color: #3A5A81'>|</span> <span style="font-family: 'JetBrains Mono'; color: #4A4B52">Quick Overview</span></b><a class="anchor" id="quick_overview"></a> [↑](#top)

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
#     border-bottom: 2px solid #3A5A81;
# ">
#     <b>About Section</b> 💡
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
# ">
#     In this section, I provide a quick overview of the dataset. More detailed analysis will be done in subsequent sections.
# </p>

# %% [markdown]
# ## <b> <span style="font-family: 'JetBrains Mono'; color: #4A4B52">1.1</span> <span style='color: #3A5A81'>|</span> <span style="font-family: 'JetBrains Mono'; color: #4A4B52">Data Reading &amp; Features Description</span></b><a class="anchor" id="data_reading_and_features_description"></a> [↑](#top)

# %%
competition = "playground-series-s3e22"
expr = f"kaggle competitions download -c {competition}".split()

if not ON_KAGGLE:
    download_from_kaggle(expr)
    train_path = "data/train.csv"
    test_path = "data/test.csv"
else:
    train_path = f"/kaggle/input/{competition}/train.csv"
    test_path = f"/kaggle/input/{competition}/test.csv"

train = pd.read_csv(train_path, index_col="id", engine="pyarrow").rename(columns=str.title)
test = pd.read_csv(test_path, index_col="id", engine="pyarrow").rename(columns=str.title)

# %%
train.head().style.set_table_styles(DF_STYLE).format(precision=1)
# Out:
# <style type="text/css">
# #T_bd4d0 .index_name {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_bd4d0 th:not(.index_name) {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_bd4d0 td {
#   color: #4A4B52;
#   font-weight: bold;
# }
# </style>
# <table id="T_bd4d0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bd4d0_level0_col0" class="col_heading level0 col0" >Surgery</th>
#       <th id="T_bd4d0_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_bd4d0_level0_col2" class="col_heading level0 col2" >Hospital_Number</th>
#       <th id="T_bd4d0_level0_col3" class="col_heading level0 col3" >Rectal_Temp</th>
#       <th id="T_bd4d0_level0_col4" class="col_heading level0 col4" >Pulse</th>
#       <th id="T_bd4d0_level0_col5" class="col_heading level0 col5" >Respiratory_Rate</th>
#       <th id="T_bd4d0_level0_col6" class="col_heading level0 col6" >Temp_Of_Extremities</th>
#       <th id="T_bd4d0_level0_col7" class="col_heading level0 col7" >Peripheral_Pulse</th>
#       <th id="T_bd4d0_level0_col8" class="col_heading level0 col8" >Mucous_Membrane</th>
#       <th id="T_bd4d0_level0_col9" class="col_heading level0 col9" >Capillary_Refill_Time</th>
#       <th id="T_bd4d0_level0_col10" class="col_heading level0 col10" >Pain</th>
#       <th id="T_bd4d0_level0_col11" class="col_heading level0 col11" >Peristalsis</th>
#       <th id="T_bd4d0_level0_col12" class="col_heading level0 col12" >Abdominal_Distention</th>
#       <th id="T_bd4d0_level0_col13" class="col_heading level0 col13" >Nasogastric_Tube</th>
#       <th id="T_bd4d0_level0_col14" class="col_heading level0 col14" >Nasogastric_Reflux</th>
#       <th id="T_bd4d0_level0_col15" class="col_heading level0 col15" >Nasogastric_Reflux_Ph</th>
#       <th id="T_bd4d0_level0_col16" class="col_heading level0 col16" >Rectal_Exam_Feces</th>
#       <th id="T_bd4d0_level0_col17" class="col_heading level0 col17" >Abdomen</th>
#       <th id="T_bd4d0_level0_col18" class="col_heading level0 col18" >Packed_Cell_Volume</th>
#       <th id="T_bd4d0_level0_col19" class="col_heading level0 col19" >Total_Protein</th>
#       <th id="T_bd4d0_level0_col20" class="col_heading level0 col20" >Abdomo_Appearance</th>
#       <th id="T_bd4d0_level0_col21" class="col_heading level0 col21" >Abdomo_Protein</th>
#       <th id="T_bd4d0_level0_col22" class="col_heading level0 col22" >Surgical_Lesion</th>
#       <th id="T_bd4d0_level0_col23" class="col_heading level0 col23" >Lesion_1</th>
#       <th id="T_bd4d0_level0_col24" class="col_heading level0 col24" >Lesion_2</th>
#       <th id="T_bd4d0_level0_col25" class="col_heading level0 col25" >Lesion_3</th>
#       <th id="T_bd4d0_level0_col26" class="col_heading level0 col26" >Cp_Data</th>
#       <th id="T_bd4d0_level0_col27" class="col_heading level0 col27" >Outcome</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd4d0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bd4d0_row0_col0" class="data row0 col0" >yes</td>
#       <td id="T_bd4d0_row0_col1" class="data row0 col1" >adult</td>
#       <td id="T_bd4d0_row0_col2" class="data row0 col2" >530001</td>
#       <td id="T_bd4d0_row0_col3" class="data row0 col3" >38.1</td>
#       <td id="T_bd4d0_row0_col4" class="data row0 col4" >132.0</td>
#       <td id="T_bd4d0_row0_col5" class="data row0 col5" >24.0</td>
#       <td id="T_bd4d0_row0_col6" class="data row0 col6" >cool</td>
#       <td id="T_bd4d0_row0_col7" class="data row0 col7" >reduced</td>
#       <td id="T_bd4d0_row0_col8" class="data row0 col8" >dark_cyanotic</td>
#       <td id="T_bd4d0_row0_col9" class="data row0 col9" >more_3_sec</td>
#       <td id="T_bd4d0_row0_col10" class="data row0 col10" >depressed</td>
#       <td id="T_bd4d0_row0_col11" class="data row0 col11" >absent</td>
#       <td id="T_bd4d0_row0_col12" class="data row0 col12" >slight</td>
#       <td id="T_bd4d0_row0_col13" class="data row0 col13" >slight</td>
#       <td id="T_bd4d0_row0_col14" class="data row0 col14" >less_1_liter</td>
#       <td id="T_bd4d0_row0_col15" class="data row0 col15" >6.5</td>
#       <td id="T_bd4d0_row0_col16" class="data row0 col16" >decreased</td>
#       <td id="T_bd4d0_row0_col17" class="data row0 col17" >distend_small</td>
#       <td id="T_bd4d0_row0_col18" class="data row0 col18" >57.0</td>
#       <td id="T_bd4d0_row0_col19" class="data row0 col19" >8.5</td>
#       <td id="T_bd4d0_row0_col20" class="data row0 col20" >serosanguious</td>
#       <td id="T_bd4d0_row0_col21" class="data row0 col21" >3.4</td>
#       <td id="T_bd4d0_row0_col22" class="data row0 col22" >yes</td>
#       <td id="T_bd4d0_row0_col23" class="data row0 col23" >2209</td>
#       <td id="T_bd4d0_row0_col24" class="data row0 col24" >0</td>
#       <td id="T_bd4d0_row0_col25" class="data row0 col25" >0</td>
#       <td id="T_bd4d0_row0_col26" class="data row0 col26" >no</td>
#       <td id="T_bd4d0_row0_col27" class="data row0 col27" >died</td>
#     </tr>
#     <tr>
#       <th id="T_bd4d0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bd4d0_row1_col0" class="data row1 col0" >yes</td>
#       <td id="T_bd4d0_row1_col1" class="data row1 col1" >adult</td>
#       <td id="T_bd4d0_row1_col2" class="data row1 col2" >533836</td>
#       <td id="T_bd4d0_row1_col3" class="data row1 col3" >37.5</td>
#       <td id="T_bd4d0_row1_col4" class="data row1 col4" >88.0</td>
#       <td id="T_bd4d0_row1_col5" class="data row1 col5" >12.0</td>
#       <td id="T_bd4d0_row1_col6" class="data row1 col6" >cool</td>
#       <td id="T_bd4d0_row1_col7" class="data row1 col7" >normal</td>
#       <td id="T_bd4d0_row1_col8" class="data row1 col8" >pale_cyanotic</td>
#       <td id="T_bd4d0_row1_col9" class="data row1 col9" >more_3_sec</td>
#       <td id="T_bd4d0_row1_col10" class="data row1 col10" >mild_pain</td>
#       <td id="T_bd4d0_row1_col11" class="data row1 col11" >absent</td>
#       <td id="T_bd4d0_row1_col12" class="data row1 col12" >moderate</td>
#       <td id="T_bd4d0_row1_col13" class="data row1 col13" >none</td>
#       <td id="T_bd4d0_row1_col14" class="data row1 col14" >more_1_liter</td>
#       <td id="T_bd4d0_row1_col15" class="data row1 col15" >2.0</td>
#       <td id="T_bd4d0_row1_col16" class="data row1 col16" >absent</td>
#       <td id="T_bd4d0_row1_col17" class="data row1 col17" >distend_small</td>
#       <td id="T_bd4d0_row1_col18" class="data row1 col18" >33.0</td>
#       <td id="T_bd4d0_row1_col19" class="data row1 col19" >64.0</td>
#       <td id="T_bd4d0_row1_col20" class="data row1 col20" >serosanguious</td>
#       <td id="T_bd4d0_row1_col21" class="data row1 col21" >2.0</td>
#       <td id="T_bd4d0_row1_col22" class="data row1 col22" >yes</td>
#       <td id="T_bd4d0_row1_col23" class="data row1 col23" >2208</td>
#       <td id="T_bd4d0_row1_col24" class="dat

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
#     border-bottom: 2px solid #3A5A81;
# ">
#     <b>Insight</b> 💡
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
# ">
#     I prefer to capitalize data frame columns because sometimes they can contain features named the same way as some methods. Since I like to refer to columns as an attribute (with a dot), it's better to provide capitalized names.
# </p>

# %%
train.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1235 entries, 0 to 1234
# Columns: 28 entries, Surgery to Outcome
# dtypes: float64(7), int64(4), object(17)
# memory usage: 279.8+ KB

# %%
test.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 824 entries, 1235 to 2058
# Columns: 27 entries, Surgery to Cp_Data
# dtypes: float64(7), int64(4), object(16)
# memory usage: 180.2+ KB

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
#     border-bottom: 2px solid #3A5A81;
# ">
#     <b>Features Description</b> 📔
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
# ">
#     The dataset is divided into $27$ main features and the target. As we can read in the original dataset description, these are:
# </p>
#
# <ul style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
# ">
#     <li><code>Surgery</code> - Whether the horse was treated with surgery or not.</li>
#     <li><code>Age</code> - Age of the horse (young mean $< 6$ months).</li>
#     <li><code>Hospital_Number</code> - The case number assigned to the horse (may not be unique if the horse is treated $> 1$ time).</li>
#     <li><code>Rectal_Temp</code> - The normal temperature is $37.8$ (Celcius degrees) and will usually change as the problem progresses. It may start out normal, then become elevated because of the lesion, passing back through the normal range as the horse goes into shock.</li>
#     <li><code>Pulse</code> - Heart rate in beats per minute. This reflects the heart condition: $30$ - $40$ is normal for adult horses. It's rare to have a lower than normal rate, although athletic horses may have a rate of $20$ - $25$. Animals with painful lesions or suffering from circulatory shock may have an elevated heart rate.</li>
#     <li><code>Respiratory_Rate</code> - The normal rate is $8$ to $10$ and usefulness is doubtful due to the great fluctuations.</li>
#     <li><code>Temp_Of_Extremities</code> - A subjective indication of peripheral circulation. Cool to cold extremities indicate possible shock, whereas hot extremities should correlate with an elevated rectal temperature.</li>
#     <li><code>Peripheral_Pulse</code> - Subjective. Normal or increased values are indicative of adequate circulation, while reduced or absent indicate poor perfusion.</li>
#     <li><code>Mucous_Membrane</code> - A subjective measurement of colour. Normal pink and bright pink probably indicate a normal or slightly increased circulation. Pale pink may occur in early shock. Pale cyanotic and dark cyanotic are indicative of serious circulatory compromise. Bright red is more indicative of septicemia.</li>
#     <li><code>Capillary_Refill_Time</code> - A clinical judgement. The longer the refill, the poorer the circulation.</li>
#     <li><code>Pain</code> - A subjective judgement of the horse's pain level. In general, the more painful, the more likely it is to require surgery, but should not be treated as an ordered or discrete variable.</li>
#     <li><code>Peristalsis</code> - An indication of the activity in the horse's gut. As the gut becomes more distended or the horse becomes more toxic, the activity decreases.</li>
#     <li><code>Abdominal_Distention</code> - According to the author, this is an important parameter. An animal with abdominal distension is likely to be painful and have reduced gut motility. A horse with severe abdominal distension is likely to require surgery just to relieve the pressure.</li>
#     <li><code>Nasogastric_Tube</code> - Refers to any gas coming out of the tube. A large gas cap in the stomach is likely to give the horse discomfort.</li>
#     <li><code>Nasogastric_Reflux</code> - The greater the amount of reflux, the more likelihood that there is some serious obstruction to the fluid passage from the rest of the intestine.</li>
#     <li><code>Nasogastric_Reflux_Ph</code> - Scale is from $0$ to $14$ with $7$ being neutral, and normal values are in the $3$ to $4$ range.</li>
#     <li><code>Rectal_Exam_Feces</code> - Absent feces probably indicates an obstruction.</li>
#     <li><code>Abdomen</code> - Firm is probably an obstruction caused by a mechanical impaction and is normally treated medically. A distended small intestine and a distended large intestine indicate a surgical lesion.</li>
#     <li><code>Packed_Cell_Volume</code> - Normal range is $30$ to $50$. The level rises as the circulation becomes compromised or as the animal becomes dehydrated.</li>
#     <li><code>Total_Protein</code> - Normal values lie in the $6$ - $7.5$ (gms/dL) range, and the higher the value the greater the dehydration.</li>
#     <li><code>Abdomo_Appearance</code> - Normal fluid is clear while cloudy or serosanguinous indicates a compromised gut.</li>
#     <li><code>Abdomo_Protein</code> - The higher the level of protein the more likely it is to have a compromised gut. Values are in gms/dL.</li>
#     <li><code>Surgical_Lesion</code> - Retrospectively, was the problem (lesion) surgical?</li>
#     <li><code>Lesion_1</code>, <code>Lesion_2</code>, <code>Lesion_3</code> - Type of lesion. First number is site of lesion. Second number is type. Third number is subtype. Fourth number is specific code. Unfortunately, these indicators can be two-digit ones, so it's hard to interpret what is what.</li>
#     <li><code>Cp_Data</code> - Is pathology data present for this case? This variable is of no significance since pathology data is not included or collected for these cases.</li>
#     <li><code>Outcome</code> - <b>Horse health status. Variable to predict.</b></li>
# </ul>
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
# ">
#     Reading the original dataset description, we can get a little intuition about which features may be important from the task perspective and which are not. <b>For example, the author says right up front that some features like</b> <code>Respiratory_Rate</code> <b>and</b> <code>Cp_Data</code> <b>are probably useless.</b> <b>On the other hand,</b> <code>Abdominal_Distention</code> <b>perhaps is the most important.</b> Also, <code>Hospital_Number</code> may be doubtful since this is a case number assigned to the horse, not being related directly to the health status. Anyway, there we have $27$ features and $1235$ training samples, which gives us around $45$ samples per dimension. This is a little bit low value, and we should perform a feature selection analysis.
# </p>

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
#     border-bottom: 2px solid #3A5A81;
# ">
#     <b>Insight</b> 💡
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
# ">
#     The <code>Hospital_Number</code> should be related to only one horse, but observation can appear more than one time in the original dataset. On the other hand in the synthetic training dataset the same <code>Hospital_Number</code> value is associated with different horses. See below.
# </p>

# %%
train[train.Hospital_Number == 528800].style.set_table_styles(DF_STYLE).format(precision=1)
# Out:
# <style type="text/css">
# #T_6982b .index_name {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_6982b th:not(.index_name) {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_6982b td {
#   color: #4A4B52;
#   font-weight: bold;
# }
# </style>
# <table id="T_6982b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6982b_level0_col0" class="col_heading level0 col0" >Surgery</th>
#       <th id="T_6982b_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_6982b_level0_col2" class="col_heading level0 col2" >Hospital_Number</th>
#       <th id="T_6982b_level0_col3" class="col_heading level0 col3" >Rectal_Temp</th>
#       <th id="T_6982b_level0_col4" class="col_heading level0 col4" >Pulse</th>
#       <th id="T_6982b_level0_col5" class="col_heading level0 col5" >Respiratory_Rate</th>
#       <th id="T_6982b_level0_col6" class="col_heading level0 col6" >Temp_Of_Extremities</th>
#       <th id="T_6982b_level0_col7" class="col_heading level0 col7" >Peripheral_Pulse</th>
#       <th id="T_6982b_level0_col8" class="col_heading level0 col8" >Mucous_Membrane</th>
#       <th id="T_6982b_level0_col9" class="col_heading level0 col9" >Capillary_Refill_Time</th>
#       <th id="T_6982b_level0_col10" class="col_heading level0 col10" >Pain</th>
#       <th id="T_6982b_level0_col11" class="col_heading level0 col11" >Peristalsis</th>
#       <th id="T_6982b_level0_col12" class="col_heading level0 col12" >Abdominal_Distention</th>
#       <th id="T_6982b_level0_col13" class="col_heading level0 col13" >Nasogastric_Tube</th>
#       <th id="T_6982b_level0_col14" class="col_heading level0 col14" >Nasogastric_Reflux</th>
#       <th id="T_6982b_level0_col15" class="col_heading level0 col15" >Nasogastric_Reflux_Ph</th>
#       <th id="T_6982b_level0_col16" class="col_heading level0 col16" >Rectal_Exam_Feces</th>
#       <th id="T_6982b_level0_col17" class="col_heading level0 col17" >Abdomen</th>
#       <th id="T_6982b_level0_col18" class="col_heading level0 col18" >Packed_Cell_Volume</th>
#       <th id="T_6982b_level0_col19" class="col_heading level0 col19" >Total_Protein</th>
#       <th id="T_6982b_level0_col20" class="col_heading level0 col20" >Abdomo_Appearance</th>
#       <th id="T_6982b_level0_col21" class="col_heading level0 col21" >Abdomo_Protein</th>
#       <th id="T_6982b_level0_col22" class="col_heading level0 col22" >Surgical_Lesion</th>
#       <th id="T_6982b_level0_col23" class="col_heading level0 col23" >Lesion_1</th>
#       <th id="T_6982b_level0_col24" class="col_heading level0 col24" >Lesion_2</th>
#       <th id="T_6982b_level0_col25" class="col_heading level0 col25" >Lesion_3</th>
#       <th id="T_6982b_level0_col26" class="col_heading level0 col26" >Cp_Data</th>
#       <th id="T_6982b_level0_col27" class="col_heading level0 col27" >Outcome</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6982b_level0_row0" class="row_heading level0 row0" >186</th>
#       <td id="T_6982b_row0_col0" class="data row0 col0" >yes</td>
#       <td id="T_6982b_row0_col1" class="data row0 col1" >adult</td>
#       <td id="T_6982b_row0_col2" class="data row0 col2" >528800</td>
#       <td id="T_6982b_row0_col3" class="data row0 col3" >39.3</td>
#       <td id="T_6982b_row0_col4" class="data row0 col4" >66.0</td>
#       <td id="T_6982b_row0_col5" class="data row0 col5" >48.0</td>
#       <td id="T_6982b_row0_col6" class="data row0 col6" >warm</td>
#       <td id="T_6982b_row0_col7" class="data row0 col7" >reduced</td>
#       <td id="T_6982b_row0_col8" class="data row0 col8" >bright_red</td>
#       <td id="T_6982b_row0_col9" class="data row0 col9" >less_3_sec</td>
#       <td id="T_6982b_row0_col10" class="data row0 col10" >mild_pain</td>
#       <td id="T_6982b_row0_col11" class="data row0 col11" >hypomotile</td>
#       <td id="T_6982b_row0_col12" class="data row0 col12" >moderate</td>
#       <td id="T_6982b_row0_col13" class="data row0 col13" >slight</td>
#       <td id="T_6982b_row0_col14" class="data row0 col14" >less_1_liter</td>
#       <td id="T_6982b_row0_col15" class="data row0 col15" >4.5</td>
#       <td id="T_6982b_row0_col16" class="data row0 col16" >absent</td>
#       <td id="T_6982b_row0_col17" class="data row0 col17" >distend_small</td>
#       <td id="T_6982b_row0_col18" class="data row0 col18" >54.0</td>
#       <td id="T_6982b_row0_col19" class="data row0 col19" >7.5</td>
#       <td id="T_6982b_row0_col20" class="data row0 col20" >cloudy</td>
#       <td id="T_6982b_row0_col21" class="data row0 col21" >2.9</td>
#       <td id="T_6982b_row0_col22" class="data row0 col22" >yes</td>
#       <td id="T_6982b_row0_col23" class="data row0 col23" >2205</td>
#       <td id="T_6982b_row0_col24" class="data row0 col24" >0</td>
#       <td id="T_6982b_row0_col25" class="data row0 col25" >0</td>
#       <td id="T_6982b_row0_col26" class="data row0 col26" >no</td>
#       <td id="T_6982b_row0_col27" class="data row0 col27" >lived</td>
#     </tr>
#     <tr>
#       <th id="T_6982b_level0_row1" class="row_heading level0 row1" >397</th>
#       <td id="T_6982b_row1_col0" class="data row1 col0" >yes</td>
#       <td id="T_6982b_row1_col1" class="data row1 col1" >adult</td>
#       <td id="T_6982b_row1_col2" class="data row1 col2" >528800</td>
#       <td id="T_6982b_row1_col3" class="data row1 col3" >37.8</td>
#       <td id="T_6982b_row1_col4" class="data row1 col4" >48.0</td>
#       <td id="T_6982b_row1_col5" class="data row1 col5" >12.0</td>
#       <td id="T_6982b_row1_col6" class="data row1 col6" >cool</td>
#       <td id="T_6982b_row1_col7" class="data row1 col7" >normal</td>
#       <td id="T_6982b_row1_col8" class="data row1 col8" >pale_cyanotic</td>
#       <td id="T_6982b_row1_col9" class="data row1 col9" >less_3_sec</td>
#       <td id="T_6982b_row1_col10" class="data row1 col10" >mild_pain</td>
#       <td id="T_6982b_row1_col11" class="data row1 col11" >normal</td>
#       <td id="T_6982b_row1_col12" class="data row1 col12" >slight</td>
#       <td id="T_6982b_row1_col13" class="data row1 col13" >slight</td>
#       <td id="T_6982b_row1_col14" class="data row1 col14" >more_1_liter</td>
#       <td id="T_6982b_row1_col15" class="data row1 col15" >2.0</td>
#       <td id="T_6982b_row1_col16" class="data row1 col16" >decreased</td>
#       <td id="T_6982b_row1_col17" class="data row1 col17" >firm</td>
#       <td id="T_6982b_row1_col18" class="data row1 col18" >50.0</td>
#       <td id="T_6982b_row1_col19" class="data row1 col19" >7.0</td>
#       <td id="T_6982b_row1_col20" class="data row1 col20" >serosanguious</td>
#       <td id="T_6982b_row1_col21" class="data row1 col21" >5.0</td>
#       <td id="T_6982b_row1_col22" class="data row1 col22" >yes</td>
#       <td id="T_6982b_row1_col23" class="data row1 col23" >2205</td>
#       <td id="T_6982b_row1_col24" class="data row1 col

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
#     border-bottom: 2px solid #3A5A81;
# ">
#     <b>Hospital Number Feature</b> 📜
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
# ">
#     Here for example, $528800$ number is related to different observations (different horses), which have no sense. <b>That's probably the result of synthetic generation process. We can reject this feature at once I believe.</b>
# </p>

# %% [markdown]
# ## <b> <span style="font-family: 'JetBrains Mono'; color: #4A4B52">1.2</span> <span style='color: #3A5A81'>|</span> <span style="font-family: 'JetBrains Mono'; color: #4A4B52">Basic Numerical Properties &amp; Summaries</span></b><a class="anchor" id="basic_numerical_properties_summaries"></a> [↑](#top)

# %% [markdown]
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
# ">
#     Now we're going to look more closely at feature properties and dependencies. Let's have a look at the target variable distribution first.
# </p>

# %%
fig = px.histogram(
    y=train.Outcome,
    histnorm="percent",
    text_auto=".1f",
    title="Horse Health Status - Target to Predict<br>"
    "<span style='font-size: 75%; font-weight: bold;'>"
    "Three different outcomes which gives a multiclass classification problem</span>",
    color_discrete_sequence=["#4A4B52"],
    opacity=0.5,
    height=340,
    width=840,
)
fig.update_xaxes(title="Percent Count", range=(-2, 100))
fig.update_yaxes(title="", categoryorder="total ascending")
fig.update_traces(textposition="outside")
fig.update_layout(
    font_color=FONT_COLOR,
    title_font_size=18,
    plot_bgcolor=BACKGROUND_COLOR,
    paper_bgcolor=BACKGROUND_COLOR,
    xaxis_showgrid=False,
    yaxis_showgrid=False,
    bargap=0.4,
)
fig.show()

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
#     border-bottom: 2px solid #3A5A81;
# ">
#     <b>Target Distribution</b> 📜
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
# ">
#     The <code>Outcome</code> feature has three distinct classes, i.e. horse health status. As we can see almost half ($46.5$%) of horses have lived, whereas $53.5$% have died or have been euthanized. Let's get to the basic numerical summaries of the dataset. Firstly, let's see the diversity of the dataset, i.e. missing values, unique values and their frequency.
# </p>

# %%
def missing_unique_vals_summary(frame):
    missing_vals = frame.isna().sum()

    unique_vals = frame.apply(lambda col: len(col.unique()))
    most_freq_count = frame.apply(lambda col: col.value_counts().iloc[0])
    most_freq_val = frame.mode().iloc[:1].T.squeeze()

    unique_ratio = unique_vals / len(frame)
    freq_count_ratio = most_freq_count / len(frame)

    return pd.DataFrame(
        {
            "MissingValues": missing_vals,
            "UniqueValues": unique_vals,
            "UniqueValuesRatio": unique_ratio,
            "MostFreqValueCount": most_freq_count,
            "MostFreqValueCountRatio": freq_count_ratio,
            "MostFreqValue": most_freq_val,
            "Dtype": frame.dtypes,
        }
    )


train_summary = missing_unique_vals_summary(train)
test_summary = missing_unique_vals_summary(test)

# %%
print(CLR + "Training Dataset:")
train_summary.style.set_table_styles(DF_STYLE).background_gradient(DF_CMAP).format(
    {"UniqueValuesRatio": "{:.1%}", "MostFreqValueCountRatio": "{:.1%}"}, precision=1
)
# Out:
# Training Dataset:
# <style type="text/css">
# #T_ed843 .index_name {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_ed843 th:not(.index_name) {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_ed843 td {
#   color: #4A4B52;
#   font-weight: bold;
# }
# #T_ed843_row0_col0, #T_ed843_row0_col1, #T_ed843_row0_col2, #T_ed843_row1_col0, #T_ed843_row1_col1, #T_ed843_row1_col2, #T_ed843_row2_col0, #T_ed843_row2_col3, #T_ed843_row2_col4, #T_ed843_row3_col0, #T_ed843_row4_col0, #T_ed843_row5_col0, #T_ed843_row6_col0, #T_ed843_row7_col0, #T_ed843_row8_col0, #T_ed843_row9_col0, #T_ed843_row10_col0, #T_ed843_row11_col0, #T_ed843_row12_col0, #T_ed843_row13_col0, #T_ed843_row14_col0, #T_ed843_row15_col0, #T_ed843_row16_col0, #T_ed843_row17_col0, #T_ed843_row18_col0, #T_ed843_row19_col0, #T_ed843_row20_col0, #T_ed843_row21_col0, #T_ed843_row22_col0, #T_ed843_row22_col1, #T_ed843_row22_col2, #T_ed843_row23_col0, #T_ed843_row24_col0, #T_ed843_row25_col0, #T_ed843_row25_col1, #T_ed843_row25_col2, #T_ed843_row26_col0, #T_ed843_row26_col1, #T_ed843_row26_col2, #T_ed843_row27_col0 {
#   background-color: #f1f1f1;
#   color: #000000;
# }
# #T_ed843_row0_col3, #T_ed843_row0_col4 {
#   background-color: #cac8c8;
#   color: #000000;
# }
# #T_ed843_row1_col3, #T_ed843_row1_col4 {
#   background-color: #bdbbbb;
#   color: #000000;
# }
# #T_ed843_row2_col1, #T_ed843_row2_col2, #T_ed843_row24_col3, #T_ed843_row24_col4, #T_ed843_row25_col3, #T_ed843_row25_col4 {
#   background-color: #bab8b8;
#   color: #000000;
# }
# #T_ed843_row3_col1, #T_ed843_row3_col2 {
#   background-color: #e8e7e7;
#   color: #000000;
# }
# #T_ed843_row3_col3, #T_ed843_row3_col4 {
#   background-color: #ededed;
#   color: #000000;
# }
# #T_ed843_row4_col1, #T_ed843_row4_col2 {
#   background-color: #e6e6e6;
#   color: #000000;
# }
# #T_ed843_row4_col3, #T_ed843_row4_col4, #T_ed843_row18_col3, #T_ed843_row18_col4 {
#   background-color: #eeeeee;
#   color: #000000;
# }
# #T_ed843_row5_col1, #T_ed843_row5_col2 {
#   background-color: #e9e9e9;
#   color: #000000;
# }
# #T_ed843_row5_col3, #T_ed843_row5_col4, #T_ed843_row15_col1, #T_ed843_row15_col2 {
#   background-color: #ebebeb;
#   color: #000000;
# }
# #T_ed843_row6_col1, #T_ed843_row6_col2, #T_ed843_row7_col1, #T_ed843_row7_col2, #T_ed843_row9_col1, #T_ed843_row9_col2, #T_ed843_row11_col1, #T_ed843_row11_col2, #T_ed843_row12_col1, #T_ed843_row12_col2, #T_ed843_row13_col1, #T_ed843_row13_col2, #T_ed843_row14_col1, #T_ed843_row14_col2, #T_ed843_row16_col1, #T_ed843_row16_col2, #T_ed843_row17_col1, #T_ed843_row17_col2, #T_ed843_row20_col1, #T_ed843_row20_col2, #T_ed843_row24_col1, #T_ed843_row24_col2, #T_ed843_row27_col1, #T_ed843_row27_col2 {
#   background-color: #f0f0f0;
#   color: #000000;
# }
# #T_ed843_row6_col3, #T_ed843_row6_col4 {
#   background-color: #d2d1d1;
#   color: #000000;
# }
# #T_ed843_row7_col3, #T_ed843_row7_col4 {
#   background-color: #d1d0d0;
#   color: #000000;
# }
# #T_ed843_row8_col1, #T_ed843_row8_col2, #T_ed843_row10_col1, #T_ed843_row10_col2 {
#   background-color: #f0efef;
#   color: #000000;
# }
# #T_ed843_row8_col3, #T_ed843_row8_col4, #T_ed843_row15_col3, #T_ed843_row15_col4 {
#   background-color: #e6e5e5;
#   color: #000000;
# }
# #T_ed843_row9_col3, #T_ed843_row9_col4 {
#   background-color: #cccbcb;
#   color: #000000;
# }
# #T_ed843_row10_col3, #T_ed843_row10_col4 {
#   background-color: #dfdede;
#   color: #000000;
# }
# #T_ed843_row11_col3, #T_ed843_row11_col4, #T_ed843_row26_col3, #T_ed843_row26_col4 {
#   background-color: #d4d3d3;
#   color: #000000;
# }
# #T_ed843_row12_col3, #T_ed843_row12_col4 {
#   background-color: #dad9d9;
#   color: #000000;
# }
# #T_ed843_row13_col3, #T_ed843_row13_col4 {
#   background-color: #d0cfcf;
#   color: #000000;
# }
# #T_ed843_row14_col3, #T_ed843_row14_col4 {
#   background-color: #d7d6d6;
#   color: #000000;
# }
# #T_ed843_row16_col3, #T_ed843_row16_col4 {
#   background-color: #dcdbdb;
#   color: #000000;
# }
# #T_ed843_row17_col3, #T_ed843_row17_col4 {
#   background-color: #dcdcdc;
#   color: #000000;
# }
# #T_ed843_row18_col1, #T_ed843_row18_col2 {
#   background-color: #e7e6e6;
#   color: #000000;
# }
# #T_ed843_row19_col1, #T_ed843_row19_col2 {
#   background-color: #dfdfdf;
#   color: #000000;
# }
# #T_ed843_row19_col3, #T_ed843_row19_col4 {
#   background-color: #edecec;
#   color: #000000;
# }
# #T_ed843_row20_col3, #T_ed843_row20_col4, #T_ed843_row27_col3, #T_ed843_row27_col4 {
#   background-color: #d8d8d7;
#   color: #000000;
# }
# #T_ed843_row21_col1, #T_ed843_row21_col2, #T_ed843_row21_col3, #T_ed843_row21_col4 {
#   background-color: #e5e5e5;
#   color: #000000;
# }
# #T_ed843_row22_col3, #T_ed843_row22_col4 {
#   background-color: #c8c6c6;
#   color: #000000;
# }
# #T_ed843_row23_col1, #T_ed843_row23_col2 {
#   background-color: #e5e4e4;
#   color: #000000;
# }
# #T_ed843_row23_col3, #T_ed843_row23_col4 {
#   background-color: #ececec;
#   color: #000000;
# }
# </style>
# <table id="T_ed843">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ed843_level0_col0" class="col_heading level0 col0" >MissingValues</th>
#       <th id="T_ed843_level0_col1" class="col_heading level0 col1" >UniqueValues</th>
#       <th id="T_ed843_level0_col2" class="col_heading level0 col2" >UniqueValuesRatio</th>
#       <th id="T_ed843_level0_col3" class="col_heading level0 col3" >MostFreqValueCount</th>
#       <th id="T_ed843_level0_col4" class="col_heading level0 col4" >MostFreqValueCountRatio</th>
#       <th id="T_ed843_level0_col5" class="col_heading level0 col5" >MostFreqValue</th>
#       <th id="T_ed843_level0_col6" class="col_heading level0 col6" >Dtype</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed843_level0_row0" class="row_heading level0 row0" >Surgery</th>
#       <td id="T_ed843_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_ed843_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_ed843_row0_col2" class="data row0 col2" >0.2%</td>
#       <td id="T_ed843_row0_col3" class="data row0 col3" >887</td>
#       <td id="T_ed843_row0_col4" class="data row0 col4" >71.8%</td>
#       <td id="T_ed843_row0_col5" class="data row0 col5" >yes</td>
#       <td id="T_ed843_row0_col6" class="data row0 col6" >object</td>
#     </tr>
#     <tr>
#       <th id="T_ed843_level0_row1" class="row_heading level0 row1" >Age</th>
#       <td id="T_ed843_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_ed843_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_ed843_row1_col2" class="data row1 col2" >0.2%</td>
#       <td id="T_ed843_row1_col3" class="data row1 col3" >1160</td>
#       <td id="T_ed843_row1_col4" class="data row1 col4" >93.9%</td>
#       <td id="T_ed843_row1_col5" class="data row1 col5" >adult</td>
#       <td id="T_ed843_row1_col6" class="data row1 col6" >object</td>
#     </tr>
#     <tr>
#       <th id="T_ed843_level0_row2" class="row_heading level0 row2" >Hospital_Number</th>
#       <td id="T_ed843_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_ed843_row2_col1" class="data row2 col1" >255</td>
#       <td id="T_ed843_row2_col2" class="data row2 col2" >20.6%</td>
#       <td id="T_ed843_row2_col3" class="data row2 col3" >46</td>
#       <td id="T_ed843_row2_col4" class="data row2 col4" >3.7%</td>
#       <td id="T_ed843_row2_col5" class="data row2 col5" >529461</td>
#       <td id="T_ed843_row2_col6" class="data row2 col6" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_ed843_level0_row3" class="row_heading level0 row3" >Rectal_Temp</th>
#       <td id="T_ed843_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_ed843_row3_col1" class="data row3 col1" >43</td>
#       <td id="T_ed843_row3_col2" class="data row3 col2" >3.5%</td>
#       <td id="T_ed843_row3_col3" class="data row3 col3" >120</td>
#       <td id="T_ed843_row3_col4" class="data row3 col4" >9.7%</td>
#       <td id="T_ed843_row3_col5" class="data row3 col5" >38.0</td>
#       <td id="T_ed843_row3_col6" class="data row3 col6" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_ed843_level0_row4" class="row_heading level0 row4" >Pulse</th>
#       <td id="T_ed843_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_ed843_row4_col1" class="data row4 col1" >50</td>
#       <td id="T_ed843_row4_col2" class="data row4 c

# %%
print(CLR + "Test Dataset:")
test_summary.style.set_table_styles(DF_STYLE).background_gradient(DF_CMAP).format(
    {"UniqueValuesRatio": "{:.1%}", "MostFreqValueCountRatio": "{:.1%}"}, precision=1
)
# Out:
# Test Dataset:
# <style type="text/css">
# #T_8b625 .index_name {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_8b625 th:not(.index_name) {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_8b625 td {
#   color: #4A4B52;
#   font-weight: bold;
# }
# #T_8b625_row0_col0, #T_8b625_row1_col0, #T_8b625_row2_col0, #T_8b625_row2_col3, #T_8b625_row2_col4, #T_8b625_row3_col0, #T_8b625_row4_col0, #T_8b625_row5_col0, #T_8b625_row6_col0, #T_8b625_row7_col0, #T_8b625_row8_col0, #T_8b625_row9_col0, #T_8b625_row10_col0, #T_8b625_row11_col0, #T_8b625_row12_col0, #T_8b625_row13_col0, #T_8b625_row14_col0, #T_8b625_row15_col0, #T_8b625_row16_col0, #T_8b625_row17_col0, #T_8b625_row18_col0, #T_8b625_row19_col0, #T_8b625_row20_col0, #T_8b625_row21_col0, #T_8b625_row22_col0, #T_8b625_row23_col0, #T_8b625_row24_col0, #T_8b625_row25_col0, #T_8b625_row25_col1, #T_8b625_row25_col2, #T_8b625_row26_col0 {
#   background-color: #f1f1f1;
#   color: #000000;
# }
# #T_8b625_row0_col1, #T_8b625_row0_col2, #T_8b625_row1_col1, #T_8b625_row1_col2, #T_8b625_row6_col1, #T_8b625_row6_col2, #T_8b625_row7_col1, #T_8b625_row7_col2, #T_8b625_row9_col1, #T_8b625_row9_col2, #T_8b625_row11_col1, #T_8b625_row11_col2, #T_8b625_row12_col1, #T_8b625_row12_col2, #T_8b625_row13_col1, #T_8b625_row13_col2, #T_8b625_row14_col1, #T_8b625_row14_col2, #T_8b625_row16_col1, #T_8b625_row16_col2, #T_8b625_row20_col1, #T_8b625_row20_col2, #T_8b625_row22_col1, #T_8b625_row22_col2, #T_8b625_row24_col1, #T_8b625_row24_col2, #T_8b625_row26_col1, #T_8b625_row26_col2 {
#   background-color: #f0f0f0;
#   color: #000000;
# }
# #T_8b625_row0_col3, #T_8b625_row0_col4 {
#   background-color: #cac9c9;
#   color: #000000;
# }
# #T_8b625_row1_col3, #T_8b625_row1_col4 {
#   background-color: #bdbbbb;
#   color: #000000;
# }
# #T_8b625_row2_col1, #T_8b625_row2_col2, #T_8b625_row24_col3, #T_8b625_row24_col4, #T_8b625_row25_col3, #T_8b625_row25_col4 {
#   background-color: #bab8b8;
#   color: #000000;
# }
# #T_8b625_row3_col1, #T_8b625_row3_col2 {
#   background-color: #e8e8e8;
#   color: #000000;
# }
# #T_8b625_row3_col3, #T_8b625_row3_col4, #T_8b625_row4_col3, #T_8b625_row4_col4 {
#   background-color: #eeeeee;
#   color: #000000;
# }
# #T_8b625_row4_col1, #T_8b625_row4_col2, #T_8b625_row8_col3, #T_8b625_row8_col4, #T_8b625_row18_col1, #T_8b625_row18_col2 {
#   background-color: #e4e4e4;
#   color: #000000;
# }
# #T_8b625_row5_col1, #T_8b625_row5_col2, #T_8b625_row15_col3, #T_8b625_row15_col4 {
#   background-color: #e7e7e7;
#   color: #000000;
# }
# #T_8b625_row5_col3, #T_8b625_row5_col4 {
#   background-color: #ebebeb;
#   color: #000000;
# }
# #T_8b625_row6_col3, #T_8b625_row6_col4, #T_8b625_row7_col3, #T_8b625_row7_col4 {
#   background-color: #d2d1d1;
#   color: #000000;
# }
# #T_8b625_row8_col1, #T_8b625_row8_col2, #T_8b625_row10_col1, #T_8b625_row10_col2, #T_8b625_row17_col1, #T_8b625_row17_col2, #T_8b625_row18_col3, #T_8b625_row18_col4 {
#   background-color: #efefef;
#   color: #000000;
# }
# #T_8b625_row9_col3, #T_8b625_row9_col4, #T_8b625_row13_col3, #T_8b625_row13_col4 {
#   background-color: #cfcece;
#   color: #000000;
# }
# #T_8b625_row10_col3, #T_8b625_row10_col4, #T_8b625_row19_col1, #T_8b625_row19_col2 {
#   background-color: #dedddd;
#   color: #000000;
# }
# #T_8b625_row11_col3, #T_8b625_row11_col4 {
#   background-color: #d4d3d3;
#   color: #000000;
# }
# #T_8b625_row12_col3, #T_8b625_row12_col4 {
#   background-color: #dcdcdb;
#   color: #000000;
# }
# #T_8b625_row14_col3, #T_8b625_row14_col4 {
#   background-color: #d9d8d8;
#   color: #000000;
# }
# #T_8b625_row15_col1, #T_8b625_row15_col2 {
#   background-color: #e9e9e9;
#   color: #000000;
# }
# #T_8b625_row16_col3, #T_8b625_row16_col4 {
#   background-color: #dcdbdb;
#   color: #000000;
# }
# #T_8b625_row17_col3, #T_8b625_row17_col4 {
#   background-color: #dddddd;
#   color: #000000;
# }
# #T_8b625_row19_col3, #T_8b625_row19_col4, #T_8b625_row23_col3, #T_8b625_row23_col4 {
#   background-color: #ededed;
#   color: #000000;
# }
# #T_8b625_row20_col3, #T_8b625_row20_col4 {
#   background-color: #d8d7d7;
#   color: #000000;
# }
# #T_8b625_row21_col1, #T_8b625_row21_col2 {
#   background-color: #e4e3e3;
#   color: #000000;
# }
# #T_8b625_row21_col3, #T_8b625_row21_col4 {
#   background-color: #e6e5e5;
#   color: #000000;
# }
# #T_8b625_row22_col3, #T_8b625_row22_col4 {
#   background-color: #c8c7c7;
#   color: #000000;
# }
# #T_8b625_row23_col1, #T_8b625_row23_col2 {
#   background-color: #e3e2e2;
#   color: #000000;
# }
# #T_8b625_row26_col3, #T_8b625_row26_col4 {
#   background-color: #d5d4d3;
#   color: #000000;
# }
# </style>
# <table id="T_8b625">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b625_level0_col0" class="col_heading level0 col0" >MissingValues</th>
#       <th id="T_8b625_level0_col1" class="col_heading level0 col1" >UniqueValues</th>
#       <th id="T_8b625_level0_col2" class="col_heading level0 col2" >UniqueValuesRatio</th>
#       <th id="T_8b625_level0_col3" class="col_heading level0 col3" >MostFreqValueCount</th>
#       <th id="T_8b625_level0_col4" class="col_heading level0 col4" >MostFreqValueCountRatio</th>
#       <th id="T_8b625_level0_col5" class="col_heading level0 col5" >MostFreqValue</th>
#       <th id="T_8b625_level0_col6" class="col_heading level0 col6" >Dtype</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b625_level0_row0" class="row_heading level0 row0" >Surgery</th>
#       <td id="T_8b625_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_8b625_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_8b625_row0_col2" class="data row0 col2" >0.2%</td>
#       <td id="T_8b625_row0_col3" class="data row0 col3" >589</td>
#       <td id="T_8b625_row0_col4" class="data row0 col4" >71.5%</td>
#       <td id="T_8b625_row0_col5" class="data row0 col5" >yes</td>
#       <td id="T_8b625_row0_col6" class="data row0 col6" >object</td>
#     </tr>
#     <tr>
#       <th id="T_8b625_level0_row1" class="row_heading level0 row1" >Age</th>
#       <td id="T_8b625_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_8b625_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_8b625_row1_col2" class="data row1 col2" >0.2%</td>
#       <td id="T_8b625_row1_col3" class="data row1 col3" >782</td>
#       <td id="T_8b625_row1_col4" class="data row1 col4" >94.9%</td>
#       <td id="T_8b625_row1_col5" class="data row1 col5" >adult</td>
#       <td id="T_8b625_row1_col6" class="data row1 col6" >object</td>
#     </tr>
#     <tr>
#       <th id="T_8b625_level0_row2" class="row_heading level0 row2" >Hospital_Number</th>
#       <td id="T_8b625_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_8b625_row2_col1" class="data row2 col1" >210</td>
#       <td id="T_8b625_row2_col2" class="data row2 col2" >25.5%</td>
#       <td id="T_8b625_row2_col3" class="data row2 col3" >35</td>
#       <td id="T_8b625_row2_col4" class="data row2 col4" >4.2%</td>
#       <td id="T_8b625_row2_col5" class="data row2 col5" >529461.0</td>
#       <td id="T_8b625_row2_col6" class="data row2 col6" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_8b625_level0_row3" class="row_heading level0 row3" >Rectal_Temp</th>
#       <td id="T_8b625_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_8b625_row3_col1" class="data row3 col1" >34</td>
#       <td id="T_8b625_row3_col2" class="data row3 col2" >4.1%</td>
#       <td id="T_8b625_row3_col3" class="data row3 col3" >75</td>
#       <td id="T_8b625_row3_col4" class="data row3 col4" >9.1%</td>
#       <td id="T_8b625_row3_col5" class="data row3 col5" >38.0</td>
#       <td id="T_8b625_row3_col6" class="data row3 col6" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_8b625_level0_row4" class="row_heading level0 row4" >Pulse</th>
#       <td id="T_8b625_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_8b625_row4_col1" class="data row4 col1" >49</td>
#       <td id="T_8b625_row4_col2" class="data row4 col2" >5.9%</td>
#       <td id="T_8b625_row4_col3" class="data row4 col3" >74</td>
#       <td id="T_8b625_row4_col4" class="data row4 col4" >9.0%</td>
#       <td id="T_8b625_row4_col5" class="data row4 col5" >52.0</td>
#       <td id="T_8b625_row4_col6" class="data row4 col6" >float64</td>
#     </tr>
#     <tr>

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
#     border-bottom: 2px solid #3A5A81;
# ">
#     <b>Unique &amp; Most Frequent Values</b> 📜
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
# ">
#     The dataset is mainly an object-type dataset with categorical features. Those compose $17$ features, whereas numerical ones comprise $11$ variables ($7$ decimals and $4$ integers). <b>As we can see, there are no missing values in both training and test datasets. Moreover, these are very similar regarding diversity, showing only small differences.</b> There are two variables which can be rejected at hand, i.e., <code>Lesion_2</code> and <code>Lesion_3</code>, since these are composed of one unique value that covers almost the whole dataset. Let's see numerical summaries now.
# </p>

# %%
def numeric_descr(frame):
    return (
        frame.describe(percentiles=[0.01, 0.05, 0.25, 0.50, 0.75, 0.95, 0.99])
        .T.drop("count", axis=1)
        .rename(columns=str.title)
    )


train_num_descr = numeric_descr(train)
test_num_descr = numeric_descr(test)

# %%
train_num_descr.style.set_table_styles(DF_STYLE).format(precision=1)
# Out:
# <style type="text/css">
# #T_4ee8e .index_name {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_4ee8e th:not(.index_name) {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_4ee8e td {
#   color: #4A4B52;
#   font-weight: bold;
# }
# </style>
# <table id="T_4ee8e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4ee8e_level0_col0" class="col_heading level0 col0" >Mean</th>
#       <th id="T_4ee8e_level0_col1" class="col_heading level0 col1" >Std</th>
#       <th id="T_4ee8e_level0_col2" class="col_heading level0 col2" >Min</th>
#       <th id="T_4ee8e_level0_col3" class="col_heading level0 col3" >1%</th>
#       <th id="T_4ee8e_level0_col4" class="col_heading level0 col4" >5%</th>
#       <th id="T_4ee8e_level0_col5" class="col_heading level0 col5" >25%</th>
#       <th id="T_4ee8e_level0_col6" class="col_heading level0 col6" >50%</th>
#       <th id="T_4ee8e_level0_col7" class="col_heading level0 col7" >75%</th>
#       <th id="T_4ee8e_level0_col8" class="col_heading level0 col8" >95%</th>
#       <th id="T_4ee8e_level0_col9" class="col_heading level0 col9" >99%</th>
#       <th id="T_4ee8e_level0_col10" class="col_heading level0 col10" >Max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ee8e_level0_row0" class="row_heading level0 row0" >Hospital_Number</th>
#       <td id="T_4ee8e_row0_col0" class="data row0 col0" >954500.4</td>
#       <td id="T_4ee8e_row0_col1" class="data row0 col1" >1356403.1</td>
#       <td id="T_4ee8e_row0_col2" class="data row0 col2" >521399.0</td>
#       <td id="T_4ee8e_row0_col3" class="data row0 col3" >527365.0</td>
#       <td id="T_4ee8e_row0_col4" class="data row0 col4" >527563.0</td>
#       <td id="T_4ee8e_row0_col5" class="data row0 col5" >528800.0</td>
#       <td id="T_4ee8e_row0_col6" class="data row0 col6" >529777.0</td>
#       <td id="T_4ee8e_row0_col7" class="data row0 col7" >534145.0</td>
#       <td id="T_4ee8e_row0_col8" class="data row0 col8" >5290409.0</td>
#       <td id="T_4ee8e_row0_col9" class="data row0 col9" >5299603.0</td>
#       <td id="T_4ee8e_row0_col10" class="data row0 col10" >5305129.0</td>
#     </tr>
#     <tr>
#       <th id="T_4ee8e_level0_row1" class="row_heading level0 row1" >Rectal_Temp</th>
#       <td id="T_4ee8e_row1_col0" class="data row1 col0" >38.2</td>
#       <td id="T_4ee8e_row1_col1" class="data row1 col1" >0.8</td>
#       <td id="T_4ee8e_row1_col2" class="data row1 col2" >35.4</td>
#       <td id="T_4ee8e_row1_col3" class="data row1 col3" >36.1</td>
#       <td id="T_4ee8e_row1_col4" class="data row1 col4" >37.1</td>
#       <td id="T_4ee8e_row1_col5" class="data row1 col5" >37.8</td>
#       <td id="T_4ee8e_row1_col6" class="data row1 col6" >38.2</td>
#       <td id="T_4ee8e_row1_col7" class="data row1 col7" >38.6</td>
#       <td id="T_4ee8e_row1_col8" class="data row1 col8" >39.5</td>
#       <td id="T_4ee8e_row1_col9" class="data row1 col9" >40.3</td>
#       <td id="T_4ee8e_row1_col10" class="data row1 col10" >40.8</td>
#     </tr>
#     <tr>
#       <th id="T_4ee8e_level0_row2" class="row_heading level0 row2" >Pulse</th>
#       <td id="T_4ee8e_row2_col0" class="data row2 col0" >79.6</td>
#       <td id="T_4ee8e_row2_col1" class="data row2 col1" >29.1</td>
#       <td id="T_4ee8e_row2_col2" class="data row2 col2" >30.0</td>
#       <td id="T_4ee8e_row2_col3" class="data row2 col3" >36.0</td>
#       <td id="T_4ee8e_row2_col4" class="data row2 col4" >42.0</td>
#       <td id="T_4ee8e_row2_col5" class="data row2 col5" >53.0</td>
#       <td id="T_4ee8e_row2_col6" class="data row2 col6" >76.0</td>
#       <td id="T_4ee8e_row2_col7" class="data row2 col7" >100.0</td>
#       <td id="T_4ee8e_row2_col8" class="data row2 col8" >129.0</td>
#       <td id="T_4ee8e_row2_col9" class="data row2 col9" >164.0</td>
#       <td id="T_4ee8e_row2_col10" class="data row2 col10" >184.0</td>
#     </tr>
#     <tr>
#       <th id="T_4ee8e_level0_row3" class="row_heading level0 row3" >Respiratory_Rate</th>
#       <td id="T_4ee8e_row3_col0" class="data row3 col0" >30.1</td>
#       <td id="T_4ee8e_row3_col1" class="data row3 col1" >16.5</td>
#       <td id="T_4ee8e_row3_col2" class="data row3 col2" >8.0</td>
#       <td id="T_4ee8e_row3_col3" class="data row3 col3" >10.0</td>
#       <td id="T_4ee8e_row3_col4" class="data row3 col4" >12.0</td>
#       <td id="T_4ee8e_row3_col5" class="data row3 col5" >18.0</td>
#       <td id="T_4ee8e_row3_col6" class="data row3 col6" >28.0</td>
#       <td id="T_4ee8e_row3_col7" class="data row3 col7" >36.0</td>
#       <td id="T_4ee8e_row3_col8" class="data row3 col8" >60.0</td>
#       <td id="T_4ee8e_row3_col9" class="data row3 col9" >90.0</td>
#       <td id="T_4ee8e_row3_col10" class="data row3 col10" >96.0</td>
#     </tr>
#     <tr>
#       <th id="T_4ee8e_level0_row4" class="row_heading level0 row4" >Nasogastric_Reflux_Ph</th>
#       <td id="T_4ee8e_row4_col0" class="data row4 col0" >4.4</td>
#       <td id="T_4ee8e_row4_col1" class="data row4 col1" >1.9</td>
#       <td id="T_4ee8e_row4_col2" class="data row4 col2" >1.0</td>
#       <td id="T_4ee8e_row4_col3" class="data row4 col3" >1.0</td>
#       <td id="T_4ee8e_row4_col4" class="data row4 col4" >2.0</td>
#       <td id="T_4ee8e_row4_col5" class="data row4 col5" >2.0</td>
#       <td id="T_4ee8e_row4_col6" class="data row4 col6" >4.5</td>
#       <td id="T_4ee8e_row4_col7" class="data row4 col7" >6.0</td>
#       <td id="T_4ee8e_row4_col8" class="data row4 col8" >7.0</td>
#       <td id="T_4ee8e_row4_col9" class="data row4 col9" >7.5</td>
#       <td id="T_4ee8e_row4_col10" class="data row4 col10" >7.5</td>
#     </tr>
#     <tr>
#       <th id="T_4ee8e_level0_row5" class="row_heading level0 row5" >Packed_Cell_Volume</th>
#       <td id="T_4ee8e_row5_col0" class="data row5 col0" >49.6</td>
#       <td id="T_4ee8e_row5_col1" class="data row5 col1" >10.5</td>
#       <td id="T_4ee8e_row5_col2" class="data row5 col2" >23.0</td>
#       <td id="T_4ee8e_row5_col3" class="data row5 col3" >30.0</td>
#       <td id="T_4ee8e_row5_col4" class="data row5 col4" >34.7</td>
#       <td id="T_4ee8e_row5_col5" class="data row5 col5" >43.0</td>
#       <td id="T_4ee8e_row5_col6" class="data row5 col6" >48.0</td>
#       <td id="T_4ee8e_row5_col7" class="data row5 col7" >57.0</td>
#       <td id="T_4ee8e_row5_col8" class="data row5 col8" >69.0</td>
#       <td id="T_4ee8e_row5_col9" class="data row5 col9" >75.0</td>
#       <td id="T_4ee8e_row5_col10" class="data row5 col10" >75.0</td>
#     </tr>
#     <tr>
#       <th id="T_4ee8e_level0_row6" class="row_heading level0 row6" >Total_Protein</th>
#       <td id="T_4ee8e_row6_col0" class="data row6 col0" >21.4</td>
#       <td id="T_4ee8e_row6_col1" class="data row6 col1" >26.7</td>
#       <td id="T_4ee8e_row6_col2" class="data row6 col2" >3.5</td>
#       <td id="T_4ee8e_row6_col3" class="data row6 col3" >4.5</td>
#       <td id="T_4ee8e_row6_col4" class="data row6 col4" >5.9</td>
#       <td id="T_4ee8e_row6_col5" class="data row6 col5" >6.6</td>
#       <td id="T_4ee8e_row6_col6" class="data row6 col6" >7.5</td>
#       <td id="T_4ee8e_row6_col7" class="data row6 col7" >9.1</td>
#       <td id="T_4ee8e_row6_col8" class="data row6 col8" >80.0</td>
#       <td id="T_4ee8e_row6_col9" class="data row6 col9" >82.0</td>
#       <td id="T_4ee8e_row6_col10" class="data row6 col10" >89.0</td>
#     </tr>
#     <tr>
#       <th id="T_4ee8e_level0_row7" class="row_heading level0 row7" >Abdomo_Protein</th>
#       <td id="T_4ee8e_row7_col0" class="data row7 col0" >3.3</td>
#       <td id="T_4ee8e_row7_col1" class="data row7 col1" >1.6</td>
#       <td id="T_4ee8e_row7_col2" class="data row7 col2" >0.1</td>
#       <td id="T_4ee8e_row7_col3" class="data row7 col3" >1.0</td>
#       <td id="T_4ee8e_row7_col4" class="data row7 col4" >1.0</td>
#       <td id="T_4ee8e_row7_col5" class="data row7 col5" >2.0</td>
#       <td id="T_4ee8e_row7_col6" class="data row7 col6" >3.0</td>
#       <td id="T_4ee8e_row7_col7" class="data row7 col7" >4.3</td>
#       <td id="T_4ee8e_row7_col8" class="data row7 col8" >6.5</td>
#       <td id="T_4ee8e_row7_col9" class="data row7 col9" >8.0</td>
#       <td id="T_4ee8e_row7_col10" clas

# %%
test_num_descr.style.set_table_styles(DF_STYLE).format(precision=1)
# Out:
# <style type="text/css">
# #T_99c27 .index_name {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_99c27 th:not(.index_name) {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_99c27 td {
#   color: #4A4B52;
#   font-weight: bold;
# }
# </style>
# <table id="T_99c27">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99c27_level0_col0" class="col_heading level0 col0" >Mean</th>
#       <th id="T_99c27_level0_col1" class="col_heading level0 col1" >Std</th>
#       <th id="T_99c27_level0_col2" class="col_heading level0 col2" >Min</th>
#       <th id="T_99c27_level0_col3" class="col_heading level0 col3" >1%</th>
#       <th id="T_99c27_level0_col4" class="col_heading level0 col4" >5%</th>
#       <th id="T_99c27_level0_col5" class="col_heading level0 col5" >25%</th>
#       <th id="T_99c27_level0_col6" class="col_heading level0 col6" >50%</th>
#       <th id="T_99c27_level0_col7" class="col_heading level0 col7" >75%</th>
#       <th id="T_99c27_level0_col8" class="col_heading level0 col8" >95%</th>
#       <th id="T_99c27_level0_col9" class="col_heading level0 col9" >99%</th>
#       <th id="T_99c27_level0_col10" class="col_heading level0 col10" >Max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99c27_level0_row0" class="row_heading level0 row0" >Hospital_Number</th>
#       <td id="T_99c27_row0_col0" class="data row0 col0" >1108357.2</td>
#       <td id="T_99c27_row0_col1" class="data row0 col1" >1555626.9</td>
#       <td id="T_99c27_row0_col2" class="data row0 col2" >521399.0</td>
#       <td id="T_99c27_row0_col3" class="data row0 col3" >527365.0</td>
#       <td id="T_99c27_row0_col4" class="data row0 col4" >527680.2</td>
#       <td id="T_99c27_row0_col5" class="data row0 col5" >528743.0</td>
#       <td id="T_99c27_row0_col6" class="data row0 col6" >529808.5</td>
#       <td id="T_99c27_row0_col7" class="data row0 col7" >534644.0</td>
#       <td id="T_99c27_row0_col8" class="data row0 col8" >5291243.5</td>
#       <td id="T_99c27_row0_col9" class="data row0 col9" >5299603.0</td>
#       <td id="T_99c27_row0_col10" class="data row0 col10" >5305129.0</td>
#     </tr>
#     <tr>
#       <th id="T_99c27_level0_row1" class="row_heading level0 row1" >Rectal_Temp</th>
#       <td id="T_99c27_row1_col0" class="data row1 col0" >38.2</td>
#       <td id="T_99c27_row1_col1" class="data row1 col1" >0.8</td>
#       <td id="T_99c27_row1_col2" class="data row1 col2" >36.0</td>
#       <td id="T_99c27_row1_col3" class="data row1 col3" >36.4</td>
#       <td id="T_99c27_row1_col4" class="data row1 col4" >37.1</td>
#       <td id="T_99c27_row1_col5" class="data row1 col5" >37.8</td>
#       <td id="T_99c27_row1_col6" class="data row1 col6" >38.2</td>
#       <td id="T_99c27_row1_col7" class="data row1 col7" >38.6</td>
#       <td id="T_99c27_row1_col8" class="data row1 col8" >39.5</td>
#       <td id="T_99c27_row1_col9" class="data row1 col9" >40.3</td>
#       <td id="T_99c27_row1_col10" class="data row1 col10" >40.8</td>
#     </tr>
#     <tr>
#       <th id="T_99c27_level0_row2" class="row_heading level0 row2" >Pulse</th>
#       <td id="T_99c27_row2_col0" class="data row2 col0" >80.2</td>
#       <td id="T_99c27_row2_col1" class="data row2 col1" >29.2</td>
#       <td id="T_99c27_row2_col2" class="data row2 col2" >36.0</td>
#       <td id="T_99c27_row2_col3" class="data row2 col3" >40.0</td>
#       <td id="T_99c27_row2_col4" class="data row2 col4" >44.0</td>
#       <td id="T_99c27_row2_col5" class="data row2 col5" >54.0</td>
#       <td id="T_99c27_row2_col6" class="data row2 col6" >76.0</td>
#       <td id="T_99c27_row2_col7" class="data row2 col7" >100.0</td>
#       <td id="T_99c27_row2_col8" class="data row2 col8" >132.0</td>
#       <td id="T_99c27_row2_col9" class="data row2 col9" >164.0</td>
#       <td id="T_99c27_row2_col10" class="data row2 col10" >184.0</td>
#     </tr>
#     <tr>
#       <th id="T_99c27_level0_row3" class="row_heading level0 row3" >Respiratory_Rate</th>
#       <td id="T_99c27_row3_col0" class="data row3 col0" >30.7</td>
#       <td id="T_99c27_row3_col1" class="data row3 col1" >17.4</td>
#       <td id="T_99c27_row3_col2" class="data row3 col2" >9.0</td>
#       <td id="T_99c27_row3_col3" class="data row3 col3" >12.0</td>
#       <td id="T_99c27_row3_col4" class="data row3 col4" >12.0</td>
#       <td id="T_99c27_row3_col5" class="data row3 col5" >18.0</td>
#       <td id="T_99c27_row3_col6" class="data row3 col6" >28.0</td>
#       <td id="T_99c27_row3_col7" class="data row3 col7" >36.0</td>
#       <td id="T_99c27_row3_col8" class="data row3 col8" >68.0</td>
#       <td id="T_99c27_row3_col9" class="data row3 col9" >90.0</td>
#       <td id="T_99c27_row3_col10" class="data row3 col10" >96.0</td>
#     </tr>
#     <tr>
#       <th id="T_99c27_level0_row4" class="row_heading level0 row4" >Nasogastric_Reflux_Ph</th>
#       <td id="T_99c27_row4_col0" class="data row4 col0" >4.5</td>
#       <td id="T_99c27_row4_col1" class="data row4 col1" >1.9</td>
#       <td id="T_99c27_row4_col2" class="data row4 col2" >1.0</td>
#       <td id="T_99c27_row4_col3" class="data row4 col3" >1.0</td>
#       <td id="T_99c27_row4_col4" class="data row4 col4" >2.0</td>
#       <td id="T_99c27_row4_col5" class="data row4 col5" >3.0</td>
#       <td id="T_99c27_row4_col6" class="data row4 col6" >4.5</td>
#       <td id="T_99c27_row4_col7" class="data row4 col7" >6.5</td>
#       <td id="T_99c27_row4_col8" class="data row4 col8" >7.0</td>
#       <td id="T_99c27_row4_col9" class="data row4 col9" >7.5</td>
#       <td id="T_99c27_row4_col10" class="data row4 col10" >7.5</td>
#     </tr>
#     <tr>
#       <th id="T_99c27_level0_row5" class="row_heading level0 row5" >Packed_Cell_Volume</th>
#       <td id="T_99c27_row5_col0" class="data row5 col0" >49.1</td>
#       <td id="T_99c27_row5_col1" class="data row5 col1" >10.5</td>
#       <td id="T_99c27_row5_col2" class="data row5 col2" >23.0</td>
#       <td id="T_99c27_row5_col3" class="data row5 col3" >30.0</td>
#       <td id="T_99c27_row5_col4" class="data row5 col4" >33.0</td>
#       <td id="T_99c27_row5_col5" class="data row5 col5" >43.0</td>
#       <td id="T_99c27_row5_col6" class="data row5 col6" >48.0</td>
#       <td id="T_99c27_row5_col7" class="data row5 col7" >55.0</td>
#       <td id="T_99c27_row5_col8" class="data row5 col8" >69.0</td>
#       <td id="T_99c27_row5_col9" class="data row5 col9" >75.0</td>
#       <td id="T_99c27_row5_col10" class="data row5 col10" >75.0</td>
#     </tr>
#     <tr>
#       <th id="T_99c27_level0_row6" class="row_heading level0 row6" >Total_Protein</th>
#       <td id="T_99c27_row6_col0" class="data row6 col0" >20.8</td>
#       <td id="T_99c27_row6_col1" class="data row6 col1" >26.4</td>
#       <td id="T_99c27_row6_col2" class="data row6 col2" >3.9</td>
#       <td id="T_99c27_row6_col3" class="data row6 col3" >4.5</td>
#       <td id="T_99c27_row6_col4" class="data row6 col4" >5.9</td>
#       <td id="T_99c27_row6_col5" class="data row6 col5" >6.6</td>
#       <td id="T_99c27_row6_col6" class="data row6 col6" >7.5</td>
#       <td id="T_99c27_row6_col7" class="data row6 col7" >8.9</td>
#       <td id="T_99c27_row6_col8" class="data row6 col8" >81.0</td>
#       <td id="T_99c27_row6_col9" class="data row6 col9" >82.0</td>
#       <td id="T_99c27_row6_col10" class="data row6 col10" >89.0</td>
#     </tr>
#     <tr>
#       <th id="T_99c27_level0_row7" class="row_heading level0 row7" >Abdomo_Protein</th>
#       <td id="T_99c27_row7_col0" class="data row7 col0" >3.3</td>
#       <td id="T_99c27_row7_col1" class="data row7 col1" >1.5</td>
#       <td id="T_99c27_row7_col2" class="data row7 col2" >0.1</td>
#       <td id="T_99c27_row7_col3" class="data row7 col3" >1.0</td>
#       <td id="T_99c27_row7_col4" class="data row7 col4" >1.0</td>
#       <td id="T_99c27_row7_col5" class="data row7 col5" >2.0</td>
#       <td id="T_99c27_row7_col6" class="data row7 col6" >3.3</td>
#       <td id="T_99c27_row7_col7" class="data row7 col7" >4.3</td>
#       <td id="T_99c27_row7_col8" class="data row7 col8" >5.6</td>
#       <td id="T_99c27_row7_col9" class="data row7 col9" >8.0</td>
#       <td id="T_99c27_row7_col10" cla

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
#     border-bottom: 2px solid #3A5A81;
# ">
#     <b>Numerical Summary</b> 📜
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
# ">
#     There we have almost perfect overlaying in both training and test datasets when you look at percentiles. <b>This means that datasets most probably derive from the same distribution.</b> A slightly different situation appears for the <code>Lesion-Variables</code> since these are not truly numeric values but codes. It's hard to say whether these may be handy. Since we have tables above, let's have a look at distribution plots.
# </p>

# %%
def get_n_rows_axes(n_features, n_cols):
    n_rows = int(np.ceil(n_features / n_cols))
    current_col = range(1, n_cols + 1)
    current_row = range(1, n_rows + 1)
    return n_rows, list(product(current_row, current_col))


def draw_dist_for_group(group, vars_to_plot, n_cols=3, height=640):
    n_rows, axes = get_n_rows_axes(len(vars_to_plot), n_cols)
    fig = make_subplots(
        rows=n_rows,
        cols=n_cols,
        y_title="Probability Density",
        horizontal_spacing=0.1,
        vertical_spacing=0.1,
    )
    fig.update_annotations(font_size=14)
    for frame, color, frame_name in zip((train, test), ("#4A4B52", "#3A5A81"), ("Train", "Test")):
        for k, (var, (row, col)) in enumerate(zip(vars_to_plot, axes), start=1):
            # density, bins = np.histogram(frame[var].dropna(), density=True)
            fig.add_histogram(
                # x=bins,
                x=frame[var],
                histnorm="probability density",
                marker_color=color,
                marker_line_width=0,
                # marker_line_color=color,
                opacity=0.75,
                name=frame_name,
                legendgroup=frame_name,
                showlegend=k == 1,
                row=row,
                col=col,
            )
            fig.update_xaxes(
                tickfont_size=8,
                showgrid=False,
                title_text=var,
                titlefont_size=8,
                titlefont_family="Arial Black",
                row=row,
                col=col,
            )
            fig.update_yaxes(tickfont_size=8, showgrid=False, row=row, col=col)

    fig.update_layout(
        width=840,
        height=height,
        title=f"{group} Features - Distributions<br>"
        "<span style='font-size: 75%; font-weight: bold;'>"
        "Training and test datasets show almost perfect overlaying</span>",
        font_color=FONT_COLOR,
        title_font_size=18,
        plot_bgcolor=BACKGROUND_COLOR,
        paper_bgcolor=BACKGROUND_COLOR,
        bargap=0.1,
        bargroupgap=0.1,
        legend=dict(yanchor="bottom", xanchor="right", y=1, x=1, orientation="h", title=""),
    )
    return fig


cat_features = train.drop("Outcome", axis=1).select_dtypes("object").columns.to_list()
fig = draw_dist_for_group("Categorical", cat_features, height=940)
fig.update_xaxes(categoryorder="total ascending")
fig.update_layout(bargap=0.2, bargroupgap=0.2)
fig.show()

# %%
num_features = train.select_dtypes("number").columns.to_list()
fig = draw_dist_for_group("Numeric", num_features, height=740)
fig.show()

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
#     border-bottom: 2px solid #3A5A81;
# ">
#     <b>Categorical &amp; Numerical Distributions</b> 📜
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
# ">
#     Training and test datasets show us almost perfect overlaying in all features. This mean that values derive from the same distribution as we thought earlier. <b>Such situation gives us hope that results obtained from machine learning models for training and test datasets should follow each other.</b> In the case of categorical features, a one problem arises, since there is a lot of categories, there may be a problem with one hot encoding. OHE will introduce too many features here, so probably we should use ordinal encoding. Let's have a look at correlation matrix now.
# </p>

# %%
pearson_corr = train.corr(method="pearson", numeric_only=True).round(2)
lower_triangular_corr = (
    pearson_corr.mask(np.triu(np.ones_like(pearson_corr, dtype=bool)))
    .dropna(axis="index", how="all")
    .dropna(axis="columns", how="all")
)

color_map = [[0.0, "#FCFCFC"], [0.5, "#4A4B52"], [1.0, "#3A5A81"]]

heatmap = go.Heatmap(
    z=lower_triangular_corr,
    x=lower_triangular_corr.columns,
    y=lower_triangular_corr.index,
    text=lower_triangular_corr.fillna(""),
    texttemplate="%{text}",
    opacity=0.85,
    xgap=4,
    ygap=4,
    showscale=True,
    colorscale=color_map,
    colorbar_len=1.02,
    hoverinfo="none",
)
fig = go.Figure(heatmap)
fig.add_annotation(
    x=3.5,
    y=1,
    align="left",
    xanchor="left",
    text="<b>Lesion_2 and Lesion_3 are mostly correlated (0.64),<br>"
    "but it's misleading, since these features are<br>"
    "composed of zeros in almost all observations.</b>",
    showarrow=False,
)
fig.update_yaxes(tickfont_size=10)
fig.update_xaxes(tickfont_size=10)
fig.update_layout(
    font_color=FONT_COLOR,
    title="Lower Triangular of Correlation Matrix (Pearson)<br>"
    "<span style='font-size: 75%; font-weight: bold;'>"
    "There is only 6 somewhat linearly correlated numerical pairs</span>",
    title_font_size=18,
    plot_bgcolor=BACKGROUND_COLOR,
    paper_bgcolor=BACKGROUND_COLOR,
    width=840,
    height=840,
    xaxis_showgrid=False,
    yaxis_showgrid=False,
    yaxis_autorange="reversed",
)
fig.show()

# %%
highest_abs_corr = (
    lower_triangular_corr.abs()
    .unstack()
    .sort_values(ascending=False)  # type: ignore
    .rename("Absolute Pearson Correlation")
    .to_frame()
    .reset_index(names=["Feature 1", "Feature 2"])
)

top_corr = highest_abs_corr[highest_abs_corr["Absolute Pearson Correlation"] >= 0.4]
top_corr.style.set_table_styles(DF_STYLE).format(precision=2)
# Out:
# <style type="text/css">
# #T_46bc9 .index_name {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_46bc9 th:not(.index_name) {
#   font-weight: normal;
#   background-color: #FFFCFA;
#   color: #4A4B52;
# }
# #T_46bc9 td {
#   color: #4A4B52;
#   font-weight: bold;
# }
# </style>
# <table id="T_46bc9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46bc9_level0_col0" class="col_heading level0 col0" >Feature 1</th>
#       <th id="T_46bc9_level0_col1" class="col_heading level0 col1" >Feature 2</th>
#       <th id="T_46bc9_level0_col2" class="col_heading level0 col2" >Absolute Pearson Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46bc9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_46bc9_row0_col0" class="data row0 col0" >Lesion_2</td>
#       <td id="T_46bc9_row0_col1" class="data row0 col1" >Lesion_3</td>
#       <td id="T_46bc9_row0_col2" class="data row0 col2" >0.64</td>
#     </tr>
#     <tr>
#       <th id="T_46bc9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_46bc9_row1_col0" class="data row1 col0" >Nasogastric_Reflux_Ph</td>
#       <td id="T_46bc9_row1_col1" class="data row1 col1" >Total_Protein</td>
#       <td id="T_46bc9_row1_col2" class="data row1 col2" >0.58</td>
#     </tr>
#     <tr>
#       <th id="T_46bc9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_46bc9_row2_col0" class="data row2 col0" >Total_Protein</td>
#       <td id="T_46bc9_row2_col1" class="data row2 col1" >Abdomo_Protein</td>
#       <td id="T_46bc9_row2_col2" class="data row2 col2" >0.47</td>
#     </tr>
#     <tr>
#       <th id="T_46bc9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_46bc9_row3_col0" class="data row3 col0" >Pulse</td>
#       <td id="T_46bc9_row3_col1" class="data row3 col1" >Packed_Cell_Volume</td>
#       <td id="T_46bc9_row3_col2" class="data row3 col2" >0.44</td>
#     </tr>
#     <tr>
#       <th id="T_46bc9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_46bc9_row4_col0" class="data row4 col0" >Nasogastric_Reflux_Ph</td>
#       <td id="T_46bc9_row4_col1" class="data row4 col1" >Abdomo_Protein</td>
#       <td id="T_46bc9_row4_col2" class="data row4 col2" >0.43</td>
#     </tr>
#     <tr>
#       <th id="T_46bc9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_46bc9_row5_col0" class="data row5 col0" >Pulse</td>
#       <td id="T_46bc9_row5_col1" class="data row5 col1" >Respiratory_Rate</td>
#       <td id="T_46bc9_row5_col2" class="data row5 col2" >0.40</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
#     border-bottom: 2px solid #3A5A81;
# ">
#     <b>Correlation Matrix</b> 📜
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
# ">
#     As we can see, there is only six somewhat correlated pairs, however <code>Lesion_2</code> and <code>Lesion_3</code> are composed almost from zeros, so it's hard to say about correlation here. <b>I also checked the Spearman correlation, but the situation is similar to the Pearson one, i.e. weakly correlated features. As the training and test datasets follow each other, the situation is similar in both cases.</b><br><br>
#     Since we have the correlation matrix, we could use it for another visualisation - hierarchical clustering. Nevertheless, I checked that and there is no clear clusters, which may be useful in PCA or some other dimensionality reduction algorithm. Let's have a look at numerical variables pair plots.
# </p>

# %%
dims = np.setdiff1d(num_features, ("Lesion_2", "Lesion_3", "Hospital_Number"))

fig = px.scatter_matrix(
    train,
    dimensions=dims,
    color="Outcome",
    color_discrete_sequence=["#815B3A", "#4A4B52", "#3A5A81"],
    symbol="Outcome",
    symbol_sequence=["cross", "circle", "diamond"],
    opacity=0.75,
    title="Numerical Features - Scatter Pair Plots",
    width=840,
    height=840,
)
fig.update_yaxes(showgrid=False)
fig.update_xaxes(showgrid=False)
fig.update_traces(diagonal_visible=False, showupperhalf=False, marker_size=1.5)
fig.update_layout(
    font_color=FONT_COLOR,
    font_size=7,
    title_font_size=18,
    plot_bgcolor=BACKGROUND_COLOR,
    paper_bgcolor=BACKGROUND_COLOR,
    showlegend=True,
    legend=dict(
        orientation="h",
        yanchor="bottom",
        xanchor="right",
        y=1,
        x=1,
        itemsizing="constant",
        font_size=12,
        title="",
    ),
)
fig.show()

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
#     border-bottom: 2px solid #3A5A81;
# ">
#     <b>Pair Plots</b> 📜
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
# ">
#     In the pair plots above, I rejected <code>Lesion_2</code>, <code>Lesion_3</code>, <code>Hospital_Number</code> features, since these are useless in this visualization. Here, we can see that regardless the outcome, there is an overlaying in data points. So there is no distinguish areas of clusters, where for example <code>Outcome</code> is <i>lived</i> or <i>died</i>. Let's have a look at categorical feature once more time. This time regarding to the <code>Outcome</code>.
# </p>

# %%
n_cols = 3
n_rows, axes = get_n_rows_axes(len(cat_features), n_cols)
fig = make_subplots(
    rows=n_rows,
    cols=n_cols,
    y_title="Sum of Count (Normalized as Percent)",
    horizontal_spacing=0.1,
    vertical_spacing=0.1,
)
fig.update_annotations(font_size=14)

for k, (var, (row, col)) in enumerate(zip(cat_features, axes), start=1):
    for outcome, color in zip(("died", "euthanized", "lived"), ("#815B3A", "#4A4B52", "#3A5A81")):
        fig.add_histogram(
            x=train.query(f"Outcome == '{outcome}'")[var],
            marker_color=color,
            opacity=0.75,
            name=outcome,
            legendgroup=outcome,
            showlegend=k == 1,
            row=row,
            col=col,
        )
        fig.update_xaxes(
            tickfont_size=8,
            showgrid=False,
            title_text=var,
            titlefont_size=8,
            titlefont_family="Arial Black",
            row=row,
            col=col,
        )
        fig.update_yaxes(tickfont_size=8, showgrid=False, row=row, col=col)

fig.update_layout(
    font_color=FONT_COLOR,
    title="Categorical Features vs Horse Health Status",
    title_font_size=18,
    plot_bgcolor=BACKGROUND_COLOR,
    paper_bgcolor=BACKGROUND_COLOR,
    width=840,
    height=1040,
    xaxis_showgrid=False,
    yaxis_showgrid=False,
    barnorm="percent",
    barmode="relative",
    bargap=0.3,
    legend=dict(
        orientation="h",
        yanchor="bottom",
        xanchor="right",
        y=1.02,
        x=1,
        itemsizing="constant",
        title="",
    ),
)
fig.show()

# %% [markdown]
# <p style="
#     font-size: 20px;
#     font-family: 'JetBrains Mono';
#     color: #4A4B52;
#     border-bottom: 2px solid #3A5A81;
# ">
#     <b>Categories vs Horse Health Status</b> 📜
# </p>
#
# <p style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
# ">
#     There we have bar plots related to the horse health status. Bars were normalized as percentage, so we can easily compare specific category and <code>Outcome</code> feature. This way we can easily see that:
# </p>
#
# <ul style="
#     font-size: 16px;
#     font-family: 'JetBrains Mono';
# ">
#     <li>If the horse was treated with surgery it was a higher chance to die.</li>
#     <li>Young horses have more chance to die.</li>
#     <li>If <code>Temp_Of_Extremities</code> is <i>warm</i> or <i>normal</i>, the horse has a higher chance to live.</li>
#     <li>If <code>Peripheral_Pulse</code> is <i>normal</i> or <i>increased</i>, the horse has a higher chance to live. On the other hand <i>absent</i> means a higher chance to be euthanized.</li>
#     <li>If <code>Mucous_Membrane</code> is <i>pale_pink</i>, <i>bright_pink</i> or <i>normal_pink</i> the horse has a higher chance to live.</li>
#     <li>If <code>Capillary_Refill_Time</code> is <i>less_3_sec</i>, the horse has a higher chance to live.</li>
#     <li>The <i>mild_pain</i> or <i>alert</i> in <code>Pain</code> give the horse a higher chance to survive.</li>
#     <li>The <i>normal</i>, <i>hypermotile</i> or <i>hypomotile</i> in <code>Peristalsis</code> give the horse a higher chance to survive.</li>
#     <li>The <i>slight</i> or <i>none</i> in <code>Abdominal_Distention</code> give the horse a higher chance to survive.</li>
#     <li>When <code>Nasogastric_Tube</code> is <i>slight</i>, there is more than $50$% that the horse is lived. In the rest categories the situation is mixed.</li>
#     <li>When <code>Nasogastric_Reflux</code> is <i>slight</i> or <i>none</i>, there is a big chance that the horse is lived.</li>
#     <li>When <code>Rectal_Exam_Feces</code> is <i>absent</i> there is a higher chance that the horse is died.</li>
#     <li>When <code>Abdomen</code> is <i>firm</i> or <i>other</i> there is a higher chance that the horse is lived.</li>
#     <li>In the case of the <code>Abdomo_Appearance</code>, the is <i>none</i> means that the horse has a higher chance to be euthanized. On the other hand, <i>clear</i> gives him a higher chance to live.</li>
#     <li>If the problem (lesion) was surgical, then the horse has a higher chance to be died.</li>
#     <li>If the pathology data is present, there is a bigger chance to be euthanized for being alive.</li>
# </ul>

# %% [markdown]
# Continue...
